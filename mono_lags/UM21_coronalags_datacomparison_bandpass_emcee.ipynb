# %%
from __future__ import division
import numpy as np
import mpmath
import scipy
import scipy.stats as sps
import scipy.fftpack as spfft
import scipy.signal as spsig
import scipy.optimize as spopt
import scipy.interpolate as spint
import matplotlib
from mpl_toolkits.axes_grid1.inset_locator import (inset_axes, InsetPosition,
                                                  mark_inset)
import lmfit as lmfit

import math
import matplotlib.pyplot as plt
import um21_lagmodel_new as uml
import sys, os
sys.path.append(os.path.abspath("../C++/"))
import lagmodel as lm
from lagmodel import geometries as geo
# %matplotlib notebook

# Set up list of colours that are more colour-blind accessible.
CBcol = ['#377eb8', '#ff7f00', '#4daf4a',
                  '#f781bf', '#a65628', '#984ea3',
                  '#999999', '#e41a1c', '#dede00']

# %%
disklag_data = np.loadtxt('tlags_111_gx339_04_2_3vs0p5_0p9keV59s.dat')
freq_data = (disklag_data[:,0]+disklag_data[:,1])/2.
dfreq_data = (disklag_data[:,1]-disklag_data[:,0])/2.
disktlags_data = disklag_data[:,2]/(2*dfreq_data)
disktlags_err_data = disklag_data[:,3]/(2*dfreq_data)

powlag_data = np.loadtxt('tlags_111_gx339_04_6_9vs2_3keV59s.dat')
powtlags_data = powlag_data[:,2]/(2*dfreq_data)
powtlags_err_data = powlag_data[:,3]/(2*dfreq_data)

diskpsd_fulldata = np.loadtxt('psd_111_gx339_04_0p5_0p9vs2_3keV59s.dat')
diskpsd_data = diskpsd_fulldata[:,2]/(2*dfreq_data)
diskpsd_err_data = diskpsd_fulldata[:,3]/(2*dfreq_data)
disknoise = np.mean(diskpsd_data[-8:]/freq_data[-8:])*freq_data

powspsd_fulldata = np.loadtxt('psd_111_gx339_04_2_3vs0p5_0p9keV59s.dat')
powspsd_data = powspsd_fulldata[:,2]/(2*dfreq_data)
powspsd_err_data = powspsd_fulldata[:,3]/(2*dfreq_data)
snoise = np.mean(powspsd_data[-8:]/freq_data[-8:])*freq_data

powhpsd_fulldata = np.loadtxt('psd_111_gx339_04_6_9vs2_3keV59s.dat')
powhpsd_data = powhpsd_fulldata[:,2]/(2*dfreq_data)
powhpsd_err_data = powhpsd_fulldata[:,3]/(2*dfreq_data)
hnoise = np.mean(powhpsd_data[-8:]/freq_data[-8:])*freq_data
diskpsd_data = diskpsd_data - disknoise
powspsd_data = powspsd_data - snoise
powhpsd_data = powhpsd_data - hnoise
diskvssoft_psdratio = diskpsd_data/powspsd_data
softvshard_psdratio = powspsd_data/powhpsd_data
diskvssoft_err_psdratio = diskpsd_err_data/powspsd_data
softvshard_err_psdratio = powspsd_err_data/powhpsd_data

# %%
def plot_data_lags_psds(lags_list, psds_list, vlines_list, axis_names, freqlim, freqlim_in, tlaglim, 
                        tlaglim_in, psdlim, inset_yticks, leg_title=None, figfile=None):
    
    fig, (ax1, ax2) = plt.subplots(2,1, figsize=(8,8),sharex=True,gridspec_kw={'height_ratios':[5,3]})
    fig.subplots_adjust(hspace=0)
    ax3 = plt.axes([0,0,1,1])
    ip = InsetPosition(ax1, [0.65,0.62,0.32,0.37])
    ax3.set_axes_locator(ip)
    for i, x in enumerate(lags_list):
        freq = x[0]
        tlag = x[1]
        colour_val = x[2]
        ls_val = x[3]
        label_val = x[4]
        data_freq = x[5]
        data_tlag = x[6]
        data_tlag_err = x[7]
        data_label_val = x[8]
        data_present = x[9]
        ax1.plot(freq,tlag,color=colour_val,linewidth=3,linestyle=ls_val,label=label_val)
        ax3.plot(freq,tlag,color=colour_val,linewidth=3,linestyle=ls_val)
        if (data_present == True):
            if i == 0:
                ax1.errorbar(data_freq,data_tlag,yerr=data_tlag_err,color='red',marker='o',label=data_label_val)
                ax3.errorbar(data_freq,data_tlag,yerr=data_tlag_err,color='red',marker='o')
            if i == 1:
                ax1.errorbar(data_freq,data_tlag,yerr=data_tlag_err,color='black',marker='o',label=data_label_val)
                ax3.errorbar(data_freq,data_tlag,yerr=data_tlag_err,color='black',marker='o')            
    for i, x in enumerate(psds_list):
        freq = x[0]
        psd = x[1]
        colour_val = x[2]
        ls_val = x[3]
        label_val = x[4]
        data_freq = x[5]
        data_psd = x[6]
        data_psd_err = x[7]
        data_label_val = x[8]
        data_present = x[9]
        ax2.plot(freq,psd,color=colour_val,linewidth=3,linestyle=ls_val,label=label_val)
        if (data_present == True):
            if i == 0:
                ax2.errorbar(data_freq,data_psd,yerr=data_psd_err,color='red',marker='o',label=data_label_val)
            if i == 1:
                ax2.errorbar(data_freq,data_psd,yerr=data_psd_err,color='black',marker='o',label=data_label_val)
    if (vlines_list != None):
        for line in vlines_list:
            for ax in (ax1, ax2, ax3):
                ax.axvline(line[0],color=line[1],alpha=0.5,linewidth=3,linestyle=line[2])
    ax3.set_xlim(freqlim_in)
    ax3.set_ylim(tlaglim_in)
    ax3.set_xscale('log')
    ax3.set_yscale('linear')
    ax3.axhline(color='grey',linestyle='dotted')
    ax3.set_xticks([1,10])
    ax3.set_yticks(inset_yticks)
    ax2.set_xticklabels(ax2.get_xticks(), backgroundcolor='w')
    ax2.legend(fontsize=12,title=leg_title,title_fontsize=12)
    ax2.set_xlabel(axis_names[0],fontsize=14)
    ax1.set_ylabel(axis_names[1],fontsize=14)
    ax2.set_ylabel(axis_names[2],fontsize=14)
    ax3.set_xlabel(axis_names[0],fontsize=10)
    ax3.set_ylabel(axis_names[1],fontsize=10)
    ax1.set_yscale('log')
    ax2.set_yscale('log')
    ax2.set_xscale('log')
    ax2.set_xlim(freqlim)
    ax1.set_ylim(tlaglim)
    ax2.set_ylim(psdlim)
    for ax in (ax1, ax2, ax3):
        ax.tick_params(axis='x',labelsize=12, which='both', direction='in', top=True)
        ax.tick_params(axis='y',labelsize=12, which='both', direction='in', right=True)
        ax.tick_params(which='major', length=10)
        ax.tick_params(which='minor', length=6)
    if (figfile != None):
        plt.savefig(figfile,bbox_inches='tight')
    plt.show()

    return

def plot_data_lags(inputs, lags_list, vlines_list, axis_names, freqlim, freqlim_in, tlaglim, tlaglim_in, inset_yticks, 
                   leg_title=None, figfile=None):
    
    fig, ax1 = plt.subplots(1,1, figsize=(8,6))
    fig.subplots_adjust(hspace=0)
    ax2 = plt.axes([0,0,1,1])
    ip = InsetPosition(ax1, [0.65,0.62,0.32,0.37])
    ax2.set_axes_locator(ip)
    for i, x in enumerate(lags_list):
        freq = x[0]
        tlag = x[1]
        colour_val = x[2]
        ls_val = x[3]
        label_val = x[4]
        data_freq = x[5]
        data_tlag = x[6]
        data_tlag_err = x[7]
        data_label_val = x[8]
        if (inputs[0] == True):
            ax1.plot(freq,tlag,color=colour_val,linewidth=3,linestyle=ls_val,label=label_val)
            ax2.plot(freq,tlag,color=colour_val,linewidth=3,linestyle=ls_val)
        if (inputs[1] == True):
            if i == 0:
                ax1.errorbar(data_freq,data_tlag,yerr=data_tlag_err,color='red',marker='o',label=data_label_val)
                ax2.errorbar(data_freq,data_tlag,yerr=data_tlag_err,color='red',marker='o')
            if i == 1:
                ax1.errorbar(data_freq,data_tlag,yerr=data_tlag_err,color='black',marker='o',label=data_label_val)
                ax2.errorbar(data_freq,data_tlag,yerr=data_tlag_err,color='black',marker='o')            
    if (vlines_list != None):
        for line in vlines_list:
            for ax in (ax1, ax2):
                ax.axvline(line[0],color=line[1],alpha=0.5,linewidth=3,linestyle=line[2])
    ax2.set_xlim(freqlim_in)
    ax2.set_ylim(tlaglim_in)
    ax2.set_xscale('log')
    ax2.set_yscale('linear')
    ax2.axhline(color='grey',linestyle='dotted')
    ax2.set_xticks([1,10])
    ax2.set_yticks(inset_yticks)
    ax1.set_xticklabels(ax1.get_xticks(), backgroundcolor='w')
    ax1.legend(fontsize=12,title=leg_title,title_fontsize=12,loc='lower left')
    ax1.set_xlabel(axis_names[0],fontsize=14)
    ax1.set_ylabel(axis_names[1],fontsize=14)
    ax2.set_xlabel(axis_names[0],fontsize=10)
    ax2.set_ylabel(axis_names[1],fontsize=10)
    ax1.set_xscale('log')
    ax1.set_yscale('log')
    ax1.set_xlim(freqlim)
    ax1.set_ylim(tlaglim)
    for ax in (ax1, ax2):
        ax.tick_params(axis='x',labelsize=12, which='both', direction='in', top=True)
        ax.tick_params(axis='y',labelsize=12, which='both', direction='in', right=True)
        ax.tick_params(which='major', length=10)
        ax.tick_params(which='minor', length=6)
    if (figfile != None):
        plt.savefig(figfile,bbox_inches='tight')
    plt.show()

    return

# %%
def lagmodel_original(params, freq_in, data_in, error_in, encomb_in, rout=1000, nrad=100, nphi=100, nz=400, 
             cor_geometry=uml.inv_cone, t_scale=5e-5, e_seed=1.0, ens_mono=np.array([1.,3.,9.]), 
             gamma_par=[2.33,0.167], band_calc=True, encomb=np.array([[2,0],[3,2]]), nirf_mult=8, 
             min_deltau_frac=1, freq_rsigmax=0.01, freq_range=[0.01,20.0], kTvar=True,
            psd_correct=True, lor_model='continuous'):
    
    rin = params['rin'].value
    rcor = params['rcor'].value
    hcor = params['hcor'].value
    cone_angle = params['cone_angle'].value
    seedff_norm = params['seedff_norm'].value
    thermal_frac = params['thermal_frac'].value
    pow_disk_frac = params['pow_disk_frac'].value
    disk_en = params['disk_en'].value
    band_mult = params['band_mult'].value
    disk_tau_norm = params['disk_tau_norm'].value   
    disk_tau_ind = params['disk_tau_ind'].value
    delay_tau_scale = params['delay_tau_scale'].value
    disp_ind = params['disp_ind'].value
    disksoft_psdnorm = params['disksoft_psdrat_norm'].value
    softhard_psdnorm = params['softhard_psdrat_norm'].value
    
    if lor_model == 'continuous':
        lor_q = params['lor_q1'].value
        
    if lor_model == 'multi_frequency':         
        lor_q1 = params['lor_q1'].value   
        lor_freq1 = params['lor_freq1'].value
        lor_rms1 = params['lor_rms1'].value
        lor_q2 = params['lor_q2'].value   
        lor_freq2 = params['lor_freq2'].value
        lor_rms2 = params['lor_rms2'].value
        lor_q3 = params['lor_q3'].value   
        lor_freq3 = params['lor_freq3'].value
        lor_rms3 = params['lor_rms3'].value

    
    heatff_norm = 1-seedff_norm
    seedff_ind = 0
    heatff_ind = 0
    disk_tau_par = [disk_tau_norm,disk_tau_ind]
    disk_prop_par = [disk_tau_norm*delay_tau_scale,disk_tau_ind]
    cor_tau_par = [disk_tau_norm,0]
    cor_prop_par = [0,0]
    if cor_geometry == uml.inv_cone:
        rtop = rcor + hcor*np.tan(np.pi*(np.array(cone_angle)/180))
        geopar = [rcor,hcor,rtop,nphi,nz]
    if cor_geometry == uml.an_sphere:
        geopar = [rcor]
    if lor_model == 'continuous':
        lor_par = [lor_q,0.4,0.0] # For continuous model: [q,total_rms_in_disk,total_rms_in_corona]
    if lor_model == 'multi_frequency':
        lor_par = [lor_freq1,lor_q1,lor_rms1,lor_freq2,lor_q2,lor_rms2,lor_freq3,lor_q3,lor_rms3]
    
    rsigmax = ((1/(freq_rsigmax*t_scale))/(disk_tau_norm*rcor**(-1.*disk_tau_ind)))**(1/(1.5+disk_tau_ind))
    print("Minimum frequency =",freq_rsigmax,"Hz and maximum signal radius = ",rsigmax,"Rg")
    
    rout = max([2*rsigmax,rout])
        
    #First set up radial grid
    rad_edge1 = np.logspace(np.log10(rin), np.log10(rsigmax), nrad+1)  # set up radial bin edges
    rad_edge2 = np.logspace(np.log10(rsigmax), np.log10(rout), nrad+1)
    rad_edge = np.append(rad_edge1,rad_edge2[1:])
    nrad = nrad*2
    
    rad = np.sqrt(rad_edge[1:]*rad_edge[:-1])  # Define radial bin centres as geometric mean of bin edges
    rad_area = np.pi*(np.square(rad_edge[1:])-np.square(rad_edge[:-1]))
    # Now reset coronal outer radius (i.e. disk inner radius) to be at the nearest radial bin edges
    rcor, i_rcor = uml.find_nearest(rad_edge,rcor)
    disp_frac, seed_frac_flow, heat_frac_flow = \
        uml.calc_dispfrac_ind(rad,rad_area,rin,rcor,disp_ind,seedff_norm,seedff_ind,heatff_norm,heatff_ind)
    # Normalised viscous dissipation and parameters for seed and heating fractions within coronal flow.
    # Reset maximum signal radius to nearest radial bin value
    rsigmax, i_rsigmax = uml.find_nearest(rad,rsigmax)
    # Calculate illumination of corona by disk and vice-versa
    omega_cor, disktocor_frac, cortodisk_frac = uml.calc_illumination_fracs(rad,rad_area,cor_geometry,geopar)
    # Now calculate radial dependence of timing parameters and calculate propagation delays
    tau, lfreq, q, rms = uml.calc_timing_params(rad, i_rsigmax, rcor, i_rcor, t_scale, disk_tau_par, cor_tau_par,\
                                        lor_model, lor_par)
    deltau = uml.calc_propagation_params(rad,rad_edge,rcor,disk_prop_par,cor_prop_par)
    
    # Calculate the radially-dependent direct disk, seed photon and coronal heating luminosities
    ldisk_disp, lseed_disp, lheat, ldisk_rev, lseed_rev =\
        uml.calc_radial_time_response(rad,rcor,disp_frac,disktocor_frac,cortodisk_frac,thermal_frac,seed_frac_flow,heat_frac_flow)    
    # Calculate IRFs for the mono-energetic case
    gamma_mean, gamma_irf, flux_irf_mono, disk_irf_mono, seed_irf_mono = uml.calc_irfs_mono(gamma_par,e_seed,ens_mono,\
                                ldisk_disp,lseed_disp,lheat,ldisk_rev,lseed_rev)
    
    if band_calc == True:
        disk_eband = [disk_en,disk_en*band_mult]
#        disk_eband = [disk_en,disk_en*2.0]
        band_frac, kT_rad, disk_irf_mono, lseed_band, ldiskband_disp, ldiskband_rev = calc_disk_band(disp_frac,cortodisk_frac,
                                    disktocor_frac,lseed_disp,lheat,thermal_frac,rcor,rad,rad_area,disk_eband,kTvar)
        band_frac2, kT_rad2, disk_irf_mono2, lseed_band2, ldiskband_disp2, ldiskband_rev2 = calc_disk_band(disp_frac,cortodisk_frac,
                                    disktocor_frac,lseed_disp,lheat,thermal_frac,rcor,rad,rad_area,disk_eband,kTvar=False)

#    if (pow_disk_frac > 0):
#        disk_irf_mono = flux_irf_mono[0,:]*pow_disk_frac/(np.sum(flux_irf_mono[0,:])/np.sum(disk_irf_mono))\
#                            + disk_irf_mono
#        disk_irf_mono2 = flux_irf_mono[0,:]*pow_disk_frac/(np.sum(flux_irf_mono[0,:])/np.sum(disk_irf_mono2))\
#                            + disk_irf_mono2
        norm = (gamma_mean-1)*np.sum(lseed_band2)/np.mean(np.array(disk_eband))

        plseeden_irf = norm*(gamma_irf*(1/(gamma_mean-1)) + 
                             lseed_band/np.sum(lseed_band2))*np.diff(np.array(disk_eband))

        disk_irf_mono = plseeden_irf*pow_disk_frac + disk_irf_mono
        disk_norm = norm*np.diff(np.array(disk_eband))*pow_disk_frac + np.sum(disk_irf_mono2)
        print('Disk band IRF PL frac: ',np.sum(plseeden_irf*pow_disk_frac)/np.sum(disk_irf_mono))
        print('Disk band total PL frac: ',norm*np.diff(np.array(disk_eband))*pow_disk_frac/disk_norm)

    freq, phlag, tlag, psd_ci, psd_ref, mod_sig_psd, irf_nbins, irf_binedgefrac, deltau_scale, dt, nirf,\
        ci_irf, ci_mean, ci_outer =\
    uml.calculate_stprod_mono_frange(nirf_mult,ens_mono,encomb,flux_irf_mono,disk_irf_mono,gamma_irf,
                              deltau,min_deltau_frac,i_rsigmax,lfreq,q,rms,t_scale,freq_range)
    if band_calc == True and psd_correct == True:
        psd_ref[0,:] = psd_ref[0,:]*(np.sum(disk_irf_mono)/disk_norm)**2
    if freq_in == None:
        return gamma_mean, freq, phlag, tlag, psd_ci, psd_ref, tau, i_rcor, i_rsigmax, rad, deltau,\
            ldisk_disp, lseed_disp,lheat, ldisk_rev, lseed_rev, flux_irf_mono, mod_sig_psd, disk_irf_mono, band_frac
    else:
        for i, freq_data in enumerate(freq_in):
            if (encomb_in[i] > 0):
                model_int = spint.interp1d(freq,tlag[encomb_in[i]-1,:])
            else:
#                if encomb_in[i] == -1:
#                    psdratio_norm = disksoft_psdnorm
#                else:
#                    psdratio_norm = softhard_psdnorm
                psdratio_norm = np.mean(psd_ref[abs(encomb_in[i])-1,freq<1]/psd_ci[abs(encomb_in[i])-1,freq<1])\
                            /np.mean(data_in[i][freq_data < 1])
                model_int = spint.interp1d(freq,psdratio_norm*psd_ref[abs(encomb_in[i])-1,:]/psd_ci[abs(encomb_in[i])-1,:])                
            if data_in == None:
                if i == 0:
                    y_output = model_int(freq_data)
                else:
                    y_output = np.append(y_output,model_int(freq_data))
            else:
                if i == 0:
                    y_output = (data_in[i] - model_int(freq_data))/error_in[i]
                else:
                    y_output = np.append(y_output,(data_in[i] - model_int(freq_data))/error_in[i])            
        return y_output

# %%
def calc_disk_band(disp_frac,cortodisk_frac,disktocor_frac,lseed_disp,lheat,thermal_frac,rcor,rad,rad_area,
                   eband,kTvar): 
    # Given the fractional of total flux due to 
    # dissipation, and the area
    # of each radial annulus of the disk, calculate the fraction of the flux at each radius which is emitted in a fixed
    # energy band, [E_min,E_max].  The energy band is defined not in absolute energy but relative to the maximum
    # blackbody temperature in the disk.  E.g. we observe an inner disk temperature of 0.3 keV and assume to probe 
    # this to correspond to the maximum.  If we then want to probe an energy range 0.6-0.9 keV, we should specify
    # eband = [2.0,3.0]
    
    f_rev = np.sum(cortodisk_frac) # The fraction of coronal luminosity that is reprocessed by the disk
    f_return = np.sum(cortodisk_frac*disktocor_frac) # the fraction of coronal luminosity that is reprocessed by the disk
    radldisk_rev = cortodisk_frac*thermal_frac*np.sum((lseed_disp+lheat)/(1-f_return))
    
    kT_rad = np.zeros(len(disp_frac))
    band_frac = np.zeros(len(disp_frac))
    kT_rad[rad > rcor] = ((disp_frac[rad > rcor]+
                                 radldisk_rev[rad > rcor])/rad_area[rad > rcor])**0.25
    kT_max = np.amax(kT_rad)
    kT_rad = kT_rad/kT_max
    
    E_min = eband[0]
    E_max = eband[1]
    # Total ph flux of bb_phlux for 1 keV = 2*Apery's constant *15/pi^4 for non-variable bb,
    # 1.5*Apery's constant *15/pi^4 for variable bb
    if kTvar == False:
        bb_phintnorm = 2*1.2020569031595942*15/np.pi**4 
    else:
        bb_phintnorm = 1.5*1.2020569031595942*15/np.pi**4 
    for i, radval in enumerate(rad):
        if radval > rcor:
            band_frac[i] = lm.bb_phflux(E_min, E_max, kT_rad[i], 1000, kTvar)/(bb_phintnorm/kT_rad[i])
        
    ldiskband_disp = disp_frac*(1-disktocor_frac)*band_frac
    lseedband_disp = disp_frac*disktocor_frac*band_frac
    
    ldiskband_rev_arr = thermal_frac*band_frac*(cortodisk_frac*(1-
                    disktocor_frac))*(lseed_disp.reshape(len(rad),1)+lheat.reshape(len(rad),1))/(1-f_return)
    
    lseedband_rev_arr = thermal_frac*band_frac*(cortodisk_frac*disktocor_frac)*\
        (lseed_disp.reshape(len(rad),1)+lheat.reshape(len(rad),1))/(1-f_return)
    ldiskband_rev = np.sum(ldiskband_rev_arr,axis=1)
    lseedband_rev = np.sum(lseedband_rev_arr,axis=1)
    ldisk_band = ldiskband_disp + ldiskband_rev
    lseed_band = lseedband_disp + lseedband_rev
    
    return band_frac, kT_rad, ldisk_band, lseed_band, ldiskband_disp, ldiskband_rev

        
def bb_phflux(E_min, E_max, kT, nE, kTvar): # Calculates blackbody flux for blackbody with temperature kT and
    # integrated over an energy range E_min to E_max using nE discrete bins
    # The model is normalised to maintain a constant total energy flux regardless of kT (based on XSPEC bbody model)    

    E_edge = np.logspace(np.log10(E_min), np.log10(E_max), nE+1)
    E = np.sqrt(np.multiply(E_edge[1:],E_edge[:-1]))
    dE = E_edge[1:]-E_edge[:-1]
    if kTvar == False:
        bb_flux = np.sum((dE/E)*(E**3/kT**4)/(np.exp(E/kT)-1.))
    else:
        bb_flux = np.sum((dE/E)*(0.25*(E**4/kT**5)*np.exp(E/kT)*(np.exp(E/kT)-1)**-2))

    return bb_flux/((np.pi**4)/15)

def bb_enflux(E_min, E_max, kT, nE, kTvar): # Calculates blackbody flux for blackbody with temperature kT and
    # integrated over an energy range E_min to E_max using nE discrete bins
    # The model is normalised to maintain a constant total energy flux regardless of kT (based on XSPEC bbody model)    

    E_edge = np.logspace(np.log10(E_min), np.log10(E_max), nE+1)
    E = np.sqrt(np.multiply(E_edge[1:],E_edge[:-1]))
    dE = E_edge[1:]-E_edge[:-1]
    if kTvar == False:
        bb_flux = np.sum(dE*(E**3/kT**4)/(np.exp(E/kT)-1.))
    else:
        bb_flux = np.sum(dE*(0.25*(E**4/kT**5)*np.exp(E/kT)*(np.exp(E/kT)-1)**-2))

    return bb_flux/((np.pi**4)/15)


def bb_photflux(E_edge, kT, kTvar): # Calculates blackbody flux per bin for blackbody with 
    # temperature kT and calculated over an energy range E_min to E_max using nE discrete bins
    # The models are normalised to maintain a constant total flux regardless of kT (based on XSPEC bbody model)    
    # So should be multiplied by the local fractional mdot change to give change in blackbody emission
    # kTvar is a True/False flag for whether the linearised variable blackbody spectrum should be used vs
    # the non-variable ('time averaged') spectrum
    E = np.sqrt(np.multiply(E_edge[1:],E_edge[:-1]))
    dE = E_edge[1:]-E_edge[:-1]
    if kTvar == False:
        bb_flux = dE*(E**2/kT**4)/(np.exp(E/kT)-1.)
    else:
        bb_flux = dE*(0.25*(E**3/kT**5)*np.exp(E/kT)*(np.exp(E/kT)-1)**-2)

    return bb_flux


def lagmodel(params, freq_in, data_in, error_in, encomb_in, rout=1000, nrad=100, nphi=100, nz=400, 
             cor_geometry=geo.Inv_Cone, t_scale=5e-5, e_seed=1.0, ens_mono=np.array([1.,3.,9.]), 
             gamma_par=[2.33,0.167], band_calc=True, encomb=np.array([[2,0],[3,2]]), nirf_mult=8, 
             min_deltau_frac=1, freq_rsigmax=0.01, freq_range=[0.01,20.0], kTvar=True,
            psd_correct=True, lor_model='continuous'):
# def lagmodel(params, freq_in, data_in, error_in, encomb_in, rout=1000, nrad=100, nphi=100, nz=400, 
#              cor_geometry=uml.inv_cone, t_scale=5e-5, e_seed=1.0, ens_mono=np.array([1.,3.,9.]), 
#              gamma_par=[2.33,0.167], band_calc=True, encomb=np.array([[2,0],[3,2]]), nirf_mult=8, 
#              min_deltau_frac=1, freq_rsigmax=0.01, freq_range=[0.01,20.0], kTvar=True,
#             psd_correct=True, lor_model='continuous'):
           
    # y_output_phil = lagmodel_original(params, freq_in, data_in, error_in, encomb_in, rout, nrad, nphi, nz, uml.inv_cone, t_scale, e_seed, ens_mono, gamma_par, band_calc, encomb, nirf_mult, min_deltau_frac, freq_rsigmax, freq_range, kTvar, psd_correct, lor_model)

    rin = params['rin'].value
    rcor = params['rcor'].value
    hcor = params['hcor'].value
    cone_angle = params['cone_angle'].value
    seedff_norm = params['seedff_norm'].value
    thermal_frac = params['thermal_frac'].value
    pow_disk_frac = params['pow_disk_frac'].value
    disk_en = params['disk_en'].value
    band_mult = params['band_mult'].value
    disk_tau_norm = params['disk_tau_norm'].value   
    disk_tau_ind = params['disk_tau_ind'].value
    delay_tau_scale = params['delay_tau_scale'].value
    disp_ind = params['disp_ind'].value
    disksoft_psdnorm = params['disksoft_psdrat_norm'].value
    softhard_psdnorm = params['softhard_psdrat_norm'].value
    
    if lor_model == 'continuous':
        lor_q = params['lor_q1'].value
        
    if lor_model == 'multi_frequency':         
        lor_q1 = params['lor_q1'].value   
        lor_freq1 = params['lor_freq1'].value
        lor_rms1 = params['lor_rms1'].value
        lor_q2 = params['lor_q2'].value   
        lor_freq2 = params['lor_freq2'].value
        lor_rms2 = params['lor_rms2'].value
        lor_q3 = params['lor_q3'].value   
        lor_freq3 = params['lor_freq3'].value
        lor_rms3 = params['lor_rms3'].value

    
    heatff_norm = 1-seedff_norm
    seedff_ind = 0
    heatff_ind = 0
    disk_tau_par = [disk_tau_norm,disk_tau_ind]
    disk_prop_par = [disk_tau_norm*delay_tau_scale,disk_tau_ind]
    cor_tau_par = [disk_tau_norm,0]
    cor_prop_par = [0,0]
    if cor_geometry == geo.Inv_Cone:
    # if cor_geometry == uml.inv_cone:
        rtop = rcor + hcor*np.tan(np.pi*(np.array(cone_angle)/180))
        geopar = [rcor,hcor,rtop,nphi,nz]
    if cor_geometry == geo.AN_Sphere:
    # if cor_geometry == uml.an_sphere:
        geopar = [rcor]
    if lor_model == 'continuous':
        lor_par = [lor_q,0.4,0.0] # For continuous model: [q,total_rms_in_disk,total_rms_in_corona]
    if lor_model == 'multi_frequency':
        lor_par = [lor_freq1,lor_q1,lor_rms1,lor_freq2,lor_q2,lor_rms2,lor_freq3,lor_q3,lor_rms3]
    
    rsigmax = ((1/(freq_rsigmax*t_scale))/(disk_tau_norm*rcor**(-1.*disk_tau_ind)))**(1/(1.5+disk_tau_ind))
    print("Minimum frequency =",freq_rsigmax,"Hz and maximum signal radius = ",rsigmax,"Rg")
    
    rout = max([2*rsigmax,rout])
        
    #First set up radial grid
    rad_edge1 = np.logspace(np.log10(rin), np.log10(rsigmax), nrad+1)  # set up radial bin edges
    rad_edge2 = np.logspace(np.log10(rsigmax), np.log10(rout), nrad+1)
    rad_edge = np.append(rad_edge1,rad_edge2[1:])
    nrad = nrad*2
    
    rad = np.sqrt(rad_edge[1:]*rad_edge[:-1])  # Define radial bin centres as geometric mean of bin edges
    rad_area = np.pi*(np.square(rad_edge[1:])-np.square(rad_edge[:-1]))
    # Now reset coronal outer radius (i.e. disk inner radius) to be at the nearest radial bin edges
    rcor, i_rcor = uml.find_nearest(rad_edge,rcor)
    disp_frac, seed_frac_flow, heat_frac_flow = \
        uml.calc_dispfrac_ind(rad,rad_area,rin,rcor,disp_ind,seedff_norm,seedff_ind,heatff_norm,heatff_ind)
    # Normalised viscous dissipation and parameters for seed and heating fractions within coronal flow.
    # Reset maximum signal radius to nearest radial bin value
    rsigmax, i_rsigmax = uml.find_nearest(rad,rsigmax)
    # Calculate illumination of corona by disk and vice-versa
    geometry = cor_geometry(rad, rad_area, *geopar)
    omega_cor, disktocor_frac, cortodisk_frac = lm.calc_illumination_fracs(geometry)
    # omega_cor1, disktocor_frac1, cortodisk_frac1 = uml.calc_illumination_fracs(rad,rad_area,uml.inv_cone,geopar)
    # Now calculate radial dependence of timing parameters and calculate propagation delays
    tau, lfreq, q, rms = lm.calc_timing_params(rad, i_rsigmax, rcor, i_rcor, t_scale, disk_tau_par, cor_tau_par,\
                                        lor_model, lor_par)
    deltau = lm.calc_propagation_params(rad,rad_edge,rcor,disk_prop_par,cor_prop_par)

    # print(disktocor_frac - disktocor_frac1)
    # print(cortodisk_frac - cortodisk_frac1)

    # Calculate the radially-dependent direct disk, seed photon and coronal heating luminosities
    ldisk_disp, lseed_disp, lheat, ldisk_rev, lseed_rev =\
        lm.calc_radial_time_response(rad,rcor,disp_frac,disktocor_frac,cortodisk_frac,thermal_frac,seed_frac_flow,heat_frac_flow)    
    # Calculate IRFs for the mono-energetic case
    gamma_mean, gamma_irf, flux_irf_mono, disk_irf_mono, seed_irf_mono = lm.calc_irfs_mono(gamma_par,e_seed,ens_mono,\
                                ldisk_disp,lseed_disp,lheat,ldisk_rev,lseed_rev)
    
    if band_calc == True:
        disk_eband = [disk_en,disk_en*band_mult]
#        disk_eband = [disk_en,disk_en*2.0]
        band_frac, kT_rad, disk_irf_mono, lseed_band, ldiskband_disp, ldiskband_rev = lm.calc_disk_band(disp_frac,cortodisk_frac,
                                    disktocor_frac,lseed_disp,lheat,thermal_frac,rcor,rad,rad_area,disk_eband,kTvar)
        band_frac2, kT_rad2, disk_irf_mono2, lseed_band2, ldiskband_disp2, ldiskband_rev2 = lm.calc_disk_band(disp_frac,cortodisk_frac,
                                    disktocor_frac,lseed_disp,lheat,thermal_frac,rcor,rad,rad_area,disk_eband,kTvar=False)

#    if (pow_disk_frac > 0):
#        disk_irf_mono = flux_irf_mono[0,:]*pow_disk_frac/(np.sum(flux_irf_mono[0,:])/np.sum(disk_irf_mono))\
#                            + disk_irf_mono
#        disk_irf_mono2 = flux_irf_mono[0,:]*pow_disk_frac/(np.sum(flux_irf_mono[0,:])/np.sum(disk_irf_mono2))\
#                            + disk_irf_mono2
        norm = (gamma_mean-1)*np.sum(lseed_band2)/np.mean(np.array(disk_eband))

        plseeden_irf = norm*(gamma_irf*(1/(gamma_mean-1)) + 
                             lseed_band/np.sum(lseed_band2))*np.diff(np.array(disk_eband))

        disk_irf_mono = plseeden_irf*pow_disk_frac + disk_irf_mono
        disk_norm = norm*np.diff(np.array(disk_eband))*pow_disk_frac + np.sum(disk_irf_mono2)
        print('Disk band IRF PL frac: ',np.sum(plseeden_irf*pow_disk_frac)/np.sum(disk_irf_mono))
        print('Disk band total PL frac: ',norm*np.diff(np.array(disk_eband))*pow_disk_frac/disk_norm)

    freq, phlag, tlag, psd_ci, psd_ref, mod_sig_psd, irf_nbins, irf_binedgefrac, deltau_scale, dt, nirf,\
        ci_irf, ci_mean, ci_outer =\
    uml.calculate_stprod_mono_frange(nirf_mult,ens_mono,encomb,flux_irf_mono,disk_irf_mono,gamma_irf,
                              deltau,min_deltau_frac,i_rsigmax,lfreq,q,rms,t_scale,freq_range)
    if band_calc == True and psd_correct == True:
        psd_ref[0,:] = psd_ref[0,:]*(np.sum(disk_irf_mono)/disk_norm)**2
    if freq_in == None:
        return gamma_mean, freq, phlag, tlag, psd_ci, psd_ref, tau, i_rcor, i_rsigmax, rad, deltau,\
            ldisk_disp, lseed_disp,lheat, ldisk_rev, lseed_rev, flux_irf_mono, mod_sig_psd, disk_irf_mono, band_frac
    else:
        for i, freq_data in enumerate(freq_in):
            if (encomb_in[i] > 0):
                model_int = spint.interp1d(freq,tlag[encomb_in[i]-1,:])
            else:
#                if encomb_in[i] == -1:
#                    psdratio_norm = disksoft_psdnorm
#                else:
#                    psdratio_norm = softhard_psdnorm
                psdratio_norm = np.mean(psd_ref[abs(encomb_in[i])-1,freq<1]/psd_ci[abs(encomb_in[i])-1,freq<1])\
                            /np.mean(data_in[i][freq_data < 1])
                model_int = spint.interp1d(freq,psdratio_norm*psd_ref[abs(encomb_in[i])-1,:]/psd_ci[abs(encomb_in[i])-1,:])                
            if data_in == None:
                if i == 0:
                    y_output = model_int(freq_data)
                else:
                    y_output = np.append(y_output,model_int(freq_data))
            else:
                if i == 0:
                    y_output = (data_in[i] - model_int(freq_data))/error_in[i]
                else:
                    y_output = np.append(y_output,(data_in[i] - model_int(freq_data))/error_in[i])

        # print("Phil >0; Dani <0")
        # print(np.sum(y_output_phil**2), np.sum(y_output**2))
        # print(np.sum(y_output_phil**2)-np.sum(y_output**2))
        # print(params)

        # print(y_output_phil.shape)
        # # print(y_output)
        
        return y_output

# %%
print(2*mpmath.apery/(np.pi**4/15))

nE = 10000
kTvar = False
E_min = 0.0001
E_max = 100.0
for kT in [0.3,0.6,1.0,1.2]:
    print(lm.bb_phflux(E_min, E_max, kT, nE, kTvar))
#    print(bb_enflux(E_min, E_max, kT, nE, kTvar))
print("")
#kTvar = True
#for kT in [0.3,0.6,1.0,1.2]:
#    print(bb_phflux(E_min, E_max, kT, nE, kTvar))
#    print(bb_enflux(E_min, E_max, kT, nE, kTvar))
#print("")
kTvar = True
for kT in [0.3,0.6,1.0,1.2]:
    if kTvar == False:
        bb_phintnorm = 2*1.2020569031595942*15/np.pi**4
    else:
        bb_phintnorm = 1.5*1.2020569031595942*15/np.pi**4
    bb_int = lm.bb_phflux(E_min, E_max, 1.0, nE, kTvar)
    print(lm.bb_phflux(E_min, E_max, kT, nE, kTvar)/(bb_int/kT))
    print(lm.bb_phflux(E_min, E_max, kT, nE, kTvar)/(bb_phintnorm/kT))
# Out:
# 0.370208845108716
# 1.2340295533227577
# 0.6170147873537232
# 0.37020887378093764
# 0.3085073950134895
#
# 0.9999999929904122
# 1.0000000718256294
# 0.9999999987675414
# 1.000000077602759
# 1.0
# 1.000000078835218
# 1.0000000002118288
# 1.0000000790470467

# %%
from lmfit import Minimizer, Parameters, report_fit
params = Parameters()
params.add('rin', value = 2.96, min = 1.3, max = 6.0, vary = True)
params.add('rcor', value = 7.96, min = 6.0, max = 30.0, vary = True)
params.add('hcor', value = 10.23, min = 5.0, max = 100.0, vary = True)
params.add('cone_angle', value =30., min = 0.0, max = 60.0, vary = True)
params.add('seedff_norm', value = 0., min = 0.0, max = 0.5, vary = False)
params.add('thermal_frac', value = 1.44, min = 0.3, max = 3.0, vary = True)
#params.add('thermal_frac', value = 0.7, min = 0., max = 3.0, vary = True)
params.add('pow_disk_frac', value = 1.0, min = 0., max = 100.0, vary = False)
params.add('disk_en', value = 2.5, min = 1.5, max = 5.0, vary = True)
params.add('band_mult', value = 1.5, min = 1.001, max = 3.0, vary = False)
params.add('disk_tau_norm', value = 55.0, min = 10.0, max = 500.0, vary = True)
params.add('disk_tau_ind', value = 1.8, min = 0.0, max = 2.5, vary = False)
params.add('delay_tau_scale', value = 1.0, min = 0.2, max = 5.0, vary = False)
params.add('disp_ind', value = -3.0, min = -4.0, max = -2.0, vary = False)
params.add('disksoft_psdrat_norm', value = 1.0, min = 0.3, max = 3.0, vary = False)
params.add('softhard_psdrat_norm', value = 1.0, min = 0.3, max = 3.0, vary = False)

params.add('lor_q1', value = 1, min = 0.2, max = 5.0, vary = False)
params.add('lor_freq1', value = 0.03, min = 0.01, max = 0.5, vary = False)
params.add('lor_rms1', value = 0.1, min = 0., max = 0.5, vary = False)
params.add('lor_q2', value = 1, min = 0.2, max = 5.0, vary = False)
params.add('lor_freq2', value = 0.15, min = 0.5, max = 3.0, vary = False)
params.add('lor_rms2', value = 0.1, min = 0., max = 0.5, vary = False)
params.add('lor_q3', value = 1, min = 0.2, max = 5.0, vary = False)
params.add('lor_freq3', value = 1.5, min = 2.0, max = 10.0, vary = False)
params.add('lor_rms3', value = 0.1, min = 0., max = 0.5, vary = False)

#freq_in = [freq_data[freq_data < 20],freq_data[freq_data < 20],freq_data[freq_data < 20],
#           freq_data[freq_data < 20]]
#data_in = [disktlags_data[freq_data < 20],powtlags_data[freq_data < 20],
#           diskvssoft_psdratio[freq_data < 20],softvshard_psdratio[freq_data < 20]]
#err_in = [disktlags_err_data[freq_data < 20],powtlags_err_data[freq_data < 20],
#           diskvssoft_err_psdratio[freq_data < 20],softvshard_err_psdratio[freq_data < 20]]
#encomb_in = [1,2,-1,-2]

freq_in = [freq_data[freq_data < 10],freq_data[freq_data < 10]] #,freq_data[freq_data < 10]]
data_in = [disktlags_data[freq_data < 10],powtlags_data[freq_data < 10]]  #,diskvssoft_psdratio[freq_data < 10]]
err_in = [disktlags_err_data[freq_data < 10],powtlags_err_data[freq_data < 10]]  #,diskvssoft_err_psdratio[freq_data < 10]]

#freq_in = [freq_data[freq_data < 10],freq_data[(freq_data > 0.001) & (freq_data < 10)],
#           freq_data[freq_data < 10],freq_data[freq_data < 10]]
#data_in = [disktlags_data[freq_data < 10],powtlags_data[(freq_data > 0.001) & (freq_data < 10)],
#          diskvssoft_psdratio[freq_data < 10],softvshard_psdratio[freq_data < 10]]
#err_in = [disktlags_err_data[freq_data < 10],powtlags_err_data[(freq_data > 0.001) & (freq_data < 10)],
#          diskvssoft_err_psdratio[freq_data < 10],softvshard_err_psdratio[freq_data < 10]]
#encomb_in = [1,2,-1,-2]
encomb_in = [1,2]

# %%
# plot_params = params
# vlines_list = []
# laglist = []
# psdlist = []
# irflist = []
# bandflist = []
# ls_list = ['solid','dashed','dotted']
# t_scale=5e-5
# psdcor_list = [True,True]
# pdfrac_list = [1.,0.]
# #disk_en_list = [0.1,1.0]
# disk_en_list = [1.87,1.87]
# label_list = [r'soft PL vs. disk',r'hard PL vs. soft PL']

# for i, kTvar_val in enumerate([True,True]):
#     plot_params['pow_disk_frac'].value = pdfrac_list[i]
#     plot_params['disk_en'].min = 0.1*disk_en_list[i]
#     plot_params['disk_en'].value = disk_en_list[i]

#     gamma_mean, freq, phlag, tlag, psd_ci, psd_ref, tau, i_rcor, i_rsigmax, rad, deltau,\
#     ldisk_disp, lseed_disp,lheat, ldisk_rev, lseed_rev, flux_irf_mono, mod_sig_psd,\
#         disk_irf_mono, bandfrac = lagmodel(plot_params, None, None, None, encomb_in, rout=1000, nrad=100, nphi=100, nz=400, 
#             cor_geometry=geo.Inv_Cone, t_scale=5e-5, e_seed=1.0, ens_mono=np.array([1.,3.,9.]), 
#             gamma_par=[2.33,0.1], band_calc=True, encomb=np.array([[2,0],[3,2]]), nirf_mult=8, 
#             min_deltau_frac=1, freq_rsigmax=0.01, kTvar=kTvar_val, psd_correct=psdcor_list[i], 
#                                            lor_model='continuous')
#     # gamma_mean, freq, phlag, tlag, psd_ci, psd_ref, tau, i_rcor, i_rsigmax, rad, deltau,\
#     # ldisk_disp, lseed_disp,lheat, ldisk_rev, lseed_rev, flux_irf_mono, mod_sig_psd,\
#     #     disk_irf_mono, bandfrac = lagmodel(plot_params, None, None, None, encomb_in, rout=1000, nrad=100, nphi=100, nz=400, 
#     #     cor_geometry=uml.inv_cone, t_scale=5e-5, e_seed=1.0, ens_mono=np.array([1.,3.,9.]), 
#     #     gamma_par=[2.33,0.1], band_calc=True, encomb=np.array([[2,0],[3,2]]), nirf_mult=8, 
#     #     min_deltau_frac=1, freq_rsigmax=0.01, kTvar=kTvar_val, psd_correct=psdcor_list[i], 
#     #                                        lor_model='continuous')
#     print("Value",plot_params['disk_en'].value)
# #    bandflist.append(bandfrac*(ldisk_disp+lseed_disp))
#     bandflist.append(disk_irf_mono) 
#     for j in range(2):
#         if j == 0:
#             labtxt = kTvar_val
#             ydata = disktlags_data
#             ydata_err = disktlags_err_data
#         else:
#             labtxt = None
#             ydata = powtlags_data
#             ydata_err = powtlags_err_data
#         print(tlag[j,:])
#         laglist.append([np.copy(freq),np.real(1)*np.copy(tlag[j,:]),CBcol[i],ls_list[j],label_list[j],
#                         freq_data,ydata,ydata_err,None])
#         if j == 0:
#             ydata = diskvssoft_psdratio
#             ydata_err = diskvssoft_err_psdratio
#         else:
#             ydata = softvshard_psdratio
#             ydata_err = softvshard_err_psdratio
#         psdlist.append([np.copy(freq),psd_ref[j,:]/psd_ci[j,:],CBcol[i],ls_list[j],
#                         labtxt,freq_data,ydata,ydata_err,False])
#         irflist.append([[disk_irf_mono/np.sum(disk_irf_mono),lseed_disp+lseed_rev,lheat],rad,deltau,i_rcor,i_rsigmax,CBcol[i],'test'])

        
#     vlines_list.append([1./(tau[i_rcor]*t_scale),'gray','dashdot'])
# #        psdlist.append([np.copy(freq),freq*psd_ref[j,:],CBcol[i],ls_list[j],labtxt,freq_data,ydata,ydata_err])
# #vlines_list.append([1./(tau[i_rcor]*t_scale),'gray','dashdot'])

# freqlim = [0.007,100.0]
# freqlim_in = [0.5,20.0]
# tlaglim = [0.0001,1]
# tlaglim_in = [-0.018,0.01]
# psdlim = [0.1,10.5]
# inset_yticks = [-0.015,-0.01,-0.005,0,0.005]
# axis_names = ['Frequency (Hz)','Time lag (s)',r'$P/P_{\Sigma \; \dot{m}(r)}$']
# #figfile = 'figs/lagspsd_invcone_mono_hcorcompare.pdf'
# figfile = None
# #leg_title=r'$r_{\rm cor}=10$ $R_{g}$, $\theta_{\rm cor}=30^{\circ}$'
# leg_title = None
# #plot_data_lags_psds(laglist, psdlist, vlines_list, axis_names, freqlim, tlaglim, tlaglim_in, psdlim, 
# #               inset_yticks, leg_title, figfile) 

# inputs = [True,True]
# plot_data_lags(inputs, laglist, vlines_list, axis_names, freqlim, freqlim_in, tlaglim, tlaglim_in, inset_yticks, 
#                    leg_title, figfile)

# %%
class Parameter:
    def __init__ (self, string):
        vals = string.split(", ")
        self._name = vals[0][1:-1]
        if "fixed" in vals[2]:
            self._value = float(vals[2].split("=")[1].split(" (")[0])
        else:
            self._value = float(vals[2].split("=")[1])
        self._bounds = vals[3][:-1].split("=")[1].split(":")
        self._bounds[0] = self._bounds[0][1:]
        self._bounds[1] = self._bounds[1][:-1]
        try:
            assert len(self._bounds) == 2
        except:
            print(self._bounds)
            raise AssertionError("length of bounds was not 2")
        for i, bound in enumerate(self._bounds):
            self._bounds[i] = float(bound)

    @property
    def name(self):
        return self._name
    
    @property
    def value(self):
        return self._value
    
    @property
    def bounds(self):
        return self._bounds

    @property
    def bounds_size(self):
        return np.diff(self._bounds)[0]

    def __sub__(self, other):
        if self == other:
            return None
        if self._name != self._name:
            return AssertionError("not the same type of parameter")
        return self._value - other._value
    
    def __truediv__(self, other):
        if self == other:
            return None
        if self._name != self._name:
            return AssertionError("not the same type of parameter")
        return self._value/other._value
    
    def __repr__(self):
        return f"{self._name}: {self._value}"

# %%
# strings = ["Parameters([('rin', <Parameter 'rin', value=1.3241740287278592, bounds=[1.3:6.0]>), ('rcor', <Parameter 'rcor', value=29.851016902319355, bounds=[6.0:30.0]>), ('hcor', <Parameter 'hcor', value=10.052947819633538, bounds=[5.0:100.0]>), ('cone_angle', <Parameter 'cone_angle', value=23.056514157480105, bounds=[0.0:60.0]>), ('seedff_norm', <Parameter 'seedff_norm', value=0.0 (fixed), bounds=[0.0:0.5]>), ('thermal_frac', <Parameter 'thermal_frac', value=0.5892270928542189, bounds=[0.3:3.0]>), ('pow_disk_frac', <Parameter 'pow_disk_frac', value=0.0 (fixed), bounds=[0.0:100.0]>), ('disk_en', <Parameter 'disk_en', value=1.77419313691378, bounds=[0.18700000000000003:5.0]>), ('band_mult', <Parameter 'band_mult', value=1.5 (fixed), bounds=[1.001:3.0]>), ('disk_tau_norm', <Parameter 'disk_tau_norm', value=48.008775975606895, bounds=[10.0:500.0]>), ('disk_tau_ind', <Parameter 'disk_tau_ind', value=1.8 (fixed), bounds=[0.0:2.5]>), ('delay_tau_scale', <Parameter 'delay_tau_scale', value=1.0 (fixed), bounds=[0.2:5.0]>), ('disp_ind', <Parameter 'disp_ind', value=-3.0 (fixed), bounds=[-4.0:-2.0]>), ('disksoft_psdrat_norm', <Parameter 'disksoft_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('softhard_psdrat_norm', <Parameter 'softhard_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('lor_q1', <Parameter 'lor_q1', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq1', <Parameter 'lor_freq1', value=0.03 (fixed), bounds=[0.01:0.5]>), ('lor_rms1', <Parameter 'lor_rms1', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q2', <Parameter 'lor_q2', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq2', <Parameter 'lor_freq2', value=0.5 (fixed), bounds=[0.5:3.0]>), ('lor_rms2', <Parameter 'lor_rms2', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q3', <Parameter 'lor_q3', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq3', <Parameter 'lor_freq3', value=2.0 (fixed), bounds=[2.0:10.0]>), ('lor_rms3', <Parameter 'lor_rms3', value=0.1 (fixed), bounds=[0.0:0.5]>)])",
# "Parameters([('rin', <Parameter 'rin', value=5.726474188310239, bounds=[1.3:6.0]>), ('rcor', <Parameter 'rcor', value=19.46862929360856, bounds=[6.0:30.0]>), ('hcor', <Parameter 'hcor', value=41.94110537838871, bounds=[5.0:100.0]>), ('cone_angle', <Parameter 'cone_angle', value=23.08956439739968, bounds=[0.0:60.0]>), ('seedff_norm', <Parameter 'seedff_norm', value=0.0 (fixed), bounds=[0.0:0.5]>), ('thermal_frac', <Parameter 'thermal_frac', value=0.5900253114374633, bounds=[0.3:3.0]>), ('pow_disk_frac', <Parameter 'pow_disk_frac', value=0.0 (fixed), bounds=[0.0:100.0]>), ('disk_en', <Parameter 'disk_en', value=1.7738201457885514, bounds=[0.18700000000000003:5.0]>), ('band_mult', <Parameter 'band_mult', value=1.5 (fixed), bounds=[1.001:3.0]>), ('disk_tau_norm', <Parameter 'disk_tau_norm', value=13.821752307376887, bounds=[10.0:500.0]>), ('disk_tau_ind', <Parameter 'disk_tau_ind', value=1.8 (fixed), bounds=[0.0:2.5]>), ('delay_tau_scale', <Parameter 'delay_tau_scale', value=1.0 (fixed), bounds=[0.2:5.0]>), ('disp_ind', <Parameter 'disp_ind', value=-3.0 (fixed), bounds=[-4.0:-2.0]>), ('disksoft_psdrat_norm', <Parameter 'disksoft_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('softhard_psdrat_norm', <Parameter 'softhard_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('lor_q1', <Parameter 'lor_q1', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq1', <Parameter 'lor_freq1', value=0.03 (fixed), bounds=[0.01:0.5]>), ('lor_rms1', <Parameter 'lor_rms1', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q2', <Parameter 'lor_q2', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq2', <Parameter 'lor_freq2', value=0.5 (fixed), bounds=[0.5:3.0]>), ('lor_rms2', <Parameter 'lor_rms2', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q3', <Parameter 'lor_q3', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq3', <Parameter 'lor_freq3', value=2.0 (fixed), bounds=[2.0:10.0]>), ('lor_rms3', <Parameter 'lor_rms3', value=0.1 (fixed), bounds=[0.0:0.5]>)])",
# "Parameters([('rin', <Parameter 'rin', value=2.8216709170924568, bounds=[1.3:6.0]>), ('rcor', <Parameter 'rcor', value=14.489637067927765, bounds=[6.0:30.0]>), ('hcor', <Parameter 'hcor', value=9.350418174289853, bounds=[5.0:100.0]>), ('cone_angle', <Parameter 'cone_angle', value=10.471598118468476, bounds=[0.0:60.0]>), ('seedff_norm', <Parameter 'seedff_norm', value=0.0 (fixed), bounds=[0.0:0.5]>), ('thermal_frac', <Parameter 'thermal_frac', value=0.35251961935517695, bounds=[0.3:3.0]>), ('pow_disk_frac', <Parameter 'pow_disk_frac', value=0.0 (fixed), bounds=[0.0:100.0]>), ('disk_en', <Parameter 'disk_en', value=1.7390039913986786, bounds=[0.18700000000000003:5.0]>), ('band_mult', <Parameter 'band_mult', value=1.5 (fixed), bounds=[1.001:3.0]>), ('disk_tau_norm', <Parameter 'disk_tau_norm', value=97.68991279381076, bounds=[10.0:500.0]>), ('disk_tau_ind', <Parameter 'disk_tau_ind', value=1.8 (fixed), bounds=[0.0:2.5]>), ('delay_tau_scale', <Parameter 'delay_tau_scale', value=1.0 (fixed), bounds=[0.2:5.0]>), ('disp_ind', <Parameter 'disp_ind', value=-3.0 (fixed), bounds=[-4.0:-2.0]>), ('disksoft_psdrat_norm', <Parameter 'disksoft_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('softhard_psdrat_norm', <Parameter 'softhard_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('lor_q1', <Parameter 'lor_q1', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq1', <Parameter 'lor_freq1', value=0.03 (fixed), bounds=[0.01:0.5]>), ('lor_rms1', <Parameter 'lor_rms1', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q2', <Parameter 'lor_q2', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq2', <Parameter 'lor_freq2', value=0.5 (fixed), bounds=[0.5:3.0]>), ('lor_rms2', <Parameter 'lor_rms2', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q3', <Parameter 'lor_q3', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq3', <Parameter 'lor_freq3', value=2.0 (fixed), bounds=[2.0:10.0]>), ('lor_rms3', <Parameter 'lor_rms3', value=0.1 (fixed), bounds=[0.0:0.5]>)])"]

# for string in strings:
#     parm_list = []
#     parms = string.split("), (")
#     parms[0] = parms[0][13:]
#     parms[-1] = parms[-1][:-4]

#     for i, parm in enumerate(parms):
#         parm = Parameter(parm)
#         parm_list.append(parm)

#     assert len(parm_list) == len(params)

#     for parm in parm_list:
#         params[parm.name].set(parm.value)
#         # print(parm)

#     a = lagmodel(params, freq_in, data_in, err_in, encomb_in, nz=1000, nphi=1000)

# %%
set_function = Minimizer(lagmodel_original, params, fcn_args=(freq_in, data_in, err_in, encomb_in), fcn_kws={"nphi": 1000, "nz": 200}, nan_policy='omit', burn=2, steps=10, thin=1, is_weighted=False)
result = set_function.minimize(method = "emcee")
report_fit(result)
# 300 1000 20
# Out:
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71839315451066 Rg
# Disk band IRF PL frac:  0.20255206852874952
# Disk band total PL frac:  [0.23227333]
# #######################################
# Time bin size dt is:  0.0021400468771489885
# The maximum propagation delay is:  32.29628819661545  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72609288985323 Rg
# Disk band IRF PL frac:  0.20261098759025067
# Disk band total PL frac:  [0.23234053]
# #######################################
# Time bin size dt is:  0.002140525135002522
# The maximum propagation delay is:  32.301790035044384  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72470292866565 Rg
# Disk band IRF PL frac:  0.20257671472708255
# Disk band total PL frac:  [0.23229977]
# #######################################
# Time bin size dt is:  0.0021404700671542355
# The maximum propagation delay is:  32.29729475562645  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71236539986869 Rg
# Disk band IRF PL frac:  0.20249951409585007
# Disk band total PL frac:  [0.2322141]
# #######################################
# Time bin size dt is:  0.002140140346922343
# The maximum propagation delay is:  32.290751208943696  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71699009141275 Rg
# Disk band IRF PL frac:  0.20256313053325295
# Disk band total PL frac:  [0.23228505]
# #######################################
# Time bin size dt is:  0.0021405429409975855
# The maximum propagation delay is:  32.29401354695808  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71834850159955 Rg
# Disk band IRF PL frac:  0.2026255861472863
# Disk band total PL frac:  [0.23235021]
# #######################################
# Time bin size dt is:  0.0021401282957405512
# The maximum propagation delay is:  32.3010904921389  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71862825190784 Rg
# Disk band IRF PL frac:  0.20253682146074398
# Disk band total PL frac:  [0.23225813]
# #######################################
# Time bin size dt is:  0.0021403916475211658
# The maximum propagation delay is:  32.2954170577258  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71601564111936 Rg
# Disk band IRF PL frac:  0.20259053580711517
# Disk band total PL frac:  [0.23231388]
# #######################################
# Time bin size dt is:  0.0021398216950685852
# The maximum propagation delay is:  32.29772432200933  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72079532112859 Rg
# Disk band IRF PL frac:  0.2025576576981293
# Disk band total PL frac:  [0.2322809]
# #######################################
# Time bin size dt is:  0.0021400140378824493
# The maximum propagation delay is:  32.29986280254239  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71668067262114 Rg
# Disk band IRF PL frac:  0.20254875090032046
# Disk band total PL frac:  [0.23227075]
# #######################################
# Time bin size dt is:  0.00214011217435103
# The maximum propagation delay is:  32.29903663899195  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71394433761436 Rg
# Disk band IRF PL frac:  0.202568923121193
# Disk band total PL frac:  [0.23228923]
# #######################################
# Time bin size dt is:  0.002139932436366709
# The maximum propagation delay is:  32.295701968409865  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71807958647383 Rg
# Disk band IRF PL frac:  0.20256089561749432
# Disk band total PL frac:  [0.23228442]
# #######################################
# Time bin size dt is:  0.0021402079591850906
# The maximum propagation delay is:  32.298053275431876  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.7194019087818 Rg
# Disk band IRF PL frac:  0.20257839097797958
# Disk band total PL frac:  [0.23230327]
# #######################################
# Time bin size dt is:  0.0021399978804739
# The maximum propagation delay is:  32.298505944660945  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71811387792513 Rg
# Disk band IRF PL frac:  0.20250486712816804
# Disk band total PL frac:  [0.23221767]
# #######################################
# Time bin size dt is:  0.002139739548220974
# The maximum propagation delay is:  32.290925687580184  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72148108085905 Rg
# Disk band IRF PL frac:  0.20255331623114192
# Disk band total PL frac:  [0.23227695]
# #######################################
# Time bin size dt is:  0.0021399166143778767
# The maximum propagation delay is:  32.301211464900035  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71205013595639 Rg
# Disk band IRF PL frac:  0.2025438333199036
# Disk band total PL frac:  [0.23226492]
# #######################################
# Time bin size dt is:  0.0021401547148753282
# The maximum propagation delay is:  32.2944005552021  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72217389735316 Rg
# Disk band IRF PL frac:  0.20259242710596007
# Disk band total PL frac:  [0.23231628]
# #######################################
# Time bin size dt is:  0.0021401960673797372
# The maximum propagation delay is:  32.30031243442967  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72482573376024 Rg
# Disk band IRF PL frac:  0.20263989825374285
# Disk band total PL frac:  [0.23237279]
# #######################################
# Time bin size dt is:  0.0021398827428528605
# The maximum propagation delay is:  32.308245583722595  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.715788711893 Rg
# Disk band IRF PL frac:  0.20255349137811898
# Disk band total PL frac:  [0.23228144]
# #######################################
# Time bin size dt is:  0.0021403262046865213
# The maximum propagation delay is:  32.29814716182285  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71916298557743 Rg
# Disk band IRF PL frac:  0.20251694473192589
# Disk band total PL frac:  [0.23223315]
# #######################################
# Time bin size dt is:  0.002139967224918462
# The maximum propagation delay is:  32.29398247801466  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71519570825494 Rg
# Disk band IRF PL frac:  0.20245859426729781
# Disk band total PL frac:  [0.23217025]
# #######################################
# Time bin size dt is:  0.0021399050949982164
# The maximum propagation delay is:  32.28637286733476  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.7224910725093 Rg
# Disk band IRF PL frac:  0.20250724960827218
# Disk band total PL frac:  [0.23223001]
# #######################################
# Time bin size dt is:  0.002140022002501452
# The maximum propagation delay is:  32.300804071863006  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71887171671976 Rg
# Disk band IRF PL frac:  0.20252743018415076
# Disk band total PL frac:  [0.23224594]
# #######################################
# Time bin size dt is:  0.0021403395004008056
# The maximum propagation delay is:  32.291061336387436  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71399108359691 Rg
# Disk band IRF PL frac:  0.2025069253086658
# Disk band total PL frac:  [0.23222401]
# #######################################
# Time bin size dt is:  0.0021401061896699587
# The maximum propagation delay is:  32.29097393095159  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71577801371757 Rg
# Disk band IRF PL frac:  0.2025514225972453
# Disk band total PL frac:  [0.23227019]
# #######################################
# Time bin size dt is:  0.002140293993890639
# The maximum propagation delay is:  32.293059486649724  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71060279883928 Rg
# Disk band IRF PL frac:  0.202515039225955
# Disk band total PL frac:  [0.23223269]
# #######################################
# Time bin size dt is:  0.0021402510765055663
# The maximum propagation delay is:  32.29112833580554  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71774356654377 Rg
# Disk band IRF PL frac:  0.20261620308982892
# Disk band total PL frac:  [0.23234684]
# #######################################
# Time bin size dt is:  0.0021399884580589187
# The maximum propagation delay is:  32.30557479121355  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.70990144947332 Rg
# Disk band IRF PL frac:  0.20256535525237182
# Disk band total PL frac:  [0.23228712]
# #######################################
# Time bin size dt is:  0.002140408587395213
# The maximum propagation delay is:  32.29668685063462  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71648525514262 Rg
# Disk band IRF PL frac:  0.2025613132647953
# Disk band total PL frac:  [0.23228238]
# #######################################
# Time bin size dt is:  0.0021399887814139
# The maximum propagation delay is:  32.2955025759914  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72597781676532 Rg
# Disk band IRF PL frac:  0.2025996106483856
# Disk band total PL frac:  [0.2323243]
# #######################################
# Time bin size dt is:  0.0021402203237538917
# The maximum propagation delay is:  32.305545081465  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72540215767103 Rg
# Disk band IRF PL frac:  0.20259631665641925
# Disk band total PL frac:  [0.23232567]
# #######################################
# Time bin size dt is:  0.0021397723069806343
# The maximum propagation delay is:  32.303207705286766  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71952161296 Rg
# Disk band IRF PL frac:  0.20256797796982653
# Disk band total PL frac:  [0.23229178]
# #######################################
# Time bin size dt is:  0.002139519834689391
# The maximum propagation delay is:  32.301644192301744  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.7073788768865 Rg
# Disk band IRF PL frac:  0.2025101366316413
# Disk band total PL frac:  [0.2322278]
# #######################################
# Time bin size dt is:  0.002140461806066902
# The maximum propagation delay is:  32.293859961050984  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.7157594401112 Rg
# Disk band IRF PL frac:  0.2025080651340686
# Disk band total PL frac:  [0.23221991]
# #######################################
# Time bin size dt is:  0.0021397512158029246
# The maximum propagation delay is:  32.28936192634124  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71636563321982 Rg
# Disk band IRF PL frac:  0.20250866536885753
# Disk band total PL frac:  [0.23222843]
# #######################################
# Time bin size dt is:  0.0021402596763883098
# The maximum propagation delay is:  32.299051415916104  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71795952576208 Rg
# Disk band IRF PL frac:  0.20254367742539167
# Disk band total PL frac:  [0.23225829]
# #######################################
# Time bin size dt is:  0.0021404597059215113
# The maximum propagation delay is:  32.2924832587335  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71959604943315 Rg
# Disk band IRF PL frac:  0.20255390954661165
# Disk band total PL frac:  [0.23227384]
# #######################################
# Time bin size dt is:  0.0021399628254367012
# The maximum propagation delay is:  32.296743545595405  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.7254826943862 Rg
# Disk band IRF PL frac:  0.2026059325564357
# Disk band total PL frac:  [0.23233308]
# #######################################
# Time bin size dt is:  0.002140415325158512
# The maximum propagation delay is:  32.30477067562279  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71504773939068 Rg
# Disk band IRF PL frac:  0.20256412856729186
# Disk band total PL frac:  [0.2322892]
# #######################################
# Time bin size dt is:  0.0021404375848357664
# The maximum propagation delay is:  32.30041920932606  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72101258623927 Rg
# Disk band IRF PL frac:  0.20265757501486412
# Disk band total PL frac:  [0.23238771]
# #######################################
# Time bin size dt is:  0.0021397826233305957
# The maximum propagation delay is:  32.31074834707639  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72145158495927 Rg
# Disk band IRF PL frac:  0.20255826300678553
# Disk band total PL frac:  [0.23228014]
# #######################################
# Time bin size dt is:  0.0021397912063921385
# The maximum propagation delay is:  32.295511591785214  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72912750360128 Rg
# Disk band IRF PL frac:  0.20253036545312653
# Disk band total PL frac:  [0.23225238]
# #######################################
# Time bin size dt is:  0.0021401792921301797
# The maximum propagation delay is:  32.29524710645923  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.7195510398364 Rg
# Disk band IRF PL frac:  0.2025747482735999
# Disk band total PL frac:  [0.23229468]
# #######################################
# Time bin size dt is:  0.002139965872209085
# The maximum propagation delay is:  32.29710373059381  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72157992132291 Rg
# Disk band IRF PL frac:  0.202561398929896
# Disk band total PL frac:  [0.23228494]
# #######################################
# Time bin size dt is:  0.0021400153332025787
# The maximum propagation delay is:  32.30168583827896  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71929564251538 Rg
# Disk band IRF PL frac:  0.20256237515030798
# Disk band total PL frac:  [0.23228534]
# #######################################
# Time bin size dt is:  0.0021401402469729933
# The maximum propagation delay is:  32.296435490295565  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.7165805332648 Rg
# Disk band IRF PL frac:  0.20252923115759547
# Disk band total PL frac:  [0.23224458]
# #######################################
# Time bin size dt is:  0.002140082243675474
# The maximum propagation delay is:  32.293974131993316  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72427067236688 Rg
# Disk band IRF PL frac:  0.2025978414841717
# Disk band total PL frac:  [0.2323243]
# #######################################
# Time bin size dt is:  0.002140183464701575
# The maximum propagation delay is:  32.30502546023831  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72096105913975 Rg
# Disk band IRF PL frac:  0.20257972923601267
# Disk band total PL frac:  [0.23230225]
# #######################################
# Time bin size dt is:  0.002140072280165293
# The maximum propagation delay is:  32.30171722000809  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71145412569594 Rg
# Disk band IRF PL frac:  0.20251203045882069
# Disk band total PL frac:  [0.23222518]
# #######################################
# Time bin size dt is:  0.0021399113507414736
# The maximum propagation delay is:  32.287727500884  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71761299075631 Rg
# Disk band IRF PL frac:  0.20253124486238838
# Disk band total PL frac:  [0.23224656]
# #######################################
# Time bin size dt is:  0.002139791933039416
# The maximum propagation delay is:  32.289504524149464  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71814443845844 Rg
# Disk band IRF PL frac:  0.2025643019910792
# Disk band total PL frac:  [0.23229177]
# #######################################
# Time bin size dt is:  0.0021401994986046885
# The maximum propagation delay is:  32.30341892850136  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72198967379171 Rg
# Disk band IRF PL frac:  0.2025950566585108
# Disk band total PL frac:  [0.23232227]
# #######################################
# Time bin size dt is:  0.002140316722025071
# The maximum propagation delay is:  32.30124931376328  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72441517087356 Rg
# Disk band IRF PL frac:  0.2025898657444646
# Disk band total PL frac:  [0.23231638]
# #######################################
# Time bin size dt is:  0.0021402010686650303
# The maximum propagation delay is:  32.299294111408244  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.7159755113565 Rg
# Disk band IRF PL frac:  0.20248933981845962
# Disk band total PL frac:  [0.23220754]
# #######################################
# Time bin size dt is:  0.00213998085399528
# The maximum propagation delay is:  32.288475955612974  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72443817124622 Rg
# Disk band IRF PL frac:  0.20264004746208095
# Disk band total PL frac:  [0.23236877]
# #######################################
# Time bin size dt is:  0.0021400829568988104
# The maximum propagation delay is:  32.30812889594979  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72677406048822 Rg
# Disk band IRF PL frac:  0.2025762095247377
# Disk band total PL frac:  [0.2322949]
# #######################################
# Time bin size dt is:  0.002140207389519244
# The maximum propagation delay is:  32.2966878008359  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72073538015947 Rg
# Disk band IRF PL frac:  0.20250808439256499
# Disk band total PL frac:  [0.23222736]
# #######################################
# Time bin size dt is:  0.002139763309307958
# The maximum propagation delay is:  32.297014222915024  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71356661706768 Rg
# Disk band IRF PL frac:  0.20246841731817325
# Disk band total PL frac:  [0.23218608]
# #######################################
# Time bin size dt is:  0.0021405401315170705
# The maximum propagation delay is:  32.28678074383303  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.7045668851977 Rg
# Disk band IRF PL frac:  0.2024931938583439
# Disk band total PL frac:  [0.23220097]
# #######################################
# Time bin size dt is:  0.0021399296027105634
# The maximum propagation delay is:  32.27875531638996  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72135639591639 Rg
# Disk band IRF PL frac:  0.20259417917971853
# Disk band total PL frac:  [0.23231807]
# #######################################
# Time bin size dt is:  0.0021400881324608973
# The maximum propagation delay is:  32.30278509218751  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71902789107251 Rg
# Disk band IRF PL frac:  0.20255724080451903
# Disk band total PL frac:  [0.2322759]
# #######################################
# Time bin size dt is:  0.002140192037841893
# The maximum propagation delay is:  32.29517763690939  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71798954634646 Rg
# Disk band IRF PL frac:  0.20254816246989446
# Disk band total PL frac:  [0.23226348]
# #######################################
# Time bin size dt is:  0.0021398263361119443
# The maximum propagation delay is:  32.29157997867971  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72216498582215 Rg
# Disk band IRF PL frac:  0.202581735018225
# Disk band total PL frac:  [0.2323056]
# #######################################
# Time bin size dt is:  0.0021401621747743436
# The maximum propagation delay is:  32.2969869690377  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71294984170251 Rg
# Disk band IRF PL frac:  0.2025731386898567
# Disk band total PL frac:  [0.23229781]
# #######################################
# Time bin size dt is:  0.0021402012323616954
# The maximum propagation delay is:  32.29898185410974  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72096042201707 Rg
# Disk band IRF PL frac:  0.2025467816930415
# Disk band total PL frac:  [0.23226725]
# #######################################
# Time bin size dt is:  0.0021399672988340317
# The maximum propagation delay is:  32.29286103349151  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72021045084675 Rg
# Disk band IRF PL frac:  0.20259074540132924
# Disk band total PL frac:  [0.23231502]
# #######################################
# Time bin size dt is:  0.002140169466967783
# The maximum propagation delay is:  32.29749473345611  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71991650947477 Rg
# Disk band IRF PL frac:  0.20258411789565095
# Disk band total PL frac:  [0.23231267]
# #######################################
# Time bin size dt is:  0.0021402588053302854
# The maximum propagation delay is:  32.30027614447401  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71947269397215 Rg
# Disk band IRF PL frac:  0.20250421997978296
# Disk band total PL frac:  [0.23221705]
# #######################################
# Time bin size dt is:  0.0021404657886249135
# The maximum propagation delay is:  32.289149367714806  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.7221013355797 Rg
# Disk band IRF PL frac:  0.20257902408675887
# Disk band total PL frac:  [0.23230428]
# #######################################
# Time bin size dt is:  0.002140605557313628
# The maximum propagation delay is:  32.29821422575657  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72495834596101 Rg
# Disk band IRF PL frac:  0.20254593067233823
# Disk band total PL frac:  [0.23226916]
# #######################################
# Time bin size dt is:  0.0021397138122939414
# The maximum propagation delay is:  32.29306732279612  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72020181231349 Rg
# Disk band IRF PL frac:  0.20257092998491547
# Disk band total PL frac:  [0.23229709]
# #######################################
# Time bin size dt is:  0.002140139035660173
# The maximum propagation delay is:  32.29685218442412  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72006476242375 Rg
# Disk band IRF PL frac:  0.20255430706420863
# Disk band total PL frac:  [0.23227398]
# #######################################
# Time bin size dt is:  0.0021398995410545833
# The maximum propagation delay is:  32.29766028988797  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72216077161943 Rg
# Disk band IRF PL frac:  0.20255106784642732
# Disk band total PL frac:  [0.23227234]
# #######################################
# Time bin size dt is:  0.0021403407941755622
# The maximum propagation delay is:  32.30001484486424  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.7258959415019 Rg
# Disk band IRF PL frac:  0.20261912976237512
# Disk band total PL frac:  [0.23235061]
# #######################################
# Time bin size dt is:  0.002139698845632772
# The maximum propagation delay is:  32.30921380032244  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71802432302235 Rg
# Disk band IRF PL frac:  0.20257920412991043
# Disk band total PL frac:  [0.23230042]
# #######################################
# Time bin size dt is:  0.0021400471485732314
# The maximum propagation delay is:  32.29636305820218  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71952441409219 Rg
# Disk band IRF PL frac:  0.2024743267974824
# Disk band total PL frac:  [0.23219149]
# #######################################
# Time bin size dt is:  0.0021400263005619063
# The maximum propagation delay is:  32.29008467064488  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.7176855727394 Rg
# Disk band IRF PL frac:  0.20256517247854494
# Disk band total PL frac:  [0.23229272]
# #######################################
# Time bin size dt is:  0.0021402162539367717
# The maximum propagation delay is:  32.301423211148496  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71862063376007 Rg
# Disk band IRF PL frac:  0.20256948336290226
# Disk band total PL frac:  [0.23229263]
# #######################################
# Time bin size dt is:  0.002140123913605707
# The maximum propagation delay is:  32.294666271686076  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72872698414683 Rg
# Disk band IRF PL frac:  0.20254230594082845
# Disk band total PL frac:  [0.23226534]
# #######################################
# Time bin size dt is:  0.0021403803122052494
# The maximum propagation delay is:  32.29729902084886  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.7232222323545 Rg
# Disk band IRF PL frac:  0.20251310367450878
# Disk band total PL frac:  [0.23223222]
# #######################################
# Time bin size dt is:  0.0021397838253230097
# The maximum propagation delay is:  32.29638835836225  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72067163785832 Rg
# Disk band IRF PL frac:  0.2026079054865763
# Disk band total PL frac:  [0.23233526]
# #######################################
# Time bin size dt is:  0.0021398541317218674
# The maximum propagation delay is:  32.30349290895841  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.7249240236974 Rg
# Disk band IRF PL frac:  0.20256895062767968
# Disk band total PL frac:  [0.23228935]
# #######################################
# Time bin size dt is:  0.002139921400061345
# The maximum propagation delay is:  32.29737927282023  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71619512663851 Rg
# Disk band IRF PL frac:  0.20253942925995588
# Disk band total PL frac:  [0.23225628]
# #######################################
# Time bin size dt is:  0.0021397370818182744
# The maximum propagation delay is:  32.294907407806356  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72136533792063 Rg
# Disk band IRF PL frac:  0.20259508698765322
# Disk band total PL frac:  [0.23231875]
# #######################################
# Time bin size dt is:  0.0021393640673435855
# The maximum propagation delay is:  32.2954713036313  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72411394790396 Rg
# Disk band IRF PL frac:  0.20255746634585028
# Disk band total PL frac:  [0.23228184]
# #######################################
# Time bin size dt is:  0.00214026768610327
# The maximum propagation delay is:  32.298061198585884  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71843083908576 Rg
# Disk band IRF PL frac:  0.2025919508541108
# Disk band total PL frac:  [0.23231896]
# #######################################
# Time bin size dt is:  0.002139968066856077
# The maximum propagation delay is:  32.30205351822529  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71514128797655 Rg
# Disk band IRF PL frac:  0.20255141537086413
# Disk band total PL frac:  [0.23227153]
# #######################################
# Time bin size dt is:  0.002139921564742079
# The maximum propagation delay is:  32.29226011210703  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71735065143126 Rg
# Disk band IRF PL frac:  0.20257520044559602
# Disk band total PL frac:  [0.23230244]
# #######################################
# Time bin size dt is:  0.0021397122929193643
# The maximum propagation delay is:  32.295579555434216  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71687658992629 Rg
# Disk band IRF PL frac:  0.20262073294768213
# Disk band total PL frac:  [0.23235014]
# #######################################
# Time bin size dt is:  0.002139789339347987
# The maximum propagation delay is:  32.30364793447328  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71734824143229 Rg
# Disk band IRF PL frac:  0.2025558838354272
# Disk band total PL frac:  [0.23227416]
# #######################################
# Time bin size dt is:  0.0021399160494938382
# The maximum propagation delay is:  32.29646467492725  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72021613653061 Rg
# Disk band IRF PL frac:  0.20254266559106207
# Disk band total PL frac:  [0.23227055]
# #######################################
# Time bin size dt is:  0.002140386694788902
# The maximum propagation delay is:  32.30087547057786  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71198309513007 Rg
# Disk band IRF PL frac:  0.20255118221750237
# Disk band total PL frac:  [0.23226928]
# #######################################
# Time bin size dt is:  0.0021403755569806182
# The maximum propagation delay is:  32.288682957585415  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71705640409397 Rg
# Disk band IRF PL frac:  0.20257909518757752
# Disk band total PL frac:  [0.23230594]
# #######################################
# Time bin size dt is:  0.0021399966302267123
# The maximum propagation delay is:  32.29540502054317  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71970281234393 Rg
# Disk band IRF PL frac:  0.20255968682991793
# Disk band total PL frac:  [0.23228779]
# #######################################
# Time bin size dt is:  0.0021401638370939784
# The maximum propagation delay is:  32.30374743227255  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.7213749925059 Rg
# Disk band IRF PL frac:  0.2025500620974096
# Disk band total PL frac:  [0.23227156]
# #######################################
# Time bin size dt is:  0.0021401260089315595
# The maximum propagation delay is:  32.29815045833961  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71673649853456 Rg
# Disk band IRF PL frac:  0.20255953442128846
# Disk band total PL frac:  [0.23228137]
# #######################################
# Time bin size dt is:  0.002140358574192463
# The maximum propagation delay is:  32.29715824098622  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71624998555252 Rg
# Disk band IRF PL frac:  0.20252133971169606
# Disk band total PL frac:  [0.23223852]
# #######################################
# Time bin size dt is:  0.002139582901715873
# The maximum propagation delay is:  32.29423091920975  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71267887468204 Rg
# Disk band IRF PL frac:  0.2024896189348713
# Disk band total PL frac:  [0.23220462]
# #######################################
# Time bin size dt is:  0.002140276915926802
# The maximum propagation delay is:  32.29100719906323  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71942245432498 Rg
# Disk band IRF PL frac:  0.2025880437024129
# Disk band total PL frac:  [0.23231084]
# #######################################
# Time bin size dt is:  0.0021398657467530434
# The maximum propagation delay is:  32.299476892425595  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72152484865191 Rg
# Disk band IRF PL frac:  0.20249621576396878
# Disk band total PL frac:  [0.23221531]
# #######################################
# Time bin size dt is:  0.0021400447411864896
# The maximum propagation delay is:  32.29416605594375  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71497561749878 Rg
# Disk band IRF PL frac:  0.20259495637999078
# Disk band total PL frac:  [0.23232049]
# #######################################
# Time bin size dt is:  0.0021398380225729706
# The maximum propagation delay is:  32.3025435644157  and there are  524288  irf bins.
#   0%|          | 0/10 [00:00<?, ?it/s]
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.73302956483991 Rg
# Disk band IRF PL frac:  0.20264468575840291
# Disk band total PL frac:  [0.23237102]
# #######################################
# Time bin size dt is:  0.002140680100129465
# The maximum propagation delay is:  32.29554098940549  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71147815430909 Rg
# Disk band IRF PL frac:  0.20247814592678434
# Disk band total PL frac:  [0.23218927]
# #######################################
# Time bin size dt is:  0.002140042032301884
# The maximum propagation delay is:  32.287553940815705  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71954527547581 Rg
# Disk band IRF PL frac:  0.20254487528687376
# Disk band total PL frac:  [0.23226727]
# #######################################
# Time bin size dt is:  0.0021403077928168765
# The maximum propagation delay is:  32.296471676935134  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72306366690769 Rg
# Disk band IRF PL frac:  0.20256533133387092
# Disk band total PL frac:  [0.23229498]
# #######################################
# Time bin size dt is:  0.0021401657887974495
# The maximum propagation delay is:  32.30656081044704  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72138433205062 Rg
# Disk band IRF PL frac:  0.2024807854676172
# Disk band total PL frac:  [0.23219002]
# #######################################
# Time bin size dt is:  0.0021394732025135565
# The maximum propagation delay is:  32.28863237256169  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72507297556224 Rg
# Disk band IRF PL frac:  0.20259331850284984
# Disk band total PL frac:  [0.2323174]
# #######################################
# Time bin size dt is:  0.0021403723245855036
# The maximum propagation delay is:  32.30153077638113  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72448384258665 Rg
# Disk band IRF PL frac:  0.2026292181671384
# Disk band total PL frac:  [0.23236109]
# #######################################
# Time bin size dt is:  0.002139892005790625
# The maximum propagation delay is:  32.30707394502475  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71659675512436 Rg
# Disk band IRF PL frac:  0.20255153875155907
# Disk band total PL frac:  [0.23227485]
# #######################################
# Time bin size dt is:  0.0021401426426039425
# The maximum propagation delay is:  32.29573548591187  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71488780924336 Rg
# Disk band IRF PL frac:  0.20242890568861535
# Disk band total PL frac:  [0.23213731]
# #######################################
# Time bin size dt is:  0.002139926279725525
# The maximum propagation delay is:  32.283209855935894  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.7229087527327 Rg
# Disk band IRF PL frac:  0.20249196143051473
# Disk band total PL frac:  [0.23221444]
# #######################################
# Time bin size dt is:  0.0021399949959323154
# The maximum propagation delay is:  32.30141018428406  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72532843614916 Rg
# Disk band IRF PL frac:  0.20250517088874437
# Disk band total PL frac:  [0.23222406]
# #######################################
# Time bin size dt is:  0.0021403056741461503
# The maximum propagation delay is:  32.293290129685516  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71504233405034 Rg
# Disk band IRF PL frac:  0.2025159804795649
# Disk band total PL frac:  [0.23223236]
# #######################################
# Time bin size dt is:  0.0021400964687084186
# The maximum propagation delay is:  32.29219191570108  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72388428422131 Rg
# Disk band IRF PL frac:  0.20258048261862915
# Disk band total PL frac:  [0.23230387]
# #######################################
# Time bin size dt is:  0.0021400218321088334
# The maximum propagation delay is:  32.30090390415951  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71952015662168 Rg
# Disk band IRF PL frac:  0.20256792984199593
# Disk band total PL frac:  [0.23229173]
# #######################################
# Time bin size dt is:  0.002139518461243041
# The maximum propagation delay is:  32.30165296781671  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71717390030092 Rg
# Disk band IRF PL frac:  0.20247531476443392
# Disk band total PL frac:  [0.23218071]
# #######################################
# Time bin size dt is:  0.002139524739196773
# The maximum propagation delay is:  32.28452195553275  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71798151154614 Rg
# Disk band IRF PL frac:  0.20254318907182353
# Disk band total PL frac:  [0.23225783]
# #######################################
# Time bin size dt is:  0.0021404507069171194
# The maximum propagation delay is:  32.292510648711925  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72580464236226 Rg
# Disk band IRF PL frac:  0.20261016635537202
# Disk band total PL frac:  [0.23233759]
# #######################################
# Time bin size dt is:  0.002140455453937019
# The maximum propagation delay is:  32.305057036458415  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.7207225111568 Rg
# Disk band IRF PL frac:  0.202711102197886
# Disk band total PL frac:  [0.23244651]
# #######################################
# Time bin size dt is:  0.0021395248404614334
# The maximum propagation delay is:  32.31746985280453  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.73788300325869 Rg
# Disk band IRF PL frac:  0.20250813335692794
# Disk band total PL frac:  [0.23223114]
# #######################################
# Time bin size dt is:  0.002140321527891887
# The maximum propagation delay is:  32.29498470730634  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71579134933161 Rg
# Disk band IRF PL frac:  0.20255426873398305
# Disk band total PL frac:  [0.23227115]
# #######################################
# Time bin size dt is:  0.002139956784138295
# The maximum propagation delay is:  32.29249924887647  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72169620997144 Rg
# Disk band IRF PL frac:  0.2025645554228075
# Disk band total PL frac:  [0.23228869]
# #######################################
# Time bin size dt is:  0.0021399904734928548
# The maximum propagation delay is:  32.302377894177795  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72265899230813 Rg
# Disk band IRF PL frac:  0.20260237519636973
# Disk band total PL frac:  [0.23232986]
# #######################################
# Time bin size dt is:  0.0021401353171858232
# The maximum propagation delay is:  32.30516108887807  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71770809081376 Rg
# Disk band IRF PL frac:  0.20255375912837
# Disk band total PL frac:  [0.23227038]
# #######################################
# Time bin size dt is:  0.002140318462248974
# The maximum propagation delay is:  32.296776441474606  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71833779092759 Rg
# Disk band IRF PL frac:  0.20252455765509286
# Disk band total PL frac:  [0.23224029]
# #######################################
# Time bin size dt is:  0.00213987390067541
# The maximum propagation delay is:  32.29159840724583  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71753668125322 Rg
# Disk band IRF PL frac:  0.2025642678155914
# Disk band total PL frac:  [0.23229126]
# #######################################
# Time bin size dt is:  0.0021402462231897277
# The maximum propagation delay is:  32.30283020118203  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72179611358405 Rg
# Disk band IRF PL frac:  0.2025940353586161
# Disk band total PL frac:  [0.23232138]
# #######################################
# Time bin size dt is:  0.0021403113146979415
# The maximum propagation delay is:  32.30115845537711  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71708369573939 Rg
# Disk band IRF PL frac:  0.20252291307570788
# Disk band total PL frac:  [0.23224318]
# #######################################
# Time bin size dt is:  0.0021400407888257375
# The maximum propagation delay is:  32.29106926056447  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.7233315667325 Rg
# Disk band IRF PL frac:  0.20255387082215856
# Disk band total PL frac:  [0.23227291]
# #######################################
# Time bin size dt is:  0.0021402246985188413
# The maximum propagation delay is:  32.297469463640695  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71808598520269 Rg
# Disk band IRF PL frac:  0.20244921815179825
# Disk band total PL frac:  [0.23216329]
# #######################################
# Time bin size dt is:  0.0021394481844911853
# The maximum propagation delay is:  32.29537276528123  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.7129340850255 Rg
# Disk band IRF PL frac:  0.20245235871027203
# Disk band total PL frac:  [0.2321688]
# #######################################
# Time bin size dt is:  0.0021406145210217404
# The maximum propagation delay is:  32.284795432134686  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.7186216319545 Rg
# Disk band IRF PL frac:  0.20255691307619092
# Disk band total PL frac:  [0.23227548]
# #######################################
# Time bin size dt is:  0.0021401252819081423
# The maximum propagation delay is:  32.29548890885176  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72369618788163 Rg
# Disk band IRF PL frac:  0.20256414272690348
# Disk band total PL frac:  [0.2322877]
# #######################################
# Time bin size dt is:  0.0021401757535590357
# The maximum propagation delay is:  32.29534102215383  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72019979109075 Rg
# Disk band IRF PL frac:  0.20256629253033973
# Disk band total PL frac:  [0.2322929]
# #######################################
# Time bin size dt is:  0.002140131914156976
# The maximum propagation delay is:  32.29670181710456  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.7210345315329 Rg
# Disk band IRF PL frac:  0.20256607736497145
# Disk band total PL frac:  [0.23228841]
# #######################################
# Time bin size dt is:  0.0021402357109429147
# The maximum propagation delay is:  32.29792403284545  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72284326206899 Rg
# Disk band IRF PL frac:  0.20255350714071993
# Disk band total PL frac:  [0.23227523]
# #######################################
# Time bin size dt is:  0.002140553151190428
# The maximum propagation delay is:  32.30408253371376  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.714625139625 Rg
# Disk band IRF PL frac:  0.20254350761864817
# Disk band total PL frac:  [0.23226678]
# #######################################
# Time bin size dt is:  0.0021402313055378973
# The maximum propagation delay is:  32.2969745039446  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.73417494341805 Rg
# Disk band IRF PL frac:  0.2025062609906114
# Disk band total PL frac:  [0.23222637]
# #######################################
# Time bin size dt is:  0.002140651939385804
# The maximum propagation delay is:  32.294382066123866  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72191938336032 Rg
# Disk band IRF PL frac:  0.20249944203133852
# Disk band total PL frac:  [0.23221787]
# #######################################
# Time bin size dt is:  0.0021398692556458057
# The maximum propagation delay is:  32.29416724881506  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71956187130476 Rg
# Disk band IRF PL frac:  0.20258777794077817
# Disk band total PL frac:  [0.23231349]
# #######################################
# Time bin size dt is:  0.0021400056141833417
# The maximum propagation delay is:  32.30116385090575  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.73003402226173 Rg
# Disk band IRF PL frac:  0.20257964964177477
# Disk band total PL frac:  [0.23231111]
# #######################################
# Time bin size dt is:  0.0021404134037907785
# The maximum propagation delay is:  32.3012727582463  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71177684607757 Rg
# Disk band IRF PL frac:  0.20253023965727235
# Disk band total PL frac:  [0.2322468]
# #######################################
# Time bin size dt is:  0.002139991217469045
# The maximum propagation delay is:  32.2869580689785  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71324793866631 Rg
# Disk band IRF PL frac:  0.20254886686790205
# Disk band total PL frac:  [0.23226985]
# #######################################
# Time bin size dt is:  0.0021397820466420602
# The maximum propagation delay is:  32.290179415994494  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72179011722203 Rg
# Disk band IRF PL frac:  0.2024727737418912
# Disk band total PL frac:  [0.23220341]
# #######################################
# Time bin size dt is:  0.0021406044850304615
# The maximum propagation delay is:  32.30069433044807  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71844983264502 Rg
# Disk band IRF PL frac:  0.20255515407104596
# Disk band total PL frac:  [0.23228073]
# #######################################
# Time bin size dt is:  0.0021401424181928625
# ...
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.69405261374007 Rg
# Disk band IRF PL frac:  0.20361118750891882
# Disk band total PL frac:  [0.23342223]
# #######################################
# Time bin size dt is:  0.0021360849569672835
# The maximum propagation delay is:  32.42114257928512  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.70067030967708 Rg
# Disk band IRF PL frac:  0.2022873667656995
# Disk band total PL frac:  [0.23197405]
# #######################################
# Time bin size dt is:  0.0021389955741515916
# The maximum propagation delay is:  32.27518902105243  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.8395940830053 Rg
# Disk band IRF PL frac:  0.20332847234670218
# Disk band total PL frac:  [0.23311527]
# #######################################
# Time bin size dt is:  0.002134563330074048
# The maximum propagation delay is:  32.33100525554299  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.81599224020202 Rg
# Disk band IRF PL frac:  0.2024824261867968
# Disk band total PL frac:  [0.23226291]
# #######################################
# Time bin size dt is:  0.0021394348690504258
# The maximum propagation delay is:  32.26834113959889  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.86162605681953 Rg
# Disk band IRF PL frac:  0.2030879226587689
# Disk band total PL frac:  [0.2329155]
# #######################################
# Time bin size dt is:  0.002127142824354191
# The maximum propagation delay is:  32.46981481062587  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.76691320621363 Rg
# Disk band IRF PL frac:  0.2032034718285283
# Disk band total PL frac:  [0.23301197]
# #######################################
# Time bin size dt is:  0.0021394034500014135
# The maximum propagation delay is:  32.371328571762305  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.77600898733785 Rg
# Disk band IRF PL frac:  0.20316816911595095
# Disk band total PL frac:  [0.23291763]
# #######################################
# Time bin size dt is:  0.002139716609942738
# The maximum propagation delay is:  32.381164097650846  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72610088010705 Rg
# Disk band IRF PL frac:  0.20275566179610077
# Disk band total PL frac:  [0.23249494]
# #######################################
# Time bin size dt is:  0.002141214361009823
# The maximum propagation delay is:  32.311156172128285  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.2247972806544 Rg
# Disk band IRF PL frac:  0.21009092029632412
# Disk band total PL frac:  [0.24063383]
# #######################################
# Time bin size dt is:  0.002040793208616239
# The maximum propagation delay is:  33.816047162014975  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.7922394833931 Rg
# Disk band IRF PL frac:  0.20291235205124908
# Disk band total PL frac:  [0.23270478]
# #######################################
# Time bin size dt is:  0.002135661231452236
# The maximum propagation delay is:  32.28012603085103  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.68082443842121 Rg
# Disk band IRF PL frac:  0.2028232658497231
# Disk band total PL frac:  [0.23252409]
# #######################################
# Time bin size dt is:  0.0021392196763421346
# The maximum propagation delay is:  32.322720217158476  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.61126045081497 Rg
# Disk band IRF PL frac:  0.2022526479757275
# Disk band total PL frac:  [0.23197546]
# #######################################
# Time bin size dt is:  0.0021401197289556808
# The maximum propagation delay is:  32.16111297189686  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.70295619891182 Rg
# Disk band IRF PL frac:  0.20244709235945912
# Disk band total PL frac:  [0.2321999]
# #######################################
# Time bin size dt is:  0.002134592994968042
# The maximum propagation delay is:  32.26633602408367  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.73146305495189 Rg
# Disk band IRF PL frac:  0.20222842593234597
# Disk band total PL frac:  [0.23199411]
# #######################################
# Time bin size dt is:  0.002144480234622124
# The maximum propagation delay is:  32.30064728583799  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.73838941726103 Rg
# Disk band IRF PL frac:  0.2039888927976863
# Disk band total PL frac:  [0.23391658]
# #######################################
# Time bin size dt is:  0.002144227830222517
# The maximum propagation delay is:  32.42166252980815  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.79874423727703 Rg
# Disk band IRF PL frac:  0.20218915921510897
# Disk band total PL frac:  [0.23184423]
# #######################################
# Time bin size dt is:  0.0021313428692605802
# The maximum propagation delay is:  32.261033461204086  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.21896966504079 Rg
# Disk band IRF PL frac:  0.20874338476181245
# Disk band total PL frac:  [0.24005022]
# #######################################
# Time bin size dt is:  0.002065221840886782
# The maximum propagation delay is:  33.48268743957138  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.6376025035731 Rg
# Disk band IRF PL frac:  0.20183967823222362
# Disk band total PL frac:  [0.23142036]
# #######################################
# Time bin size dt is:  0.002139472249058169
# The maximum propagation delay is:  32.136510905324776  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72705619285149 Rg
# Disk band IRF PL frac:  0.20226264201402164
# Disk band total PL frac:  [0.23175235]
# #######################################
# Time bin size dt is:  0.002141178734494947
# The maximum propagation delay is:  32.16245305847585  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.91226236939247 Rg
# Disk band IRF PL frac:  0.2032014462169044
# Disk band total PL frac:  [0.23297989]
# #######################################
# Time bin size dt is:  0.002142668497155261
# The maximum propagation delay is:  32.2758853870772  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.31401844985757 Rg
# Disk band IRF PL frac:  0.20418576869492763
# Disk band total PL frac:  [0.23396957]
# #######################################
# Time bin size dt is:  0.0021410242092921444
# The maximum propagation delay is:  32.25470395216352  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.74829739139759 Rg
# Disk band IRF PL frac:  0.2028180259054969
# Disk band total PL frac:  [0.23268072]
# #######################################
# Time bin size dt is:  0.002145766455280268
# The maximum propagation delay is:  32.453286747689475  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.68488941223217 Rg
# Disk band IRF PL frac:  0.20162936529929293
# Disk band total PL frac:  [0.23118529]
# #######################################
# Time bin size dt is:  0.0021403409159738355
# The maximum propagation delay is:  32.18688940679822  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.7253167777632 Rg
# Disk band IRF PL frac:  0.20199613433480074
# Disk band total PL frac:  [0.23170393]
# #######################################
# Time bin size dt is:  0.0021461382889877835
# The maximum propagation delay is:  32.292327986546994  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.72121643371658 Rg
# Disk band IRF PL frac:  0.20246647535204101
# Disk band total PL frac:  [0.23215303]
# #######################################
# Time bin size dt is:  0.002137548244430279
# The maximum propagation delay is:  32.276679253320566  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.73272003375762 Rg
# Disk band IRF PL frac:  0.20217723854534922
# Disk band total PL frac:  [0.23189568]
# #######################################
# Time bin size dt is:  0.0021420238602528918
# The maximum propagation delay is:  32.24967263559473  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.81783728228028 Rg
# Disk band IRF PL frac:  0.20304454143592038
# Disk band total PL frac:  [0.23285968]
# #######################################
# Time bin size dt is:  0.002141134283080457
# The maximum propagation delay is:  32.452394635828774  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.57284534311647 Rg
# Disk band IRF PL frac:  0.20176980181312754
# Disk band total PL frac:  [0.23134344]
# #######################################
# Time bin size dt is:  0.0021344362847848836
# The maximum propagation delay is:  32.167872299100466  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.78994674881318 Rg
# Disk band IRF PL frac:  0.20283149798318337
# Disk band total PL frac:  [0.23264423]
# #######################################
# Time bin size dt is:  0.0021384150758051936
# The maximum propagation delay is:  32.328161322193516  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.61387258138907 Rg
# Disk band IRF PL frac:  0.20271628596948138
# Disk band total PL frac:  [0.23246634]
# #######################################
# Time bin size dt is:  0.002136725346195074
# The maximum propagation delay is:  32.318212566857646  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.69450810203719 Rg
# Disk band IRF PL frac:  0.2031035297980332
# Disk band total PL frac:  [0.23289199]
# #######################################
# Time bin size dt is:  0.00213998478023344
# The maximum propagation delay is:  32.35127383019727  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.77512032250073 Rg
# Disk band IRF PL frac:  0.20260781460776117
# Disk band total PL frac:  [0.23241007]
# #######################################
# Time bin size dt is:  0.0021414325965546607
# The maximum propagation delay is:  32.36846471507932  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.747691050954 Rg
# Disk band IRF PL frac:  0.2033470243861381
# Disk band total PL frac:  [0.23312501]
# #######################################
# Time bin size dt is:  0.0021494759139534716
# The maximum propagation delay is:  32.28622137640144  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.68802901351651 Rg
# Disk band IRF PL frac:  0.20368916895769115
# Disk band total PL frac:  [0.23349441]
# #######################################
# Time bin size dt is:  0.0021407156962020453
# The maximum propagation delay is:  32.277531473064116  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.68968253149681 Rg
# Disk band IRF PL frac:  0.20214334231776906
# Disk band total PL frac:  [0.23175304]
# #######################################
# Time bin size dt is:  0.002135668739033032
# The maximum propagation delay is:  32.188193264102615  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.6943566513212 Rg
# Disk band IRF PL frac:  0.20276187079612432
# Disk band total PL frac:  [0.23254245]
# #######################################
# Time bin size dt is:  0.002146784812320283
# The maximum propagation delay is:  32.38177188317133  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.7596359500013 Rg
# Disk band IRF PL frac:  0.2024160168899244
# Disk band total PL frac:  [0.23203863]
# #######################################
# Time bin size dt is:  0.002130788742290693
# The maximum propagation delay is:  32.27077679523778  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.51385680244593 Rg
# Disk band IRF PL frac:  0.2009343308805277
# Disk band total PL frac:  [0.23049191]
# #######################################
# Time bin size dt is:  0.002147610859831971
# The maximum propagation delay is:  32.1054910150022  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.51678367099528 Rg
# Disk band IRF PL frac:  0.20213759644155657
# Disk band total PL frac:  [0.23175775]
# #######################################
# Time bin size dt is:  0.0021440056040691034
# The maximum propagation delay is:  32.24064242801045  and there are  524288  irf bins.
# 100%|██████████| 10/10 [1:27:21<00:00, 524.16s/it]
# The chain is shorter than 50 times the integrated autocorrelation time for 8 parameter(s). Use this estimate with caution and run a longer chain!
# N/50 = 0;
# tau: [1.03807997 1.11302817 1.08334715 1.06886149 1.12230982 1.06781485
#  1.10409995 1.14383184]
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71869238681835 Rg
# Disk band IRF PL frac:  0.2025528821085879
# Disk band total PL frac:  [0.23227363]
# #######################################
# Time bin size dt is:  0.002140107745157606
# The maximum propagation delay is:  32.29543684448761  and there are  524288  irf bins.
# [[Fit Statistics]]
#     # fitting method   = emcee
#     # function evals   = 1000
#     # data points      = 70
#     # variables        = 8
#     chi-square         = 1298.32341
#     reduced chi-square = 20.9407002
#     Akaike info crit   = 220.423365
#     Bayesian info crit = 238.411327
# [[Variables]]
#     rin:                   2.96009477 +/- 0.00170243 (0.06%) (init = 2.96)
#     rcor:                  7.96006987 +/- 0.00538345 (0.07%) (init = 7.96)
#     hcor:                  10.2305677 +/- 0.00898660 (0.09%) (init = 10.23)
#     cone_angle:            30.0002850 +/- 0.01630794 (0.05%) (init = 30)
#     seedff_norm:           0 (fixed)
#     thermal_frac:          1.44001946 +/- 7.7823e-04 (0.05%) (init = 1.44)
#     pow_disk_frac:         1 (fixed)
#     disk_en:               2.50002259 +/- 0.00164720 (0.07%) (init = 2.5)
#     band_mult:             1.5 (fixed)
#     disk_tau_norm:         55.0001421 +/- 0.04234158 (0.08%) (init = 55)
#     disk_tau_ind:          1.8 (fixed)
#     delay_tau_scale:       1 (fixed)
#     disp_ind:             -3 (fixed)
#     disksoft_psdrat_norm:  1 (fixed)
#     softhard_psdrat_norm:  1 (fixed)
#     lor_q1:                1 (fixed)
#     lor_freq1:             0.03 (fixed)
#     lor_rms1:              0.1 (fixed)
#     lor_q2:                1 (fixed)
#     lor_freq2:             0.5 (fixed)
#     lor_rms2:              0.1 (fixed)
#     lor_q3:                1 (fixed)
#     lor_freq3:             2 (fixed)
#     lor_rms3:              0.1 (fixed)
#     __lnsigma:             0.01000013 +/- 7.2686e-06 (0.07%) (init = 0.01)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(rin, disk_en)                = -0.396
#     C(disk_tau_norm, __lnsigma)    = -0.373
#     C(rcor, disk_tau_norm)         = -0.366
#     C(thermal_frac, disk_en)       = 0.287
#     C(hcor, thermal_frac)          = 0.259
#     C(rcor, __lnsigma)             = 0.245
#     C(rin, thermal_frac)           = -0.233
#     C(hcor, disk_en)               = 0.214
#     C(cone_angle, disk_tau_norm)   = -0.212
#     C(rcor, hcor)                  = -0.210
#     C(cone_angle, thermal_frac)    = 0.201
#     C(thermal_frac, disk_tau_norm) = -0.201
#     C(hcor, cone_angle)            = -0.180
#     C(hcor, __lnsigma)             = 0.167
#     C(disk_en, disk_tau_norm)      = -0.147
#     C(thermal_frac, __lnsigma)     = 0.146
#     C(rin, disk_tau_norm)          = -0.141
#     C(rcor, cone_angle)            = 0.130

# %%
import corner
corner.corner(result.flatchain, labels=result.var_names, truths=list(result.params.valuesdict().values()))
# Out:
# <div id='e9aa5ad7-1512-4790-a6d6-1f951b8a956e'></div>
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# WARNING:root:Too few points to create valid contours
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/corner/core.py:756, in _get_fig_axes(fig, K)
#     755 try:
# --> 756     return np.array(fig.axes).reshape((K, K))
#     757 except ValueError:
#
# ValueError: cannot reshape array of size 64 into shape (25,25)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /mnt/c/Users/danivenk/Dropbox/Master_Project/UVA-API_Master-Project/mono_lags/UM21_coronalags_datacomparison_bandpass_emcee.ipynb Cell 12 in <cell line: 2>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/danivenk/Dropbox/Master_Project/UVA-API_Master-Project/mono_lags/UM21_coronalags_datacomparison_bandpass_emcee.ipynb#X30sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> import corner
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/danivenk/Dropbox/Master_Project/UVA-API_Master-Project/mono_lags/UM21_coronalags_datacomparison_bandpass_emcee.ipynb#X30sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> corner.corner(result.flatchain, labels=result.var_names, truths=list(result.params.valuesdict().values()))
#
# File ~/.local/lib/python3.8/site-packages/corner/corner.py:226, in corner(data, bins, range, weights, color, hist_bin_factor, smooth, smooth1d, labels, label_kwargs, titles, show_titles, title_fmt, title_kwargs, truths, truth_color, scale_hist, quantiles, verbose, fig, max_n_ticks, top_ticks, use_math_text, reverse, labelpad, hist_kwargs, group, var_names, filter_vars, coords, divergences, divergences_kwargs, labeller, **hist2d_kwargs)
#     214     if (
#     215         var_names is not None
#     216         or filter_vars is not None
#    (...)
#     220         or labeller is not None
#     221     ):
#     222         logging.warning(
#     223             "Please install arviz to use the advanced features of corner"
#     224         )
# --> 226     return corner_impl(
#     227         data,
#     228         bins=bins,
#     229         range=range,
#     230         weights=weights,
#     231         color=color,
#     232         hist_bin_factor=hist_bin_factor,
#     233         smooth=smooth,
#     234         smooth1d=smooth1d,
#     235         labels=labels,
#     236         label_kwargs=label_kwargs,
#     237         titles=titles,
#     238         show_titles=show_titles,
#     239         title_fmt=title_fmt,
#     240         title_kwargs=title_kwargs,
#     241         truths=truths,
#     242         truth_color=truth_color,
#     243         scale_hist=scale_hist,
#     244         quantiles=quantiles,
#     245         verbose=verbose,
#     246         fig=fig,
#     247         max_n_ticks=max_n_ticks,
#     248         top_ticks=top_ticks,
#     249         use_math_text=use_math_text,
#     250         reverse=reverse,
#     251         labelpad=labelpad,
#     252         hist_kwargs=hist_kwargs,
#     253         **hist2d_kwargs,
#     254     )
#     256 return arviz_corner(
#     257     data,
#     258     bins=bins,
#    (...)
#     290     **hist2d_kwargs,
#     291 )
#
# File ~/.local/lib/python3.8/site-packages/corner/core.py:377, in corner_impl(xs, bins, range, weights, color, hist_bin_factor, smooth, smooth1d, labels, label_kwargs, titles, show_titles, title_fmt, title_kwargs, truths, truth_color, scale_hist, quantiles, verbose, fig, max_n_ticks, top_ticks, use_math_text, reverse, labelpad, hist_kwargs, **hist2d_kwargs)
#     372             ax.yaxis.set_major_formatter(
#     373                 ScalarFormatter(useMathText=use_math_text)
#     374             )
#     376 if truths is not None:
# --> 377     overplot_lines(fig, truths, color=truth_color)
#     378     overplot_points(
#     379         fig,
#     380         [[np.nan if t is None else t for t in truths]],
#     381         marker="s",
#     382         color=truth_color,
#     383     )
#     385 return fig
#
# File ~/.local/lib/python3.8/site-packages/corner/core.py:702, in overplot_lines(fig, xs, **kwargs)
#     682 """
#     683 Overplot lines on a figure generated by ``corner.corner``
#     684
#    (...)
#     699
#     700 """
#     701 K = len(xs)
# --> 702 axes = _get_fig_axes(fig, K)
#     703 for k1 in range(K):
#     704     if xs[k1] is not None:
#
# File ~/.local/lib/python3.8/site-packages/corner/core.py:758, in _get_fig_axes(fig, K)
#     756     return np.array(fig.axes).reshape((K, K))
#     757 except ValueError:
# --> 758     raise ValueError(
#     759         (
#     760             "Provided figure has {0} axes, but data has "
#     761             "dimensions K={1}"
#     762         ).format(len(fig.axes), K)
#     763     )
#
# ValueError: Provided figure has 64 axes, but data has dimensions K=25

# %%
# set_function = Minimizer(lagmodel, params, fcn_args=(freq_in, data_in, err_in, encomb_in), fcn_kws={"nphi": 1000, "nz": 1000}, nan_policy='omit')
# #out = minimize(residual, params, args=())
# #result = set_function.minimize(method = 'leastsq')
# result = set_function.minimize(method = 'leastsq')
# report_fit(result)
# Out:
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71839315451066 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.002140046877148988
# The maximum propagation delay is:  32.29628819661545  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71839315451066 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.002140046877148988
# The maximum propagation delay is:  32.29628819661545  and there are  524288  irf bins.
# Phil >0; Dani <0
# 353.6245869466711 353.230586252363
# 0.39400069430809026
# Parameters([('rin', <Parameter 'rin', value=2.96, bounds=[1.3:6.0]>), ('rcor', <Parameter 'rcor', value=7.96, bounds=[6.0:30.0]>), ('hcor', <Parameter 'hcor', value=10.229999999999999, bounds=[5.0:100.0]>), ('cone_angle', <Parameter 'cone_angle', value=30.0, bounds=[0.0:60.0]>), ('seedff_norm', <Parameter 'seedff_norm', value=0.0 (fixed), bounds=[0.0:0.5]>), ('thermal_frac', <Parameter 'thermal_frac', value=1.44, bounds=[0.3:3.0]>), ('pow_disk_frac', <Parameter 'pow_disk_frac', value=0.0 (fixed), bounds=[0.0:100.0]>), ('disk_en', <Parameter 'disk_en', value=1.87, bounds=[0.18700000000000003:5.0]>), ('band_mult', <Parameter 'band_mult', value=1.5 (fixed), bounds=[1.001:3.0]>), ('disk_tau_norm', <Parameter 'disk_tau_norm', value=54.99999999999999, bounds=[10.0:500.0]>), ('disk_tau_ind', <Parameter 'disk_tau_ind', value=1.8 (fixed), bounds=[0.0:2.5]>), ('delay_tau_scale', <Parameter 'delay_tau_scale', value=1.0 (fixed), bounds=[0.2:5.0]>), ('disp_ind', <Parameter 'disp_ind', value=-3.0 (fixed), bounds=[-4.0:-2.0]>), ('disksoft_psdrat_norm', <Parameter 'disksoft_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('softhard_psdrat_norm', <Parameter 'softhard_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('lor_q1', <Parameter 'lor_q1', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq1', <Parameter 'lor_freq1', value=0.03 (fixed), bounds=[0.01:0.5]>), ('lor_rms1', <Parameter 'lor_rms1', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q2', <Parameter 'lor_q2', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq2', <Parameter 'lor_freq2', value=0.5 (fixed), bounds=[0.5:3.0]>), ('lor_rms2', <Parameter 'lor_rms2', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q3', <Parameter 'lor_q3', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq3', <Parameter 'lor_freq3', value=2.0 (fixed), bounds=[2.0:10.0]>), ('lor_rms3', <Parameter 'lor_rms3', value=0.1 (fixed), bounds=[0.0:0.5]>)])
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71839315451066 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.002140046877148988
# The maximum propagation delay is:  32.29628819661545  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71839315451066 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.002140046877148988
# The maximum propagation delay is:  32.29628819661545  and there are  524288  irf bins.
# Phil >0; Dani <0
# 353.6245869466711 353.230586252363
# 0.39400069430809026
# Parameters([('rin', <Parameter 'rin', value=2.96, bounds=[1.3:6.0]>), ('rcor', <Parameter 'rcor', value=7.96, bounds=[6.0:30.0]>), ('hcor', <Parameter 'hcor', value=10.229999999999999, bounds=[5.0:100.0]>), ('cone_angle', <Parameter 'cone_angle', value=30.0, bounds=[0.0:60.0]>), ('seedff_norm', <Parameter 'seedff_norm', value=0.0 (fixed), bounds=[0.0:0.5]>), ('thermal_frac', <Parameter 'thermal_frac', value=1.44, bounds=[0.3:3.0]>), ('pow_disk_frac', <Parameter 'pow_disk_frac', value=0.0 (fixed), bounds=[0.0:100.0]>), ('disk_en', <Parameter 'disk_en', value=1.87, bounds=[0.18700000000000003:5.0]>), ('band_mult', <Parameter 'band_mult', value=1.5 (fixed), bounds=[1.001:3.0]>), ('disk_tau_norm', <Parameter 'disk_tau_norm', value=54.99999999999999, bounds=[10.0:500.0]>), ('disk_tau_ind', <Parameter 'disk_tau_ind', value=1.8 (fixed), bounds=[0.0:2.5]>), ('delay_tau_scale', <Parameter 'delay_tau_scale', value=1.0 (fixed), bounds=[0.2:5.0]>), ('disp_ind', <Parameter 'disp_ind', value=-3.0 (fixed), bounds=[-4.0:-2.0]>), ('disksoft_psdrat_norm', <Parameter 'disksoft_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('softhard_psdrat_norm', <Parameter 'softhard_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('lor_q1', <Parameter 'lor_q1', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq1', <Parameter 'lor_freq1', value=0.03 (fixed), bounds=[0.01:0.5]>), ('lor_rms1', <Parameter 'lor_rms1', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q2', <Parameter 'lor_q2', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq2', <Parameter 'lor_freq2', value=0.5 (fixed), bounds=[0.5:3.0]>), ('lor_rms2', <Parameter 'lor_rms2', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q3', <Parameter 'lor_q3', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq3', <Parameter 'lor_freq3', value=2.0 (fixed), bounds=[2.0:10.0]>), ('lor_rms3', <Parameter 'lor_rms3', value=0.1 (fixed), bounds=[0.0:0.5]>)])
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71839315451066 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.002140046877148988
# The maximum propagation delay is:  32.29628819661545  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71839315451066 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.002140046877148988
# The maximum propagation delay is:  32.29628819661545  and there are  524288  irf bins.
# Phil >0; Dani <0
# 353.6245869466711 353.230586252363
# 0.39400069430809026
# Parameters([('rin', <Parameter 'rin', value=2.96, bounds=[1.3:6.0]>), ('rcor', <Parameter 'rcor', value=7.96, bounds=[6.0:30.0]>), ('hcor', <Parameter 'hcor', value=10.229999999999999, bounds=[5.0:100.0]>), ('cone_angle', <Parameter 'cone_angle', value=30.0, bounds=[0.0:60.0]>), ('seedff_norm', <Parameter 'seedff_norm', value=0.0 (fixed), bounds=[0.0:0.5]>), ('thermal_frac', <Parameter 'thermal_frac', value=1.44, bounds=[0.3:3.0]>), ('pow_disk_frac', <Parameter 'pow_disk_frac', value=0.0 (fixed), bounds=[0.0:100.0]>), ('disk_en', <Parameter 'disk_en', value=1.87, bounds=[0.18700000000000003:5.0]>), ('band_mult', <Parameter 'band_mult', value=1.5 (fixed), bounds=[1.001:3.0]>), ('disk_tau_norm', <Parameter 'disk_tau_norm', value=54.99999999999999, bounds=[10.0:500.0]>), ('disk_tau_ind', <Parameter 'disk_tau_ind', value=1.8 (fixed), bounds=[0.0:2.5]>), ('delay_tau_scale', <Parameter 'delay_tau_scale', value=1.0 (fixed), bounds=[0.2:5.0]>), ('disp_ind', <Parameter 'disp_ind', value=-3.0 (fixed), bounds=[-4.0:-2.0]>), ('disksoft_psdrat_norm', <Parameter 'disksoft_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('softhard_psdrat_norm', <Parameter 'softhard_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('lor_q1', <Parameter 'lor_q1', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq1', <Parameter 'lor_freq1', value=0.03 (fixed), bounds=[0.01:0.5]>), ('lor_rms1', <Parameter 'lor_rms1', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q2', <Parameter 'lor_q2', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq2', <Parameter 'lor_freq2', value=0.5 (fixed), bounds=[0.5:3.0]>), ('lor_rms2', <Parameter 'lor_rms2', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q3', <Parameter 'lor_q3', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq3', <Parameter 'lor_freq3', value=2.0 (fixed), bounds=[2.0:10.0]>), ('lor_rms3', <Parameter 'lor_rms3', value=0.1 (fixed), bounds=[0.0:0.5]>)])
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71839315451066 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0021400468822605763
# The maximum propagation delay is:  32.29628806131298  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71839315451066 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0021400468822605763
# The maximum propagation delay is:  32.29628806131298  and there are  524288  irf bins.
# Phil >0; Dani <0
# 353.62458344380804 353.2305827616365
# 0.39400068217150874
# Parameters([('rin', <Parameter 'rin', value=2.9600000099756114, bounds=[1.3:6.0]>), ('rcor', <Parameter 'rcor', value=7.96, bounds=[6.0:30.0]>), ('hcor', <Parameter 'hcor', value=10.229999999999999, bounds=[5.0:100.0]>), ('cone_angle', <Parameter 'cone_angle', value=30.0, bounds=[0.0:60.0]>), ('seedff_norm', <Parameter 'seedff_norm', value=0.0 (fixed), bounds=[0.0:0.5]>), ('thermal_frac', <Parameter 'thermal_frac', value=1.44, bounds=[0.3:3.0]>), ('pow_disk_frac', <Parameter 'pow_disk_frac', value=0.0 (fixed), bounds=[0.0:100.0]>), ('disk_en', <Parameter 'disk_en', value=1.87, bounds=[0.18700000000000003:5.0]>), ('band_mult', <Parameter 'band_mult', value=1.5 (fixed), bounds=[1.001:3.0]>), ('disk_tau_norm', <Parameter 'disk_tau_norm', value=54.99999999999999, bounds=[10.0:500.0]>), ('disk_tau_ind', <Parameter 'disk_tau_ind', value=1.8 (fixed), bounds=[0.0:2.5]>), ('delay_tau_scale', <Parameter 'delay_tau_scale', value=1.0 (fixed), bounds=[0.2:5.0]>), ('disp_ind', <Parameter 'disp_ind', value=-3.0 (fixed), bounds=[-4.0:-2.0]>), ('disksoft_psdrat_norm', <Parameter 'disksoft_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('softhard_psdrat_norm', <Parameter 'softhard_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('lor_q1', <Parameter 'lor_q1', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq1', <Parameter 'lor_freq1', value=0.03 (fixed), bounds=[0.01:0.5]>), ('lor_rms1', <Parameter 'lor_rms1', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q2', <Parameter 'lor_q2', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq2', <Parameter 'lor_freq2', value=0.5 (fixed), bounds=[0.5:3.0]>), ('lor_rms2', <Parameter 'lor_rms2', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q3', <Parameter 'lor_q3', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq3', <Parameter 'lor_freq3', value=2.0 (fixed), bounds=[2.0:10.0]>), ('lor_rms3', <Parameter 'lor_rms3', value=0.1 (fixed), bounds=[0.0:0.5]>)])
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71839365153144 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0021400468884129786
# The maximum propagation delay is:  32.29628877883072  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71839365153144 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0021400468884129786
# The maximum propagation delay is:  32.29628877883072  and there are  524288  irf bins.
# Phil >0; Dani <0
# 353.62458875414086 353.230588036578
# 0.3940007175628466
# Parameters([('rin', <Parameter 'rin', value=2.96, bounds=[1.3:6.0]>), ('rcor', <Parameter 'rcor', value=7.960000097073688, bounds=[6.0:30.0]>), ('hcor', <Parameter 'hcor', value=10.229999999999999, bounds=[5.0:100.0]>), ('cone_angle', <Parameter 'cone_angle', value=30.0, bounds=[0.0:60.0]>), ('seedff_norm', <Parameter 'seedff_norm', value=0.0 (fixed), bounds=[0.0:0.5]>), ('thermal_frac', <Parameter 'thermal_frac', value=1.44, bounds=[0.3:3.0]>), ('pow_disk_frac', <Parameter 'pow_disk_frac', value=0.0 (fixed), bounds=[0.0:100.0]>), ('disk_en', <Parameter 'disk_en', value=1.87, bounds=[0.18700000000000003:5.0]>), ('band_mult', <Parameter 'band_mult', value=1.5 (fixed), bounds=[1.001:3.0]>), ('disk_tau_norm', <Parameter 'disk_tau_norm', value=54.99999999999999, bounds=[10.0:500.0]>), ('disk_tau_ind', <Parameter 'disk_tau_ind', value=1.8 (fixed), bounds=[0.0:2.5]>), ('delay_tau_scale', <Parameter 'delay_tau_scale', value=1.0 (fixed), bounds=[0.2:5.0]>), ('disp_ind', <Parameter 'disp_ind', value=-3.0 (fixed), bounds=[-4.0:-2.0]>), ('disksoft_psdrat_norm', <Parameter 'disksoft_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('softhard_psdrat_norm', <Parameter 'softhard_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('lor_q1', <Parameter 'lor_q1', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq1', <Parameter 'lor_freq1', value=0.03 (fixed), bounds=[0.01:0.5]>), ('lor_rms1', <Parameter 'lor_rms1', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q2', <Parameter 'lor_q2', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq2', <Parameter 'lor_freq2', value=0.5 (fixed), bounds=[0.5:3.0]>), ('lor_rms2', <Parameter 'lor_rms2', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q3', <Parameter 'lor_q3', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq3', <Parameter 'lor_freq3', value=2.0 (fixed), bounds=[2.0:10.0]>), ('lor_rms3', <Parameter 'lor_rms3', value=0.1 (fixed), bounds=[0.0:0.5]>)])
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71839315451066 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.002140046877148988
# The maximum propagation delay is:  32.29628819661545  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71839315451066 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.002140046877148988
# The maximum propagation delay is:  32.29628819661545  and there are  524288  irf bins.
# Phil >0; Dani <0
# 353.6245977660515 353.2305970047154
# 0.3940007613361445
# Parameters([('rin', <Parameter 'rin', value=2.96, bounds=[1.3:6.0]>), ('rcor', <Parameter 'rcor', value=7.96, bounds=[6.0:30.0]>), ('hcor', <Parameter 'hcor', value=10.230000354232555, bounds=[5.0:100.0]>), ('cone_angle', <Parameter 'cone_angle', value=30.0, bounds=[0.0:60.0]>), ('seedff_norm', <Parameter 'seedff_norm', value=0.0 (fixed), bounds=[0.0:0.5]>), ('thermal_frac', <Parameter 'thermal_frac', value=1.44, bounds=[0.3:3.0]>), ('pow_disk_frac', <Parameter 'pow_disk_frac', value=0.0 (fixed), bounds=[0.0:100.0]>), ('disk_en', <Parameter 'disk_en', value=1.87, bounds=[0.18700000000000003:5.0]>), ('band_mult', <Parameter 'band_mult', value=1.5 (fixed), bounds=[1.001:3.0]>), ('disk_tau_norm', <Parameter 'disk_tau_norm', value=54.99999999999999, bounds=[10.0:500.0]>), ('disk_tau_ind', <Parameter 'disk_tau_ind', value=1.8 (fixed), bounds=[0.0:2.5]>), ('delay_tau_scale', <Parameter 'delay_tau_scale', value=1.0 (fixed), bounds=[0.2:5.0]>), ('disp_ind', <Parameter 'disp_ind', value=-3.0 (fixed), bounds=[-4.0:-2.0]>), ('disksoft_psdrat_norm', <Parameter 'disksoft_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('softhard_psdrat_norm', <Parameter 'softhard_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('lor_q1', <Parameter 'lor_q1', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq1', <Parameter 'lor_freq1', value=0.03 (fixed), bounds=[0.01:0.5]>), ('lor_rms1', <Parameter 'lor_rms1', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q2', <Parameter 'lor_q2', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq2', <Parameter 'lor_freq2', value=0.5 (fixed), bounds=[0.5:3.0]>), ('lor_rms2', <Parameter 'lor_rms2', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q3', <Parameter 'lor_q3', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq3', <Parameter 'lor_freq3', value=2.0 (fixed), bounds=[2.0:10.0]>), ('lor_rms3', <Parameter 'lor_rms3', value=0.1 (fixed), bounds=[0.0:0.5]>)])
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71839315451066 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.002140046877148988
# The maximum propagation delay is:  32.29628819661545  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71839315451066 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.002140046877148988
# The maximum propagation delay is:  32.29628819661545  and there are  524288  irf bins.
# Phil >0; Dani <0
# 353.62458707129787 353.2305863661301
# 0.3940007051677412
# Parameters([('rin', <Parameter 'rin', value=2.96, bounds=[1.3:6.0]>), ('rcor', <Parameter 'rcor', value=7.96, bounds=[6.0:30.0]>), ('hcor', <Parameter 'hcor', value=10.229999999999999, bounds=[5.0:100.0]>), ('cone_angle', <Parameter 'cone_angle', value=30.000000447034836, bounds=[0.0:60.0]>), ('seedff_norm', <Parameter 'seedff_norm', value=0.0 (fixed), bounds=[0.0:0.5]>), ('thermal_frac', <Parameter 'thermal_frac', value=1.44, bounds=[0.3:3.0]>), ('pow_disk_frac', <Parameter 'pow_disk_frac', value=0.0 (fixed), bounds=[0.0:100.0]>), ('disk_en', <Parameter 'disk_en', value=1.87, bounds=[0.18700000000000003:5.0]>), ('band_mult', <Parameter 'band_mult', value=1.5 (fixed), bounds=[1.001:3.0]>), ('disk_tau_norm', <Parameter 'disk_tau_norm', value=54.99999999999999, bounds=[10.0:500.0]>), ('disk_tau_ind', <Parameter 'disk_tau_ind', value=1.8 (fixed), bounds=[0.0:2.5]>), ('delay_tau_scale', <Parameter 'delay_tau_scale', value=1.0 (fixed), bounds=[0.2:5.0]>), ('disp_ind', <Parameter 'disp_ind', value=-3.0 (fixed), bounds=[-4.0:-2.0]>), ('disksoft_psdrat_norm', <Parameter 'disksoft_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('softhard_psdrat_norm', <Parameter 'softhard_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('lor_q1', <Parameter 'lor_q1', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq1', <Parameter 'lor_freq1', value=0.03 (fixed), bounds=[0.01:0.5]>), ('lor_rms1', <Parameter 'lor_rms1', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q2', <Parameter 'lor_q2', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq2', <Parameter 'lor_freq2', value=0.5 (fixed), bounds=[0.5:3.0]>), ('lor_rms2', <Parameter 'lor_rms2', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q3', <Parameter 'lor_q3', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq3', <Parameter 'lor_freq3', value=2.0 (fixed), bounds=[2.0:10.0]>), ('lor_rms3', <Parameter 'lor_rms3', value=0.1 (fixed), bounds=[0.0:0.5]>)])
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71839315451066 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.002140046877148988
# The maximum propagation delay is:  32.29628819661545  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71839315451066 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.002140046877148988
# The maximum propagation delay is:  32.29628819661545  and there are  524288  irf bins.
# Phil >0; Dani <0
# 353.62458779022313 353.2305870926036
# 0.3940006976195036
# Parameters([('rin', <Parameter 'rin', value=2.96, bounds=[1.3:6.0]>), ('rcor', <Parameter 'rcor', value=7.96, bounds=[6.0:30.0]>), ('hcor', <Parameter 'hcor', value=10.229999999999999, bounds=[5.0:100.0]>), ('cone_angle', <Parameter 'cone_angle', value=30.0, bounds=[0.0:60.0]>), ('seedff_norm', <Parameter 'seedff_norm', value=0.0 (fixed), bounds=[0.0:0.5]>), ('thermal_frac', <Parameter 'thermal_frac', value=1.440000003103756, bounds=[0.3:3.0]>), ('pow_disk_frac', <Parameter 'pow_disk_frac', value=0.0 (fixed), bounds=[0.0:100.0]>), ('disk_en', <Parameter 'disk_en', value=1.87, bounds=[0.18700000000000003:5.0]>), ('band_mult', <Parameter 'band_mult', value=1.5 (fixed), bounds=[1.001:3.0]>), ('disk_tau_norm', <Parameter 'disk_tau_norm', value=54.99999999999999, bounds=[10.0:500.0]>), ('disk_tau_ind', <Parameter 'disk_tau_ind', value=1.8 (fixed), bounds=[0.0:2.5]>), ('delay_tau_scale', <Parameter 'delay_tau_scale', value=1.0 (fixed), bounds=[0.2:5.0]>), ('disp_ind', <Parameter 'disp_ind', value=-3.0 (fixed), bounds=[-4.0:-2.0]>), ('disksoft_psdrat_norm', <Parameter 'disksoft_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('softhard_psdrat_norm', <Parameter 'softhard_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('lor_q1', <Parameter 'lor_q1', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq1', <Parameter 'lor_freq1', value=0.03 (fixed), bounds=[0.01:0.5]>), ('lor_rms1', <Parameter 'lor_rms1', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q2', <Parameter 'lor_q2', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq2', <Parameter 'lor_freq2', value=0.5 (fixed), bounds=[0.5:3.0]>), ('lor_rms2', <Parameter 'lor_rms2', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q3', <Parameter 'lor_q3', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq3', <Parameter 'lor_freq3', value=2.0 (fixed), bounds=[2.0:10.0]>), ('lor_rms3', <Parameter 'lor_rms3', value=0.1 (fixed), bounds=[0.0:0.5]>)])
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71839315451066 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.002140046877148988
# The maximum propagation delay is:  32.29628819661545  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71839315451066 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.002140046877148988
# The maximum propagation delay is:  32.29628819661545  and there are  524288  irf bins.
# Phil >0; Dani <0
# 353.62459375618045 353.23059305934754
# 0.3940006968329044
# Parameters([('rin', <Parameter 'rin', value=2.96, bounds=[1.3:6.0]>), ('rcor', <Parameter 'rcor', value=7.96, bounds=[6.0:30.0]>), ('hcor', <Parameter 'hcor', value=10.229999999999999, bounds=[5.0:100.0]>), ('cone_angle', <Parameter 'cone_angle', value=30.0, bounds=[0.0:60.0]>), ('seedff_norm', <Parameter 'seedff_norm', value=0.0 (fixed), bounds=[0.0:0.5]>), ('thermal_frac', <Parameter 'thermal_frac', value=1.44, bounds=[0.3:3.0]>), ('pow_disk_frac', <Parameter 'pow_disk_frac', value=0.0 (fixed), bounds=[0.0:100.0]>), ('disk_en', <Parameter 'disk_en', value=1.8700000104437808, bounds=[0.18700000000000003:5.0]>), ('band_mult', <Parameter 'band_mult', value=1.5 (fixed), bounds=[1.001:3.0]>), ('disk_tau_norm', <Parameter 'disk_tau_norm', value=54.99999999999999, bounds=[10.0:500.0]>), ('disk_tau_ind', <Parameter 'disk_tau_ind', value=1.8 (fixed), bounds=[0.0:2.5]>), ('delay_tau_scale', <Parameter 'delay_tau_scale', value=1.0 (fixed), bounds=[0.2:5.0]>), ('disp_ind', <Parameter 'disp_ind', value=-3.0 (fixed), bounds=[-4.0:-2.0]>), ('disksoft_psdrat_norm', <Parameter 'disksoft_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('softhard_psdrat_norm', <Parameter 'softhard_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('lor_q1', <Parameter 'lor_q1', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq1', <Parameter 'lor_freq1', value=0.03 (fixed), bounds=[0.01:0.5]>), ('lor_rms1', <Parameter 'lor_rms1', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q2', <Parameter 'lor_q2', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq2', <Parameter 'lor_freq2', value=0.5 (fixed), bounds=[0.5:3.0]>), ('lor_rms2', <Parameter 'lor_rms2', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q3', <Parameter 'lor_q3', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq3', <Parameter 'lor_freq3', value=2.0 (fixed), bounds=[2.0:10.0]>), ('lor_rms3', <Parameter 'lor_rms3', value=0.1 (fixed), bounds=[0.0:0.5]>)])
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.7183923254798 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.002140046936718129
# The maximum propagation delay is:  32.29628840800362  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.7183923254798 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.002140046936718129
# The maximum propagation delay is:  32.29628840800362  and there are  524288  irf bins.
# Phil >0; Dani <0
# 353.6245728207394 353.23057212048826
# 0.39400070025112655
# Parameters([('rin', <Parameter 'rin', value=2.96, bounds=[1.3:6.0]>), ('rcor', <Parameter 'rcor', value=7.96, bounds=[6.0:30.0]>), ('hcor', <Parameter 'hcor', value=10.229999999999999, bounds=[5.0:100.0]>), ('cone_angle', <Parameter 'cone_angle', value=30.0, bounds=[0.0:60.0]>), ('seedff_norm', <Parameter 'seedff_norm', value=0.0 (fixed), bounds=[0.0:0.5]>), ('thermal_frac', <Parameter 'thermal_frac', value=1.44, bounds=[0.3:3.0]>), ('pow_disk_frac', <Parameter 'pow_disk_frac', value=0.0 (fixed), bounds=[0.0:100.0]>), ('disk_en', <Parameter 'disk_en', value=1.87, bounds=[0.18700000000000003:5.0]>), ('band_mult', <Parameter 'band_mult', value=1.5 (fixed), bounds=[1.001:3.0]>), ('disk_tau_norm', <Parameter 'disk_tau_norm', value=55.00000201381614, bounds=[10.0:500.0]>), ('disk_tau_ind', <Parameter 'disk_tau_ind', value=1.8 (fixed), bounds=[0.0:2.5]>), ('delay_tau_scale', <Parameter 'delay_tau_scale', value=1.0 (fixed), bounds=[0.2:5.0]>), ('disp_ind', <Parameter 'disp_ind', value=-3.0 (fixed), bounds=[-4.0:-2.0]>), ('disksoft_psdrat_norm', <Parameter 'disksoft_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('softhard_psdrat_norm', <Parameter 'softhard_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('lor_q1', <Parameter 'lor_q1', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq1', <Parameter 'lor_freq1', value=0.03 (fixed), bounds=[0.01:0.5]>), ('lor_rms1', <Parameter 'lor_rms1', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q2', <Parameter 'lor_q2', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq2', <Parameter 'lor_freq2', value=0.5 (fixed), bounds=[0.5:3.0]>), ('lor_rms2', <Parameter 'lor_rms2', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q3', <Parameter 'lor_q3', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq3', <Parameter 'lor_freq3', value=2.0 (fixed), bounds=[2.0:10.0]>), ('lor_rms3', <Parameter 'lor_rms3', value=0.1 (fixed), bounds=[0.0:0.5]>)])
# Minimum frequency = 0.01 Hz and maximum signal radius =  100.80010469576453 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.025
# The maximum propagation delay is:  32.39943732842247  and there are  32768  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  100.80010469576453 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.025
# The maximum propagation delay is:  32.39943732842247  and there are  32768  irf bins.
# Phil >0; Dani <0
# 3426.089095860604 3425.3678704536615
# 0.7212254069427217
# Parameters([('rin', <Parameter 'rin', value=1.8120410994829372, bounds=[1.3:6.0]>), ('rcor', <Parameter 'rcor', value=27.9397045272776, bounds=[6.0:30.0]>), ('hcor', <Parameter 'hcor', value=10.668124072985389, bounds=[5.0:100.0]>), ('cone_angle', <Parameter 'cone_angle', value=23.083094976781975, bounds=[0.0:60.0]>), ('seedff_norm', <Parameter 'seedff_norm', value=0.0 (fixed), bounds=[0.0:0.5]>), ('thermal_frac', <Parameter 'thermal_frac', value=0.6755415605696111, bounds=[0.3:3.0]>), ('pow_disk_frac', <Parameter 'pow_disk_frac', value=0.0 (fixed), bounds=[0.0:100.0]>), ('disk_en', <Parameter 'disk_en', value=1.7830545099402824, bounds=[0.18700000000000003:5.0]>), ('band_mult', <Parameter 'band_mult', value=1.5 (fixed), bounds=[1.001:3.0]>), ('disk_tau_norm', <Parameter 'disk_tau_norm', value=196.24925072805743, bounds=[10.0:500.0]>), ('disk_tau_ind', <Parameter 'disk_tau_ind', value=1.8 (fixed), bounds=[0.0:2.5]>), ('delay_tau_scale', <Parameter 'delay_tau_scale', value=1.0 (fixed), bounds=[0.2:5.0]>), ('disp_ind', <Parameter 'disp_ind', value=-3.0 (fixed), bounds=[-4.0:-2.0]>), ('disksoft_psdrat_norm', <Parameter 'disksoft_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('softhard_psdrat_norm', <Parameter 'softhard_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('lor_q1', <Parameter 'lor_q1', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq1', <Parameter 'lor_freq1', value=0.03 (fixed), bounds=[0.01:0.5]>), ('lor_rms1', <Parameter 'lor_rms1', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q2', <Parameter 'lor_q2', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq2', <Parameter 'lor_freq2', value=0.5 (fixed), bounds=[0.5:3.0]>), ('lor_rms2', <Parameter 'lor_rms2', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q3', <Parameter 'lor_q3', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq3', <Parameter 'lor_freq3', value=2.0 (fixed), bounds=[2.0:10.0]>), ('lor_rms3', <Parameter 'lor_rms3', value=0.1 (fixed), bounds=[0.0:0.5]>)])
# Minimum frequency = 0.01 Hz and maximum signal radius =  159.0621209849039 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.02085872690767763
# The maximum propagation delay is:  32.40426844419357  and there are  65536  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  159.0621209849039 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.02085872690767763
# The maximum propagation delay is:  32.40426844419357  and there are  65536  irf bins.
# Phil >0; Dani <0
# 1395.1899171773866 1393.9257757705716
# 1.2641414068150425
# Parameters([('rin', <Parameter 'rin', value=1.3304445608691609, bounds=[1.3:6.0]>), ('rcor', <Parameter 'rcor', value=29.99697995977637, bounds=[6.0:30.0]>), ('hcor', <Parameter 'hcor', value=10.001936161621524, bounds=[5.0:100.0]>), ('cone_angle', <Parameter 'cone_angle', value=23.376523147989293, bounds=[0.0:60.0]>), ('seedff_norm', <Parameter 'seedff_norm', value=0.0 (fixed), bounds=[0.0:0.5]>), ('thermal_frac', <Parameter 'thermal_frac', value=0.6856073330436316, bounds=[0.3:3.0]>), ('pow_disk_frac', <Parameter 'pow_disk_frac', value=0.0 (fixed), bounds=[0.0:100.0]>), ('disk_en', <Parameter 'disk_en', value=1.7792814326079673, bounds=[0.18700000000000003:5.0]>), ('band_mult', <Parameter 'band_mult', value=1.5 (fixed), bounds=[1.001:3.0]>), ('disk_tau_norm', <Parameter 'disk_tau_norm', value=49.4993181629028, bounds=[10.0:500.0]>), ('disk_tau_ind', <Parameter 'disk_tau_ind', value=1.8 (fixed), bounds=[0.0:2.5]>), ('delay_tau_scale', <Parameter 'delay_tau_scale', value=1.0 (fixed), bounds=[0.2:5.0]>), ('disp_ind', <Parameter 'disp_ind', value=-3.0 (fixed), bounds=[-4.0:-2.0]>), ('disksoft_psdrat_norm', <Parameter 'disksoft_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('softhard_psdrat_norm', <Parameter 'softhard_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('lor_q1', <Parameter 'lor_q1', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq1', <Parameter 'lor_freq1', value=0.03 (fixed), bounds=[0.01:0.5]>), ('lor_rms1', <Parameter 'lor_rms1', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q2', <Parameter 'lor_q2', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq2', <Parameter 'lor_freq2', value=0.5 (fixed), bounds=[0.5:3.0]>), ('lor_rms2', <Parameter 'lor_rms2', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q3', <Parameter 'lor_q3', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq3', <Parameter 'lor_freq3', value=2.0 (fixed), bounds=[2.0:10.0]>), ('lor_rms3', <Parameter 'lor_rms3', value=0.1 (fixed), bounds=[0.0:0.5]>)])
# Minimum frequency = 0.01 Hz and maximum signal radius =  184.47048220780894 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0011832249296478841
# The maximum propagation delay is:  31.995100733017594  and there are  1048576  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  184.47048220780894 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0011832249296478841
# The maximum propagation delay is:  31.995100733017594  and there are  1048576  irf bins.
# Phil >0; Dani <0
# 538.1203747443457 538.2011347752771
# -0.08076003093140116
# Parameters([('rin', <Parameter 'rin', value=5.999282874679256, bounds=[1.3:6.0]>), ('rcor', <Parameter 'rcor', value=16.195987082779286, bounds=[6.0:30.0]>), ('hcor', <Parameter 'hcor', value=34.61619139941862, bounds=[5.0:100.0]>), ('cone_angle', <Parameter 'cone_angle', value=23.40475101142895, bounds=[0.0:60.0]>), ('seedff_norm', <Parameter 'seedff_norm', value=0.0 (fixed), bounds=[0.0:0.5]>), ('thermal_frac', <Parameter 'thermal_frac', value=0.6865836673063896, bounds=[0.3:3.0]>), ('pow_disk_frac', <Parameter 'pow_disk_frac', value=0.0 (fixed), bounds=[0.0:100.0]>), ('disk_en', <Parameter 'disk_en', value=1.7789092016650205, bounds=[0.18700000000000003:5.0]>), ('band_mult', <Parameter 'band_mult', value=1.5 (fixed), bounds=[1.001:3.0]>), ('disk_tau_norm', <Parameter 'disk_tau_norm', value=10.009321540830536, bounds=[10.0:500.0]>), ('disk_tau_ind', <Parameter 'disk_tau_ind', value=1.8 (fixed), bounds=[0.0:2.5]>), ('delay_tau_scale', <Parameter 'delay_tau_scale', value=1.0 (fixed), bounds=[0.2:5.0]>), ('disp_ind', <Parameter 'disp_ind', value=-3.0 (fixed), bounds=[-4.0:-2.0]>), ('disksoft_psdrat_norm', <Parameter 'disksoft_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('softhard_psdrat_norm', <Parameter 'softhard_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('lor_q1', <Parameter 'lor_q1', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq1', <Parameter 'lor_freq1', value=0.03 (fixed), bounds=[0.01:0.5]>), ('lor_rms1', <Parameter 'lor_rms1', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q2', <Parameter 'lor_q2', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq2', <Parameter 'lor_freq2', value=0.5 (fixed), bounds=[0.5:3.0]>), ('lor_rms2', <Parameter 'lor_rms2', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q3', <Parameter 'lor_q3', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq3', <Parameter 'lor_freq3', value=2.0 (fixed), bounds=[2.0:10.0]>), ('lor_rms3', <Parameter 'lor_rms3', value=0.1 (fixed), bounds=[0.0:0.5]>)])
# Minimum frequency = 0.01 Hz and maximum signal radius =  130.83383526995587 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.024358664645809335
# The maximum propagation delay is:  32.546758541768575  and there are  65536  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  130.83383526995587 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.024358664645809335
# The maximum propagation delay is:  32.546758541768575  and there are  65536  irf bins.
# Phil >0; Dani <0
# 5964.3885406469635 5966.59995019538
# -2.2114095484166683
# Parameters([('rin', <Parameter 'rin', value=2.9771627368591655, bounds=[1.3:6.0]>), ('rcor', <Parameter 'rcor', value=27.903241696860377, bounds=[6.0:30.0]>), ('hcor', <Parameter 'hcor', value=8.364274042051505, bounds=[5.0:100.0]>), ('cone_angle', <Parameter 'cone_angle', value=4.048218966712369e-06, bounds=[0.0:60.0]>), ('seedff_norm', <Parameter 'seedff_norm', value=0.0 (fixed), bounds=[0.0:0.5]>), ('thermal_frac', <Parameter 'thermal_frac', value=0.3945869349584774, bounds=[0.3:3.0]>), ('pow_disk_frac', <Parameter 'pow_disk_frac', value=0.0 (fixed), bounds=[0.0:100.0]>), ('disk_en', <Parameter 'disk_en', value=1.6728606901758059, bounds=[0.18700000000000003:5.0]>), ('band_mult', <Parameter 'band_mult', value=1.5 (fixed), bounds=[1.001:3.0]>), ('disk_tau_norm', <Parameter 'disk_tau_norm', value=82.80034495285742, bounds=[10.0:500.0]>), ('disk_tau_ind', <Parameter 'disk_tau_ind', value=1.8 (fixed), bounds=[0.0:2.5]>), ('delay_tau_scale', <Parameter 'delay_tau_scale', value=1.0 (fixed), bounds=[0.2:5.0]>), ('disp_ind', <Parameter 'disp_ind', value=-3.0 (fixed), bounds=[-4.0:-2.0]>), ('disksoft_psdrat_norm', <Parameter 'disksoft_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('softhard_psdrat_norm', <Parameter 'softhard_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('lor_q1', <Parameter 'lor_q1', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq1', <Parameter 'lor_freq1', value=0.03 (fixed), bounds=[0.01:0.5]>), ('lor_rms1', <Parameter 'lor_rms1', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q2', <Parameter 'lor_q2', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq2', <Parameter 'lor_freq2', value=0.5 (fixed), bounds=[0.5:3.0]>), ('lor_rms2', <Parameter 'lor_rms2', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q3', <Parameter 'lor_q3', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq3', <Parameter 'lor_freq3', value=2.0 (fixed), bounds=[2.0:10.0]>), ('lor_rms3', <Parameter 'lor_rms3', value=0.1 (fixed), bounds=[0.0:0.5]>)])
# Minimum frequency = 0.01 Hz and maximum signal radius =  75.55214449783983 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0024694638988388366
# The maximum propagation delay is:  32.11583037992241  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  75.55214449783983 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0024694638988388366
# The maximum propagation delay is:  32.11583037992241  and there are  524288  irf bins.
# Phil >0; Dani <0
# 234.8328134430378 234.6578502699759
# 0.17496317306188303
# Parameters([('rin', <Parameter 'rin', value=3.058979481273437, bounds=[1.3:6.0]>), ('rcor', <Parameter 'rcor', value=8.412970973945724, bounds=[6.0:30.0]>), ('hcor', <Parameter 'hcor', value=9.727514231811838, bounds=[5.0:100.0]>), ('cone_angle', <Parameter 'cone_angle', value=28.482422975213233, bounds=[0.0:60.0]>), ('seedff_norm', <Parameter 'seedff_norm', value=0.0 (fixed), bounds=[0.0:0.5]>), ('thermal_frac', <Parameter 'thermal_frac', value=1.4014740883772174, bounds=[0.3:3.0]>), ('pow_disk_frac', <Parameter 'pow_disk_frac', value=0.0 (fixed), bounds=[0.0:100.0]>), ('disk_en', <Parameter 'disk_en', value=1.7057776495502703, bounds=[0.18700000000000003:5.0]>), ('band_mult', <Parameter 'band_mult', value=1.5 (fixed), bounds=[1.001:3.0]>), ('disk_tau_norm', <Parameter 'disk_tau_norm', value=58.5766420477163, bounds=[10.0:500.0]>), ('disk_tau_ind', <Parameter 'disk_tau_ind', value=1.8 (fixed), bounds=[0.0:2.5]>), ('delay_tau_scale', <Parameter 'delay_tau_scale', value=1.0 (fixed), bounds=[0.2:5.0]>), ('disp_ind', <Parameter 'disp_ind', value=-3.0 (fixed), bounds=[-4.0:-2.0]>), ('disksoft_psdrat_norm', <Parameter 'disksoft_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('softhard_psdrat_norm', <Parameter 'softhard_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('lor_q1', <Parameter 'lor_q1', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq1', <Parameter 'lor_freq1', value=0.03 (fixed), bounds=[0.01:0.5]>), ('lor_rms1', <Parameter 'lor_rms1', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q2', <Parameter 'lor_q2', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq2', <Parameter 'lor_freq2', value=0.5 (fixed), bounds=[0.5:3.0]>), ('lor_rms2', <Parameter 'lor_rms2', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q3', <Parameter 'lor_q3', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq3', <Parameter 'lor_freq3', value=2.0 (fixed), bounds=[2.0:10.0]>), ('lor_rms3', <Parameter 'lor_rms3', value=0.1 (fixed), bounds=[0.0:0.5]>)])
# Minimum frequency = 0.01 Hz and maximum signal radius =  75.55214449783983 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0024694639036497057
# The maximum propagation delay is:  32.11583026907929  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  75.55214449783983 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0024694639036497057
# The maximum propagation delay is:  32.11583026907929  and there are  524288  irf bins.
# Phil >0; Dani <0
# 234.83281239637276 234.65784923242725
# 0.17496316394550604
# Parameters([('rin', <Parameter 'rin', value=3.0589794898897713, bounds=[1.3:6.0]>), ('rcor', <Parameter 'rcor', value=8.412970973945724, bounds=[6.0:30.0]>), ('hcor', <Parameter 'hcor', value=9.727514231811838, bounds=[5.0:100.0]>), ('cone_angle', <Parameter 'cone_angle', value=28.482422975213233, bounds=[0.0:60.0]>), ('seedff_norm', <Parameter 'seedff_norm', value=0.0 (fixed), bounds=[0.0:0.5]>), ('thermal_frac', <Parameter 'thermal_frac', value=1.4014740883772174, bounds=[0.3:3.0]>), ('pow_disk_frac', <Parameter 'pow_disk_frac', value=0.0 (fixed), bounds=[0.0:100.0]>), ('disk_en', <Parameter 'disk_en', value=1.7057776495502703, bounds=[0.18700000000000003:5.0]>), ('band_mult', <Parameter 'band_mult', value=1.5 (fixed), bounds=[1.001:3.0]>), ('disk_tau_norm', <Parameter 'disk_tau_norm', value=58.5766420477163, bounds=[10.0:500.0]>), ('disk_tau_ind', <Parameter 'disk_tau_ind', value=1.8 (fixed), bounds=[0.0:2.5]>), ('delay_tau_scale', <Parameter 'delay_tau_scale', value=1.0 (fixed), bounds=[0.2:5.0]>), ('disp_ind', <Parameter 'disp_ind', value=-3.0 (fixed), bounds=[-4.0:-2.0]>), ('disksoft_psdrat_norm', <Parameter 'disksoft_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('softhard_psdrat_norm', <Parameter 'softhard_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('lor_q1', <Parameter 'lor_q1', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq1', <Parameter 'lor_freq1', value=0.03 (fixed), bounds=[0.01:0.5]>), ('lor_rms1', <Parameter 'lor_rms1', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q2', <Parameter 'lor_q2', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq2', <Parameter 'lor_freq2', value=0.5 (fixed), bounds=[0.5:3.0]>), ('lor_rms2', <Parameter 'lor_rms2', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q3', <Parameter 'lor_q3', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq3', <Parameter 'lor_freq3', value=2.0 (fixed), bounds=[2.0:10.0]>), ('lor_rms3', <Parameter 'lor_rms3', value=0.1 (fixed), bounds=[0.0:0.5]>)])
# Minimum frequency = 0.01 Hz and maximum signal radius =  75.5521449853942 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0024694639117209694
# The maximum propagation delay is:  32.11583093790136  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  75.5521449853942 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0024694639117209694
# The maximum propagation delay is:  32.11583093790136  and there are  524288  irf bins.
# Phil >0; Dani <0
# 234.83281410813686 234.65785092904238
# 0.17496317909447612
# Parameters([('rin', <Parameter 'rin', value=3.058979481273437, bounds=[1.3:6.0]>), ('rcor', <Parameter 'rcor', value=8.412971073478719, bounds=[6.0:30.0]>), ('hcor', <Parameter 'hcor', value=9.727514231811838, bounds=[5.0:100.0]>), ('cone_angle', <Parameter 'cone_angle', value=28.482422975213233, bounds=[0.0:60.0]>), ('seedff_norm', <Parameter 'seedff_norm', value=0.0 (fixed), bounds=[0.0:0.5]>), ('thermal_frac', <Parameter 'thermal_frac', value=1.4014740883772174, bounds=[0.3:3.0]>), ('pow_disk_frac', <Parameter 'pow_disk_frac', value=0.0 (fixed), bounds=[0.0:100.0]>), ('disk_en', <Parameter 'disk_en', value=1.7057776495502703, bounds=[0.18700000000000003:5.0]>), ('band_mult', <Parameter 'band_mult', value=1.5 (fixed), bounds=[1.001:3.0]>), ('disk_tau_norm', <Parameter 'disk_tau_norm', value=58.5766420477163, bounds=[10.0:500.0]>), ('disk_tau_ind', <Parameter 'disk_tau_ind', value=1.8 (fixed), bounds=[0.0:2.5]>), ('delay_tau_scale', <Parameter 'delay_tau_scale', value=1.0 (fixed), bounds=[0.2:5.0]>), ('disp_ind', <Parameter 'disp_ind', value=-3.0 (fixed), bounds=[-4.0:-2.0]>), ('disksoft_psdrat_norm', <Parameter 'disksoft_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('softhard_psdrat_norm', <Parameter 'softhard_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('lor_q1', <Parameter 'lor_q1', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq1', <Parameter 'lor_freq1', value=0.03 (fixed), bounds=[0.01:0.5]>), ('lor_rms1', <Parameter 'lor_rms1', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q2', <Parameter 'lor_q2', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq2', <Parameter 'lor_freq2', value=0.5 (fixed), bounds=[0.5:3.0]>), ('lor_rms2', <Parameter 'lor_rms2', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q3', <Parameter 'lor_q3', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq3', <Parameter 'lor_freq3', value=2.0 (fixed), bounds=[2.0:10.0]>), ('lor_rms3', <Parameter 'lor_rms3', value=0.1 (fixed), bounds=[0.0:0.5]>)])
# Minimum frequency = 0.01 Hz and maximum signal radius =  75.55214449783983 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0024694638988388366
# The maximum propagation delay is:  32.11583037992241  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  75.55214449783983 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0024694638988388366
# The maximum propagation delay is:  32.11583037992241  and there are  524288  irf bins.
# Phil >0; Dani <0
# 234.83282123259548 234.65785797138426
# 0.17496326121121797
# Parameters([('rin', <Parameter 'rin', value=3.058979481273437, bounds=[1.3:6.0]>), ('rcor', <Parameter 'rcor', value=8.412970973945724, bounds=[6.0:30.0]>), ('hcor', <Parameter 'hcor', value=9.727514576847792, bounds=[5.0:100.0]>), ('cone_angle', <Parameter 'cone_angle', value=28.482422975213233, bounds=[0.0:60.0]>), ('seedff_norm', <Parameter 'seedff_norm', value=0.0 (fixed), bounds=[0.0:0.5]>), ('thermal_frac', <Parameter 'thermal_frac', value=1.4014740883772174, bounds=[0.3:3.0]>), ('pow_disk_frac', <Parameter 'pow_disk_frac', value=0.0 (fixed), bounds=[0.0:100.0]>), ('disk_en', <Parameter 'disk_en', value=1.7057776495502703, bounds=[0.18700000000000003:5.0]>), ('band_mult', <Parameter 'band_mult', value=1.5 (fixed), bounds=[1.001:3.0]>), ('disk_tau_norm', <Parameter 'disk_tau_norm', value=58.5766420477163, bounds=[10.0:500.0]>), ('disk_tau_ind', <Parameter 'disk_tau_ind', value=1.8 (fixed), bounds=[0.0:2.5]>), ('delay_tau_scale', <Parameter 'delay_tau_scale', value=1.0 (fixed), bounds=[0.2:5.0]>), ('disp_ind', <Parameter 'disp_ind', value=-3.0 (fixed), bounds=[-4.0:-2.0]>), ('disksoft_psdrat_norm', <Parameter 'disksoft_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('softhard_psdrat_norm', <Parameter 'softhard_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('lor_q1', <Parameter 'lor_q1', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq1', <Parameter 'lor_freq1', value=0.03 (fixed), bounds=[0.01:0.5]>), ('lor_rms1', <Parameter 'lor_rms1', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q2', <Parameter 'lor_q2', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq2', <Parameter 'lor_freq2', value=0.5 (fixed), bounds=[0.5:3.0]>), ('lor_rms2', <Parameter 'lor_rms2', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q3', <Parameter 'lor_q3', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq3', <Parameter 'lor_freq3', value=2.0 (fixed), bounds=[2.0:10.0]>), ('lor_rms3', <Parameter 'lor_rms3', value=0.1 (fixed), bounds=[0.0:0.5]>)])
# Minimum frequency = 0.01 Hz and maximum signal radius =  75.55214449783983 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0024694638988388366
# The maximum propagation delay is:  32.11583037992241  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  75.55214449783983 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0024694638988388366
# The maximum propagation delay is:  32.11583037992241  and there are  524288  irf bins.
# Phil >0; Dani <0
# 234.83281347430867 234.6578503007515
# 0.17496317355715973
# ...
# Minimum frequency = 0.01 Hz and maximum signal radius =  85.31300071391577 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0032854795364529914
# The maximum propagation delay is:  33.583344346131426  and there are  262144  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  85.31300071391577 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0032854795364529914
# The maximum propagation delay is:  33.583344346131426  and there are  262144  irf bins.
# Phil >0; Dani <0
# 212.43344338418342 204.3271192186516
# 8.106324165531817
# Parameters([('rin', <Parameter 'rin', value=3.1118845083361206, bounds=[1.3:6.0]>), ('rcor', <Parameter 'rcor', value=10.380321529797886, bounds=[6.0:30.0]>), ('hcor', <Parameter 'hcor', value=8.582649387975863, bounds=[5.0:100.0]>), ('cone_angle', <Parameter 'cone_angle', value=23.354219994903474, bounds=[0.0:60.0]>), ('seedff_norm', <Parameter 'seedff_norm', value=0.0 (fixed), bounds=[0.0:0.5]>), ('thermal_frac', <Parameter 'thermal_frac', value=1.432092767828575, bounds=[0.3:3.0]>), ('pow_disk_frac', <Parameter 'pow_disk_frac', value=0.0 (fixed), bounds=[0.0:100.0]>), ('disk_en', <Parameter 'disk_en', value=1.584942508565179, bounds=[0.18700000000000003:5.0]>), ('band_mult', <Parameter 'band_mult', value=1.5 (fixed), bounds=[1.001:3.0]>), ('disk_tau_norm', <Parameter 'disk_tau_norm', value=57.26103953963757, bounds=[10.0:500.0]>), ('disk_tau_ind', <Parameter 'disk_tau_ind', value=1.8 (fixed), bounds=[0.0:2.5]>), ('delay_tau_scale', <Parameter 'delay_tau_scale', value=1.0 (fixed), bounds=[0.2:5.0]>), ('disp_ind', <Parameter 'disp_ind', value=-3.0 (fixed), bounds=[-4.0:-2.0]>), ('disksoft_psdrat_norm', <Parameter 'disksoft_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('softhard_psdrat_norm', <Parameter 'softhard_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('lor_q1', <Parameter 'lor_q1', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq1', <Parameter 'lor_freq1', value=0.03 (fixed), bounds=[0.01:0.5]>), ('lor_rms1', <Parameter 'lor_rms1', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q2', <Parameter 'lor_q2', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq2', <Parameter 'lor_freq2', value=0.5 (fixed), bounds=[0.5:3.0]>), ('lor_rms2', <Parameter 'lor_rms2', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q3', <Parameter 'lor_q3', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq3', <Parameter 'lor_freq3', value=2.0 (fixed), bounds=[2.0:10.0]>), ('lor_rms3', <Parameter 'lor_rms3', value=0.1 (fixed), bounds=[0.0:0.5]>)])
# Minimum frequency = 0.01 Hz and maximum signal radius =  85.31300071391577 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0032854795364529914
# The maximum propagation delay is:  33.583344346131426  and there are  262144  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  85.31300071391577 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0032854795364529914
# The maximum propagation delay is:  33.583344346131426  and there are  262144  irf bins.
# Phil >0; Dani <0
# 212.43344270136987 204.32711957224234
# 8.106323129127532
# Parameters([('rin', <Parameter 'rin', value=3.1118845083361206, bounds=[1.3:6.0]>), ('rcor', <Parameter 'rcor', value=10.380321529797886, bounds=[6.0:30.0]>), ('hcor', <Parameter 'hcor', value=8.582649387975863, bounds=[5.0:100.0]>), ('cone_angle', <Parameter 'cone_angle', value=23.354219994903474, bounds=[0.0:60.0]>), ('seedff_norm', <Parameter 'seedff_norm', value=0.0 (fixed), bounds=[0.0:0.5]>), ('thermal_frac', <Parameter 'thermal_frac', value=1.4320927646100023, bounds=[0.3:3.0]>), ('pow_disk_frac', <Parameter 'pow_disk_frac', value=0.0 (fixed), bounds=[0.0:100.0]>), ('disk_en', <Parameter 'disk_en', value=1.5849425226451084, bounds=[0.18700000000000003:5.0]>), ('band_mult', <Parameter 'band_mult', value=1.5 (fixed), bounds=[1.001:3.0]>), ('disk_tau_norm', <Parameter 'disk_tau_norm', value=57.26103953963757, bounds=[10.0:500.0]>), ('disk_tau_ind', <Parameter 'disk_tau_ind', value=1.8 (fixed), bounds=[0.0:2.5]>), ('delay_tau_scale', <Parameter 'delay_tau_scale', value=1.0 (fixed), bounds=[0.2:5.0]>), ('disp_ind', <Parameter 'disp_ind', value=-3.0 (fixed), bounds=[-4.0:-2.0]>), ('disksoft_psdrat_norm', <Parameter 'disksoft_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('softhard_psdrat_norm', <Parameter 'softhard_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('lor_q1', <Parameter 'lor_q1', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq1', <Parameter 'lor_freq1', value=0.03 (fixed), bounds=[0.01:0.5]>), ('lor_rms1', <Parameter 'lor_rms1', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q2', <Parameter 'lor_q2', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq2', <Parameter 'lor_freq2', value=0.5 (fixed), bounds=[0.5:3.0]>), ('lor_rms2', <Parameter 'lor_rms2', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q3', <Parameter 'lor_q3', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq3', <Parameter 'lor_freq3', value=2.0 (fixed), bounds=[2.0:10.0]>), ('lor_rms3', <Parameter 'lor_rms3', value=0.1 (fixed), bounds=[0.0:0.5]>)])
# Minimum frequency = 0.01 Hz and maximum signal radius =  85.31299979989728 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0032854796223915103
# The maximum propagation delay is:  33.58334459060983  and there are  262144  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  85.31299979989728 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0032854796223915103
# The maximum propagation delay is:  33.58334459060983  and there are  262144  irf bins.
# Phil >0; Dani <0
# 212.43346176531657 204.32710845601162
# 8.10635330930495
# Parameters([('rin', <Parameter 'rin', value=3.1118845083361206, bounds=[1.3:6.0]>), ('rcor', <Parameter 'rcor', value=10.380321529797886, bounds=[6.0:30.0]>), ('hcor', <Parameter 'hcor', value=8.582649387975863, bounds=[5.0:100.0]>), ('cone_angle', <Parameter 'cone_angle', value=23.354219994903474, bounds=[0.0:60.0]>), ('seedff_norm', <Parameter 'seedff_norm', value=0.0 (fixed), bounds=[0.0:0.5]>), ('thermal_frac', <Parameter 'thermal_frac', value=1.4320927646100023, bounds=[0.3:3.0]>), ('pow_disk_frac', <Parameter 'pow_disk_frac', value=0.0 (fixed), bounds=[0.0:100.0]>), ('disk_en', <Parameter 'disk_en', value=1.584942508565179, bounds=[0.18700000000000003:5.0]>), ('band_mult', <Parameter 'band_mult', value=1.5 (fixed), bounds=[1.001:3.0]>), ('disk_tau_norm', <Parameter 'disk_tau_norm', value=57.261041564115, bounds=[10.0:500.0]>), ('disk_tau_ind', <Parameter 'disk_tau_ind', value=1.8 (fixed), bounds=[0.0:2.5]>), ('delay_tau_scale', <Parameter 'delay_tau_scale', value=1.0 (fixed), bounds=[0.2:5.0]>), ('disp_ind', <Parameter 'disp_ind', value=-3.0 (fixed), bounds=[-4.0:-2.0]>), ('disksoft_psdrat_norm', <Parameter 'disksoft_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('softhard_psdrat_norm', <Parameter 'softhard_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('lor_q1', <Parameter 'lor_q1', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq1', <Parameter 'lor_freq1', value=0.03 (fixed), bounds=[0.01:0.5]>), ('lor_rms1', <Parameter 'lor_rms1', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q2', <Parameter 'lor_q2', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq2', <Parameter 'lor_freq2', value=0.5 (fixed), bounds=[0.5:3.0]>), ('lor_rms2', <Parameter 'lor_rms2', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q3', <Parameter 'lor_q3', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq3', <Parameter 'lor_freq3', value=2.0 (fixed), bounds=[2.0:10.0]>), ('lor_rms3', <Parameter 'lor_rms3', value=0.1 (fixed), bounds=[0.0:0.5]>)])
# Minimum frequency = 0.01 Hz and maximum signal radius =  85.31299393720545 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0032854802417647444
# The maximum propagation delay is:  33.5833482540086  and there are  262144  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  85.31299393720545 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0032854802417647444
# The maximum propagation delay is:  33.5833482540086  and there are  262144  irf bins.
# Phil >0; Dani <0
# 212.6973694480851 204.5529495572417
# 8.144419890843409
# Parameters([('rin', <Parameter 'rin', value=3.1118844361329856, bounds=[1.3:6.0]>), ('rcor', <Parameter 'rcor', value=10.380321735242989, bounds=[6.0:30.0]>), ('hcor', <Parameter 'hcor', value=8.582649473113477, bounds=[5.0:100.0]>), ('cone_angle', <Parameter 'cone_angle', value=23.354225343782808, bounds=[0.0:60.0]>), ('seedff_norm', <Parameter 'seedff_norm', value=0.0 (fixed), bounds=[0.0:0.5]>), ('thermal_frac', <Parameter 'thermal_frac', value=1.4320928505749526, bounds=[0.3:3.0]>), ('pow_disk_frac', <Parameter 'pow_disk_frac', value=0.0 (fixed), bounds=[0.0:100.0]>), ('disk_en', <Parameter 'disk_en', value=1.5849424509476322, bounds=[0.18700000000000003:5.0]>), ('band_mult', <Parameter 'band_mult', value=1.5 (fixed), bounds=[1.001:3.0]>), ('disk_tau_norm', <Parameter 'disk_tau_norm', value=57.26105658944549, bounds=[10.0:500.0]>), ('disk_tau_ind', <Parameter 'disk_tau_ind', value=1.8 (fixed), bounds=[0.0:2.5]>), ('delay_tau_scale', <Parameter 'delay_tau_scale', value=1.0 (fixed), bounds=[0.2:5.0]>), ('disp_ind', <Parameter 'disp_ind', value=-3.0 (fixed), bounds=[-4.0:-2.0]>), ('disksoft_psdrat_norm', <Parameter 'disksoft_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('softhard_psdrat_norm', <Parameter 'softhard_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('lor_q1', <Parameter 'lor_q1', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq1', <Parameter 'lor_freq1', value=0.03 (fixed), bounds=[0.01:0.5]>), ('lor_rms1', <Parameter 'lor_rms1', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q2', <Parameter 'lor_q2', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq2', <Parameter 'lor_freq2', value=0.5 (fixed), bounds=[0.5:3.0]>), ('lor_rms2', <Parameter 'lor_rms2', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q3', <Parameter 'lor_q3', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq3', <Parameter 'lor_freq3', value=2.0 (fixed), bounds=[2.0:10.0]>), ('lor_rms3', <Parameter 'lor_rms3', value=0.1 (fixed), bounds=[0.0:0.5]>)])
# Minimum frequency = 0.01 Hz and maximum signal radius =  85.31300071391577 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0032854795364529914
# The maximum propagation delay is:  33.583344346131426  and there are  262144  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  85.31300071391577 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0032854795364529914
# The maximum propagation delay is:  33.583344346131426  and there are  262144  irf bins.
# Phil >0; Dani <0
# 212.43344344078182 204.32711926257693
# 8.106324178204886
# Parameters([('rin', <Parameter 'rin', value=3.1118845083361206, bounds=[1.3:6.0]>), ('rcor', <Parameter 'rcor', value=10.380321529797886, bounds=[6.0:30.0]>), ('hcor', <Parameter 'hcor', value=8.582649387975863, bounds=[5.0:100.0]>), ('cone_angle', <Parameter 'cone_angle', value=23.354219994903474, bounds=[0.0:60.0]>), ('seedff_norm', <Parameter 'seedff_norm', value=0.0 (fixed), bounds=[0.0:0.5]>), ('thermal_frac', <Parameter 'thermal_frac', value=1.4320927646100023, bounds=[0.3:3.0]>), ('pow_disk_frac', <Parameter 'pow_disk_frac', value=0.0 (fixed), bounds=[0.0:100.0]>), ('disk_en', <Parameter 'disk_en', value=1.584942508565179, bounds=[0.18700000000000003:5.0]>), ('band_mult', <Parameter 'band_mult', value=1.5 (fixed), bounds=[1.001:3.0]>), ('disk_tau_norm', <Parameter 'disk_tau_norm', value=57.26103953963757, bounds=[10.0:500.0]>), ('disk_tau_ind', <Parameter 'disk_tau_ind', value=1.8 (fixed), bounds=[0.0:2.5]>), ('delay_tau_scale', <Parameter 'delay_tau_scale', value=1.0 (fixed), bounds=[0.2:5.0]>), ('disp_ind', <Parameter 'disp_ind', value=-3.0 (fixed), bounds=[-4.0:-2.0]>), ('disksoft_psdrat_norm', <Parameter 'disksoft_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('softhard_psdrat_norm', <Parameter 'softhard_psdrat_norm', value=1.0 (fixed), bounds=[0.3:3.0]>), ('lor_q1', <Parameter 'lor_q1', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq1', <Parameter 'lor_freq1', value=0.03 (fixed), bounds=[0.01:0.5]>), ('lor_rms1', <Parameter 'lor_rms1', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q2', <Parameter 'lor_q2', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq2', <Parameter 'lor_freq2', value=0.5 (fixed), bounds=[0.5:3.0]>), ('lor_rms2', <Parameter 'lor_rms2', value=0.1 (fixed), bounds=[0.0:0.5]>), ('lor_q3', <Parameter 'lor_q3', value=1 (fixed), bounds=[0.2:5.0]>), ('lor_freq3', <Parameter 'lor_freq3', value=2.0 (fixed), bounds=[2.0:10.0]>), ('lor_rms3', <Parameter 'lor_rms3', value=0.1 (fixed), bounds=[0.0:0.5]>)])
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 194
#     # data points      = 70
#     # variables        = 7
#     chi-square         = 204.327119
#     reduced chi-square = 3.24328761
#     Akaike info crit   = 88.9858895
#     Bayesian info crit = 104.725356
# [[Variables]]
#     rin:                   3.11188451 +/- 12846.2009 (412810.98%) (init = 2.96)
#     rcor:                  10.3803215 +/- 42850.6275 (412806.36%) (init = 7.96)
#     hcor:                  8.58264939 +/- 35428.0861 (412787.29%) (init = 10.23)
#     cone_angle:            23.3542200 +/- 49.4744312 (211.84%) (init = 30)
#     seedff_norm:           0 (fixed)
#     thermal_frac:          1.43209276 +/- 0.69246849 (48.35%) (init = 1.44)
#     pow_disk_frac:         0 (fixed)
#     disk_en:               1.58494251 +/- 0.40939900 (25.83%) (init = 1.87)
#     band_mult:             1.5 (fixed)
#     disk_tau_norm:         57.2610395 +/- 354558.698 (619197.10%) (init = 55)
#     disk_tau_ind:          1.8 (fixed)
#     delay_tau_scale:       1 (fixed)
#     disp_ind:             -3 (fixed)
#     disksoft_psdrat_norm:  1 (fixed)
#     softhard_psdrat_norm:  1 (fixed)
#     lor_q1:                1 (fixed)
#     lor_freq1:             0.03 (fixed)
#     lor_rms1:              0.1 (fixed)
#     lor_q2:                1 (fixed)
#     lor_freq2:             0.5 (fixed)
#     lor_rms2:              0.1 (fixed)
#     lor_q3:                1 (fixed)
#     lor_freq3:             2 (fixed)
#     lor_rms3:              0.1 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(rin, rcor)                   = 1.000
#     C(rcor, hcor)                  = 1.000
#     C(rin, hcor)                   = 1.000
#     C(rcor, disk_tau_norm)         = -1.000
#     C(rin, disk_tau_norm)          = -1.000
#     C(hcor, disk_tau_norm)         = -1.000
#     C(thermal_frac, disk_en)       = 0.807
#     C(rin, disk_en)                = 0.621
#     C(hcor, disk_en)               = 0.621
#     C(rcor, disk_en)               = 0.621
#     C(disk_en, disk_tau_norm)      = -0.621
#     C(cone_angle, thermal_frac)    = -0.578
#     C(cone_angle, disk_en)         = -0.525
#     C(rin, thermal_frac)           = 0.345
#     C(rcor, thermal_frac)          = 0.345
#     C(hcor, thermal_frac)          = 0.345
#     C(thermal_frac, disk_tau_norm) = -0.344
#     C(cone_angle, disk_tau_norm)   = -0.138
#     C(rcor, cone_angle)            = 0.138
#     C(rin, cone_angle)             = 0.138
#     C(hcor, cone_angle)            = 0.138

# %%
plot_params = result.params
#plot_params['delay_tau_scale'].value = 2.0
#plot_params = params

gamma_mean, freq, phlag, tlag, psd_ci, psd_ref, tau, i_rcor, i_rsigmax, rad, deltau,\
ldisk_disp, lseed_disp,lheat, ldisk_rev, lseed_rev, flux_irf_mono, mod_sig_psd,\
        disk_irf_mono, bandfrac = lagmodel(plot_params, None, None, None, encomb_in, rout=1000, nrad=100, nphi=100, nz=400, 
        cor_geometry=geo.Inv_Cone, t_scale=5e-5, e_seed=1.0, ens_mono=np.array([1.,3.,9.]), 
        gamma_par=[2.33,0.167], band_calc=True, encomb=np.array([[2,0],[3,2]]), nirf_mult=8, 
        min_deltau_frac=1, freq_rsigmax=0.01, kTvar=True, psd_correct=True)
vlines_list = []
laglist = []
psdlist = []
ls_list = ['solid','dashed','dotted']
t_scale=5e-5

for j in range(2):
    if j == 0:
        ydata = disktlags_data
        ydata_err = disktlags_err_data
        data_label = r'soft PL (2-3 keV) vs. disk (0.5-0.9 keV)'
    else:
        ydata = powtlags_data
        ydata_err = powtlags_err_data
        data_label = r'hard PL (6-9 keV) vs. soft PL (2-3 keV)'
    laglist.append([np.copy(freq),np.copy(tlag[j,:]),CBcol[0],ls_list[j],None,freq_data,
                    ydata,ydata_err,data_label,True])
    if j == 0:
        ydata = diskvssoft_psdratio
        ydata_err = diskvssoft_err_psdratio
        data_label = r'disk/soft PL'
    else:
        ydata = softvshard_psdratio
        ydata_err = softvshard_err_psdratio
        data_label = r'soft PL/hard PL'
    psdlist.append([np.copy(freq),psd_ref[j,:]/psd_ci[j,:],CBcol[0],ls_list[j],None,freq_data,
                    ydata,ydata_err,data_label,True])

vlines_list.append([1./(tau[i_rcor]*t_scale),'gray','dashdot'])
#        psdlist.append([np.copy(freq),freq*psd_ref[j,:],CBcol[i],ls_list[j],labtxt,freq_data,ydata,ydata_err])
#vlines_list.append([1./(tau[i_rcor]*t_scale),'gray','dashdot'])

freqlim = [0.007,100.0]
freqlim_in = [0.5,20]
tlaglim = [0.001,1]
tlaglim_in = [-0.007,0.01]
psdlim = [0.1,10.5]
inset_yticks = [-0.005,0,0.005]
axis_names = ['Frequency (Hz)','Time lag (s)',r'$P/P_{\Sigma \; \dot{m}(r)}$']
#fig_file = 'figs/lagsdata_invcone_mono_tauind1p9hcor10rcor8ang6.pdf'
fig_file = None
#leg_title=r'$r_{\rm cor}=10$ $R_{g}$, $\theta_{\rm cor}=30^{\circ}$'
leg_title = None
inputs = [True,True]

#laglist = [[None,None,CBcol[0],ls_list[0],None,freq_data,disktlags_data,disktlags_err_data,r'soft PL (2-3 keV) vs. disk (2-3 keV)'],
#           [None,None,CBcol[0],ls_list[0],None,freq_data,powtlags_data,powtlags_err_data,r'hard PL (6-9 keV) vs. soft PL (2-3 keV)']]

#plot_data_lags(inputs, laglist, vlines_list, axis_names, freqlim, freqlim_in, tlaglim, tlaglim_in, inset_yticks, 
#                   leg_title=None, figfile=fig_file)

plot_data_lags_psds(laglist, psdlist, vlines_list, axis_names, freqlim, freqlim_in, tlaglim, tlaglim_in, psdlim, 
               inset_yticks, leg_title, fig_file)
# Out:
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.23542299819302 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.00304970746045811
# The maximum propagation delay is:  33.2353992062357  and there are  524288  irf bins.
# <div id='474bba7d-5146-40dc-b28b-6d135bba66ee'></div>
# /tmp/ipykernel_748/4075850848.py:57: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax2.set_xticklabels(ax2.get_xticks(), backgroundcolor='w')

# %%
set_function = Minimizer(lagmodel, params, fcn_args=(freq_in, data_in, err_in, encomb_in), nan_policy='omit')
#out = minimize(residual, params, args=())
result2 = set_function.minimize(method = 'leastsq')
report_fit(result2)
# Out:
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71839315451066 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.002140046877148988
# The maximum propagation delay is:  32.29628819661545  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71839315451066 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.002140046877148988
# The maximum propagation delay is:  32.29628819661545  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71839315451066 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.002140046877148988
# The maximum propagation delay is:  32.29628819661545  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71839315451066 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0021400468822605763
# The maximum propagation delay is:  32.29628806131298  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71839365153144 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0021400468884129786
# The maximum propagation delay is:  32.29628877883072  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71839315451066 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.002140046877148988
# The maximum propagation delay is:  32.29628819661545  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71839315451066 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.002140046877148988
# The maximum propagation delay is:  32.29628819661545  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71839315451066 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.002140046877148988
# The maximum propagation delay is:  32.29628819661545  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.71839315451066 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.002140046877148988
# The maximum propagation delay is:  32.29628819661545  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  74.7183923254798 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.002140046936718129
# The maximum propagation delay is:  32.29628840800362  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  85.44224019306628 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.025
# The maximum propagation delay is:  32.03432215970742  and there are  32768  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  101.47428165786923 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.017281762405132545
# The maximum propagation delay is:  33.121492590858054  and there are  65536  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  150.52146863032067 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.02040332828918395
# The maximum propagation delay is:  32.647126705114864  and there are  65536  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  109.41103764872793 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.008201019965861579
# The maximum propagation delay is:  31.905637782584485  and there are  131072  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  79.22755126904694 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0028192095156738036
# The maximum propagation delay is:  32.236988639113555  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  79.22755126904694 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.002819209520905781
# The maximum propagation delay is:  32.23698853226885  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  79.22755174179923 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.002819209529703387
# The maximum propagation delay is:  32.23698915009925  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  79.22755126904694 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0028192095156738036
# The maximum propagation delay is:  32.236988639113555  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  79.22755126904694 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0028192095156738036
# The maximum propagation delay is:  32.236988639113555  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  79.22755126904694 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0028192095156738036
# The maximum propagation delay is:  32.236988639113555  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  79.22755126904694 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0028192095156738036
# The maximum propagation delay is:  32.236988639113555  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  79.22755043368556 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0028192095889765655
# The maximum propagation delay is:  32.23698885786687  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  105.93644846833975 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.007186601672680419
# The maximum propagation delay is:  32.172217719608426  and there are  131072  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  81.9211862346003 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.003033989002054998
# The maximum propagation delay is:  32.27110828187977  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  81.9211862346003 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0030339890071250796
# The maximum propagation delay is:  32.27110818511164  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  81.9211866912344 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.003033989016381298
# The maximum propagation delay is:  32.27110875649725  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  81.9211862346003 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.003033989002054998
# The maximum propagation delay is:  32.27110828187977  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  81.9211862346003 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.003033989002054998
# The maximum propagation delay is:  32.27110828187977  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  81.9211862346003 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.003033989002054998
# The maximum propagation delay is:  32.27110828187977  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  81.9211862346003 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.003033989002054998
# The maximum propagation delay is:  32.27110828187977  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  81.92118536113821 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0030339890814031823
# The maximum propagation delay is:  32.27110850948853  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  92.01654634713205 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.004088437005433732
# The maximum propagation delay is:  33.36398011142764  and there are  262144  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  85.00379780127072 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.00325967377418925
# The maximum propagation delay is:  32.91662298570391  and there are  262144  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.22575460713372 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0030505358864429716
# The maximum propagation delay is:  33.242993763131246  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.22575460713372 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.003050535891476393
# The maximum propagation delay is:  33.242993664900425  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.22575505553931 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0030505359003453955
# The maximum propagation delay is:  33.24299423569763  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.22575460713372 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0030505358864429716
# The maximum propagation delay is:  33.242993763131246  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.22575460713372 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0030505358864429716
# The maximum propagation delay is:  33.242993763131246  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.22575460713372 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0030505358864429716
# The maximum propagation delay is:  33.242993763131246  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.22575460713372 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0030505358864429716
# The maximum propagation delay is:  33.242993763131246  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.22575371238814 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0030505359669282567
# The maximum propagation delay is:  33.24299399956129  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  82.1252043227231 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0028659199917074026
# The maximum propagation delay is:  33.48757499312938  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  82.995207763578 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.00303790483106097
# The maximum propagation delay is:  32.83777404830369  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.18041597667666 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0030472311165921128
# The maximum propagation delay is:  33.15393156441807  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.2208312180699 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.003050146463231333
# The maximum propagation delay is:  33.232966010043064  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.2208312180699 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0030501464682627607
# The maximum propagation delay is:  33.23296591186595  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.22083166655891 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0030501464771355586
# The maximum propagation delay is:  33.23296648258278  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.2208312180699 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.003050146463231333
# The maximum propagation delay is:  33.232966010043064  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.2208312180699 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.003050146463231333
# The maximum propagation delay is:  33.232966010043064  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.2208312180699 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.003050146463231333
# The maximum propagation delay is:  33.232966010043064  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.2208312180699 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.003050146463231333
# The maximum propagation delay is:  33.232966010043064  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.22083032329714 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0030501465437132516
# The maximum propagation delay is:  33.232966246422784  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.2346266349923 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0030500135945089155
# The maximum propagation delay is:  33.24153859569492  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.2346266349923 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0030500135995402892
# The maximum propagation delay is:  33.24153849749096  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.23462708342068 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0030500136084080113
# The maximum propagation delay is:  33.24153906821413  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.2346266349923 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0030500135945089155
# The maximum propagation delay is:  33.24153859569492  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.2346266349923 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0030500135945089155
# The maximum propagation delay is:  33.24153859569492  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.2346266349923 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0030500135945089155
# The maximum propagation delay is:  33.24153859569492  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.2346266349923 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0030500135945089155
# The maximum propagation delay is:  33.24153859569492  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.23462573992803 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0030500136750006967
# The maximum propagation delay is:  33.24153883217366  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.21778649803889 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.003048649635103025
# The maximum propagation delay is:  33.20441787971238  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.23236744609312 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.003049830018456536
# The maximum propagation delay is:  33.236559024214884  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.23236744609312 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0030498300234868343
# The maximum propagation delay is:  33.236558926040146  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.23236789456169 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0030498300323565514
# The maximum propagation delay is:  33.2365594967186  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.23236744609312 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.003049830018456536
# The maximum propagation delay is:  33.236559024214884  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.23236744609312 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.003049830018456536
# The maximum propagation delay is:  33.236559024214884  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.23236744609312 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.003049830018456536
# The maximum propagation delay is:  33.236559024214884  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.23236744609312 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.003049830018456536
# The maximum propagation delay is:  33.236559024214884  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.23236655101236 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0030498300989470163
# The maximum propagation delay is:  33.23655926066892  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.23478475188973 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.003049679948192746
# The maximum propagation delay is:  33.234877479693296  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.23478475188973 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0030496799532218418
# The maximum propagation delay is:  33.234877381542475  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.23478520037025 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0030496799620920024
# The maximum propagation delay is:  33.23487795217197  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.23478475188973 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.003049679948192746
# The maximum propagation delay is:  33.234877479693296  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.23478475188973 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.003049679948192746
# The maximum propagation delay is:  33.234877479693296  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.23478475188973 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.003049679948192746
# The maximum propagation delay is:  33.234877479693296  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.23478475188973 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.003049679948192746
# The maximum propagation delay is:  33.234877479693296  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.23478385670994 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.003049680028685835
# The maximum propagation delay is:  33.23487771615468  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.24116623290432 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.0030499548867539868
# The maximum propagation delay is:  33.24009686889452  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.23542299819302 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.00304970746045811
# The maximum propagation delay is:  33.2353992062357  and there are  524288  irf bins.
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.23542299819302 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.00304970746045811
# The maximum propagation delay is:  33.2353992062357  and there are  524288  irf bins.
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 77
#     # data points      = 70
#     # variables        = 7
#     chi-square         = 205.196521
#     reduced chi-square = 3.25708763
#     Akaike info crit   = 89.2831040
#     Bayesian info crit = 105.022571
# [[Variables]]
#     rin:                   3.11372470 +/- 3.30590223 (106.17%) (init = 2.96)
#     rcor:                  9.89757104 +/- 18.3875596 (185.78%) (init = 7.96)
#     hcor:                  8.65526055 +/- 7.42979794 (85.84%) (init = 10.23)
#     cone_angle:            24.3228898 +/- 41.3717010 (170.09%) (init = 30)
#     seedff_norm:           0 (fixed)
#     thermal_frac:          1.47737310 +/- 3.40648160 (230.58%) (init = 1.44)
#     pow_disk_frac:         0 (fixed)
#     disk_en:               1.57948796 +/- 0.44711056 (28.31%) (init = 1.87)
#     band_mult:             1.5 (fixed)
#     disk_tau_norm:         57.0117662 +/- 7.4719e-04 (0.00%) (init = 55)
#     disk_tau_ind:          1.8 (fixed)
#     delay_tau_scale:       1 (fixed)
#     disp_ind:             -3 (fixed)
#     disksoft_psdrat_norm:  1 (fixed)
#     softhard_psdrat_norm:  1 (fixed)
#     lor_q1:                1 (fixed)
#     lor_freq1:             0.03 (fixed)
#     lor_rms1:              0.1 (fixed)
#     lor_q2:                1 (fixed)
#     lor_freq2:             0.5 (fixed)
#     lor_rms2:              0.1 (fixed)
#     lor_q3:                1 (fixed)
#     lor_freq3:             2 (fixed)
#     lor_rms3:              0.1 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(rin, hcor)                   = 0.963
#     C(rin, thermal_frac)           = 0.950
#     C(rin, disk_en)                = 0.945
#     C(hcor, thermal_frac)          = 0.935
#     C(rcor, thermal_frac)          = -0.920
#     C(hcor, disk_en)               = 0.896
#     C(thermal_frac, disk_en)       = 0.809
#     C(rcor, hcor)                  = -0.803
#     C(rin, rcor)                   = -0.762
#     C(rcor, disk_tau_norm)         = -0.632
#     C(rcor, cone_angle)            = -0.615
#     C(thermal_frac, disk_tau_norm) = 0.558
#     C(rcor, disk_en)               = -0.554
#     C(hcor, disk_tau_norm)         = 0.534
#     C(rin, disk_tau_norm)          = 0.437
#     C(cone_angle, thermal_frac)    = 0.355
#     C(cone_angle, disk_tau_norm)   = 0.290
#     C(disk_en, disk_tau_norm)      = 0.275
#     C(cone_angle, disk_en)         = -0.136

# %%
plot_params = result2.params
#plot_params['delay_tau_scale'].value = 2.0
#plot_params = params

gamma_mean, freq, phlag, tlag, psd_ci, psd_ref, tau, i_rcor, i_rsigmax, rad, deltau,\
ldisk_disp, lseed_disp,lheat, ldisk_rev, lseed_rev, flux_irf_mono, mod_sig_psd,\
        disk_irf_mono = lagmodel(plot_params, None, None, None, encomb_in, rout=1000, nrad=100, nphi=100, nz=400, 
        cor_geometry=geo.Inv_Cone, t_scale=5e-5, e_seed=1.0, ens_mono=np.array([1.,3.,9.]), 
        gamma_par=[2.33,0.167], band_calc=True, encomb=np.array([[2,0],[3,2]]), nirf_mult=8, 
        min_deltau_frac=1, freq_rsigmax=0.01, kTvar=True, psd_correct=True)
vlines_list = []
laglist = []
psdlist = []
ls_list = ['solid','dashed','dotted']
t_scale=5e-5

for j in range(2):
    if j == 0:
#        labtxt = r"$h_{\rm cor}$="+str(round(plot_params['hcor'].value))+" $R_{g}$"
        ydata = disktlags_data
        ydata_err = disktlags_err_data
        data_label = r'soft PL (2-3 keV) vs. disk (2-3 keV)'
    else:
#        labtxt = 
        ydata = powtlags_data
        ydata_err = powtlags_err_data
        data_label = r'hard PL (6-9 keV) vs. soft PL (2-3 keV)'
    laglist.append([np.copy(freq),np.copy(tlag[j,:]),CBcol[0],ls_list[j],labtxt,freq_data,ydata,ydata_err,data_label])
    if j == 0:
        ydata = diskvssoft_psdratio
        ydata_err = diskvssoft_err_psdratio
    else:
        ydata = softvshard_psdratio
        ydata_err = softvshard_err_psdratio
    psdlist.append([np.copy(freq),psd_ref[j,:]/psd_ci[j,:],CBcol[0],ls_list[j],labtxt,freq_data,ydata,ydata_err])

vlines_list.append([1./(tau[i_rcor]*t_scale),'gray','dashdot'])
#        psdlist.append([np.copy(freq),freq*psd_ref[j,:],CBcol[i],ls_list[j],labtxt,freq_data,ydata,ydata_err])
#vlines_list.append([1./(tau[i_rcor]*t_scale),'gray','dashdot'])

freqlim = [0.007,100.0]
tlaglim = [0.001,1]
tlaglim_in = [-0.007,0.01]
psdlim = [0.1,10.5]
inset_yticks = [-0.005,0,0.005]
axis_names = ['Frequency (Hz)','Time lag (s)',r'$P/P_{\Sigma \; \dot{m}(r)}$']
fig_file = 'figs/lagsdata_invcone_mono_tauind0hcor10rcor9ang40.pdf'
#figfile = None
leg_title=r'$r_{\rm cor}=10$ $R_{g}$, $\theta_{\rm cor}=30^{\circ}$'
inputs = [True,True]

#laglist = [[None,None,CBcol[0],ls_list[0],None,freq_data,disktlags_data,disktlags_err_data,r'soft PL (2-3 keV) vs. disk (2-3 keV)'],
#           [None,None,CBcol[0],ls_list[0],None,freq_data,powtlags_data,powtlags_err_data,r'hard PL (6-9 keV) vs. soft PL (2-3 keV)']]

plot_data_lags(inputs, laglist, vlines_list, axis_names, freqlim, freqlim_in, tlaglim, tlaglim_in, inset_yticks, 
                   leg_title=None, figfile=fig_file)

#plot_data_lags_psds(laglist, psdlist, vlines_list, axis_names, freqlim, tlaglim, tlaglim_in, psdlim, 
#               inset_yticks, leg_title, figfile)
# Out:
# Minimum frequency = 0.01 Hz and maximum signal radius =  83.23542299819302 Rg
# Disk band IRF PL frac:  0.0
# Disk band total PL frac:  [0.]
# #######################################
# Time bin size dt is:  0.00304970746045811
# The maximum propagation delay is:  33.2353992062357  and there are  524288  irf bins.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /mnt/c/Users/danivenk/Dropbox/Master_Project/UVA-API_Master-Project/mono_lags/UM21_coronalags_datacomparison_bandpass.ipynb Cell 11 in <cell line: 7>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/danivenk/Dropbox/Master_Project/UVA-API_Master-Project/mono_lags/UM21_coronalags_datacomparison_bandpass.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> plot_params = result2.params
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/danivenk/Dropbox/Master_Project/UVA-API_Master-Project/mono_lags/UM21_coronalags_datacomparison_bandpass.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> #plot_params['delay_tau_scale'].value = 2.0
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/danivenk/Dropbox/Master_Project/UVA-API_Master-Project/mono_lags/UM21_coronalags_datacomparison_bandpass.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> #plot_params = params
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/danivenk/Dropbox/Master_Project/UVA-API_Master-Project/mono_lags/UM21_coronalags_datacomparison_bandpass.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=4'>5</a> gamma_mean, freq, phlag, tlag, psd_ci, psd_ref, tau, i_rcor, i_rsigmax, rad, deltau,\
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/danivenk/Dropbox/Master_Project/UVA-API_Master-Project/mono_lags/UM21_coronalags_datacomparison_bandpass.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> ldisk_disp, lseed_disp,lheat, ldisk_rev, lseed_rev, flux_irf_mono, mod_sig_psd,\
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/danivenk/Dropbox/Master_Project/UVA-API_Master-Project/mono_lags/UM21_coronalags_datacomparison_bandpass.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>         disk_irf_mono = lagmodel(plot_params, None, None, None, encomb_in, rout=1000, nrad=100, nphi=100, nz=400,
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/danivenk/Dropbox/Master_Project/UVA-API_Master-Project/mono_lags/UM21_coronalags_datacomparison_bandpass.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a>         cor_geometry=geo.Inv_Cone, t_scale=5e-5, e_seed=1.0, ens_mono=np.array([1.,3.,9.]),
#       <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/danivenk/Dropbox/Master_Project/UVA-API_Master-Project/mono_lags/UM21_coronalags_datacomparison_bandpass.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a>         gamma_par=[2.33,0.167], band_calc=True, encomb=np.array([[2,0],[3,2]]), nirf_mult=8,
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/danivenk/Dropbox/Master_Project/UVA-API_Master-Project/mono_lags/UM21_coronalags_datacomparison_bandpass.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a>         min_deltau_frac=1, freq_rsigmax=0.01, kTvar=True, psd_correct=True)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/danivenk/Dropbox/Master_Project/UVA-API_Master-Project/mono_lags/UM21_coronalags_datacomparison_bandpass.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> vlines_list = []
#      <a href='vscode-notebook-cell://wsl%2Bubuntu/mnt/c/Users/danivenk/Dropbox/Master_Project/UVA-API_Master-Project/mono_lags/UM21_coronalags_datacomparison_bandpass.ipynb#X13sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a> laglist = []
#
# ValueError: too many values to unpack (expected 19)

# %%
set_function = Minimizer(lagmodel, params, fcn_args=(freq_in, data_in, err_in, encomb_in), nan_policy='omit')
#out = minimize(residual, params, args=())
result3 = set_function.minimize(method = 'leastsq')
report_fit(result3)

# %%
plot_params = result3.params
#plot_params['delay_tau_scale'].value = 2.0
#plot_params = params

gamma_mean, freq, phlag, tlag, psd_ci, psd_ref, tau, i_rcor, i_rsigmax, rad, deltau,\
ldisk_disp, lseed_disp,lheat, ldisk_rev, lseed_rev, flux_irf_mono, mod_sig_psd,\
        disk_irf_mono = lagmodel(plot_params, None, None, None, encomb_in, rout=1000, nrad=100, nphi=100, nz=400, 
        cor_geometry=uml.inv_cone, t_scale=5e-5, e_seed=1.0, ens_mono=np.array([1.,3.,9.]), 
        gamma_par=[2.33,0.167], band_calc=True, encomb=np.array([[2,0],[3,2]]), nirf_mult=8, 
        min_deltau_frac=1, freq_rsigmax=0.01, kTvar=True, psd_correct=True)
vlines_list = []
laglist = []
psdlist = []
ls_list = ['solid','dashed','dotted']
t_scale=5e-5

for j in range(2):
    if j == 0:
#        labtxt = r"$h_{\rm cor}$="+str(round(plot_params['hcor'].value))+" $R_{g}$"
        ydata = disktlags_data
        ydata_err = disktlags_err_data
        data_label = r'soft PL (2-3 keV) vs. disk (2-3 keV)'
    else:
#        labtxt = 
        ydata = powtlags_data
        ydata_err = powtlags_err_data
        data_label = r'hard PL (6-9 keV) vs. soft PL (2-3 keV)'
    laglist.append([np.copy(freq),np.copy(tlag[j,:]),CBcol[0],ls_list[j],labtxt,freq_data,ydata,ydata_err,data_label])
    if j == 0:
        ydata = diskvssoft_psdratio
        ydata_err = diskvssoft_err_psdratio
    else:
        ydata = softvshard_psdratio
        ydata_err = softvshard_err_psdratio
    psdlist.append([np.copy(freq),psd_ref[j,:]/psd_ci[j,:],CBcol[0],ls_list[j],labtxt,freq_data,ydata,ydata_err])

vlines_list.append([1./(tau[i_rcor]*t_scale),'gray','dashdot'])
#        psdlist.append([np.copy(freq),freq*psd_ref[j,:],CBcol[i],ls_list[j],labtxt,freq_data,ydata,ydata_err])
#vlines_list.append([1./(tau[i_rcor]*t_scale),'gray','dashdot'])

freqlim = [0.007,100.0]
tlaglim = [0.001,1]
tlaglim_in = [-0.007,0.01]
psdlim = [0.1,10.5]
inset_yticks = [-0.005,0,0.005]
axis_names = ['Frequency (Hz)','Time lag (s)',r'$P/P_{\Sigma \; \dot{m}(r)}$']
fig_file = 'figs/lagsdata_invcone_mono_tauind0hcor30rcor8ang8.pdf'
#figfile = None
leg_title=r'$r_{\rm cor}=10$ $R_{g}$, $\theta_{\rm cor}=30^{\circ}$'
inputs = [True,True]

#laglist = [[None,None,CBcol[0],ls_list[0],None,freq_data,disktlags_data,disktlags_err_data,r'soft PL (2-3 keV) vs. disk (2-3 keV)'],
#           [None,None,CBcol[0],ls_list[0],None,freq_data,powtlags_data,powtlags_err_data,r'hard PL (6-9 keV) vs. soft PL (2-3 keV)']]

plot_data_lags(inputs, laglist, vlines_list, axis_names, freqlim, freqlim_in, tlaglim, tlaglim_in, inset_yticks, 
                   leg_title=None, figfile=fig_file)

#plot_data_lags_psds(laglist, psdlist, vlines_list, axis_names, freqlim, tlaglim, tlaglim_in, psdlim, 
#               inset_yticks, leg_title, figfile)

# %%
gamma_mean, freq, phlag, tlag, psd_ci, psd_ref, tau, i_rcor, i_rsigmax, rad, deltau,\
ldisk_disp, lseed_disp,lheat, ldisk_rev, lseed_rev, flux_irf_mono, mod_sig_psd,\
        disk_irf_mono = lagmodel(plot_params, None, None, None, encomb_in, rout=1000, nrad=100, nphi=100, nz=400, 
        cor_geometry=uml.inv_cone, t_scale=5e-5, e_seed=1.0, ens_mono=np.array([1.,3.,9.]), 
        gamma_par=[2.33,0.167], band_calc=True, encomb=np.array([[2,0],[3,2]]), nirf_mult=8, 
        min_deltau_frac=1, freq_rsigmax=0.01, bb_type='static')
vlines_list = []
laglist = []
psdlist = []
ls_list = ['solid','dashed','dotted']
t_scale=5e-5

for j in range(2):
    if j == 0:
        labtxt = r"$h_{\rm cor}$="+str(round(plot_params['hcor'].value))+" $R_{g}$"
        ydata = disktlags_data
        ydata_err = disktlags_err_data
    else:
        labtxt = None
        ydata = powtlags_data
        ydata_err = powtlags_err_data           
    laglist.append([np.copy(freq),np.copy(tlag[j,:]),CBcol[0],ls_list[j],labtxt,freq_data,ydata,ydata_err])
    if j == 0:
        ydata = diskvssoft_psdratio
        ydata_err = diskvssoft_err_psdratio
    else:
        ydata = softvshard_psdratio
        ydata_err = softvshard_err_psdratio
    psdlist.append([np.copy(freq),psd_ref[j,:]/psd_ci[j,:],CBcol[0],ls_list[j],labtxt,freq_data,ydata,ydata_err])

vlines_list.append([1./(tau[i_rcor]*t_scale),'gray','dashdot'])
#        psdlist.append([np.copy(freq),freq*psd_ref[j,:],CBcol[i],ls_list[j],labtxt,freq_data,ydata,ydata_err])
#vlines_list.append([1./(tau[i_rcor]*t_scale),'gray','dashdot'])

freqlim = [0.007,100.0]
tlaglim = [0.001,1]
tlaglim_in = [-0.018,0.01]
psdlim = [0.1,1.5]
inset_yticks = [-0.015,-0.01,-0.005,0,0.005]
axis_names = ['Frequency (Hz)','Time lag (s)',r'$P/P_{\Sigma \; \dot{m}(r)}$']
#figfile = 'figs/lagspsd_invcone_mono_hcorcompare.pdf'
figfile = None
leg_title=r'$r_{\rm cor}=10$ $R_{g}$, $\theta_{\rm cor}=30^{\circ}$'

plot_data_lags_psds(laglist, psdlist, vlines_list, axis_names, freqlim, tlaglim, tlaglim_in, psdlim, 
               inset_yticks, leg_title, figfile)

# %%
freq_in = [freq_data[freq_data < 20],freq_data[(freq_data > 0.1) & (freq_data < 20)]]
data_in = [disktlags_data[freq_data < 20],powtlags_data[(freq_data > 0.1) & (freq_data < 20)]]
err_in = [disktlags_err_data[freq_data < 20],powtlags_err_data[(freq_data > 0.1) & (freq_data < 20)]]
encomb_in = [1,2]

params = result.params
#params['seedff_norm'].vary = True
params['disp_ind'].vary = True

set_function = Minimizer(lagmodel, params, fcn_args=(freq_in, data_in, err_in, encomb_in), nan_policy='omit')
#out = minimize(residual, params, args=())
result = set_function.minimize(method = 'leastsq')
report_fit(result)

# %%
plot_params = result.params

gamma_mean, freq, phlag, tlag, psd_ci, psd_ref, tau, i_rcor, i_rsigmax, rad, deltau,\
ldisk_disp, lseed_disp,lheat, ldisk_rev, lseed_rev, flux_irf_mono, mod_sig_psd,\
        disk_irf_mono = lagmodel(plot_params, None, None, None, encomb_in, rout=1000, nrad=100, nphi=100, nz=400, 
        cor_geometry=uml.inv_cone, t_scale=5e-5, e_seed=1.0, ens_mono=np.array([1.,3.,9.]), 
        gamma_par=[2.33,0.167], band_calc=True, encomb=np.array([[2,0],[3,2]]), nirf_mult=8, 
        min_deltau_frac=1, freq_rsigmax=0.01)
vlines_list = []
laglist = []
psdlist = []
ls_list = ['solid','dashed','dotted']
t_scale=5e-5

for j in range(2):
    if j == 0:
        labtxt = r"$h_{\rm cor}$="+str(round(plot_params['hcor'].value))+" $R_{g}$"
        ydata = disktlags_data
        ydata_err = disktlags_err_data
    else:
        labtxt = None
        ydata = powtlags_data
        ydata_err = powtlags_err_data           
    laglist.append([np.copy(freq),np.copy(tlag[j,:]),CBcol[0],ls_list[j],labtxt,freq_data,ydata,ydata_err])
    if j == 0:
        ydata = diskvssoft_psdratio
        ydata_err = diskvssoft_err_psdratio
    else:
        ydata = softvshard_psdratio
        ydata_err = softvshard_err_psdratio
    psdlist.append([np.copy(freq),psd_ref[j,:]/psd_ci[j,:],CBcol[0],ls_list[j],labtxt,freq_data,ydata,ydata_err])

vlines_list.append([1./(tau[i_rcor]*t_scale),'gray','dashdot'])
#        psdlist.append([np.copy(freq),freq*psd_ref[j,:],CBcol[i],ls_list[j],labtxt,freq_data,ydata,ydata_err])
#vlines_list.append([1./(tau[i_rcor]*t_scale),'gray','dashdot'])

freqlim = [0.007,100.0]
tlaglim = [0.001,1]
tlaglim_in = [-0.018,0.01]
psdlim = [0.1,1.5]
inset_yticks = [-0.015,-0.01,-0.005,0,0.005]
axis_names = ['Frequency (Hz)','Time lag (s)',r'$P/P_{\Sigma \; \dot{m}(r)}$']
#figfile = 'figs/lagspsd_invcone_mono_hcorcompare.pdf'
figfile = None
leg_title=r'$r_{\rm cor}=10$ $R_{g}$, $\theta_{\rm cor}=30^{\circ}$'

plot_data_lags_psds(laglist, psdlist, vlines_list, axis_names, freqlim, tlaglim, tlaglim_in, psdlim, 
               inset_yticks, leg_title, figfile)
