# %%
from __future__ import division
import numpy as np
import scipy
import scipy.stats as sps
import scipy.fftpack as spfft
import scipy.signal as spsig
import math
import matplotlib.pyplot as plt
import um21_lagmodel as uml
#import um_lagmodel_020421b as uml
#%matplotlib inline
# %matplotlib notebook

# Set up list of colours that are more colour-blind accessible.
CBcol = ['#377eb8', '#ff7f00', '#4daf4a',
                  '#f781bf', '#a65628', '#984ea3',
                  '#999999', '#e41a1c', '#dede00']

# %%
def plot_fdisk2cor(rad,disktocor_frac_sph,fdisk2cor_array,label_list,lstylist,leg_title,figfile):
    plt.figure()
    plt.plot(rad,disktocor_frac_sph,color=CBcol[0],label='Spherical',linewidth=3,linestyle='solid')
    for i in range(np.shape(fdisk2cor_array)[0]):
        plt.plot(rad,fdisk2cor_array[i,:],color=CBcol[i+1],label=label_list[i],linewidth=3,linestyle=lstylist[i])
    plt.xlabel(r'r ($R_{g}$)',fontsize=14)
    plt.ylabel(r'$f_{\rm d\rightarrow c}(r)$', fontsize=14)
    plt.xticks(fontsize=11)
    plt.yticks(fontsize=11)
    plt.xscale('log')
    plt.yscale('log')
    plt.xlim(8,100)
    plt.ylim(1e-4,1.0)
    plt.legend(fontsize=12,title=leg_title)
    if figfile != None:
        plt.savefig(figfile,bbox_inches='tight')
    plt.show()
    return


# Make plots of disktocor_frac and cortodisk_frac
#First set up radial grid
rin = 2.0  # Innermost radius for viscous dissipation (ISCO)
rout = 300.0 # Outermost radius for viscous dissipation - best to set large but with smaller rsigmax 
# to make linear rebinned IRFs manageable
nrad = 200 # Number of radial bins for viscous dissipation
rad_edge = np.logspace(np.log10(rin), np.log10(rout), nrad+1)  # set up radial bin edges
rad = np.sqrt(rad_edge[1:]*rad_edge[:-1])  # Define radial bin centres as geometric mean of bin edges
rad_area = np.pi*(np.square(rad_edge[1:])-np.square(rad_edge[:-1]))
# Now reset coronal outer radius (i.e. disk inner radius) to be at the nearest radial bin edges
rcor = 10.0 # Outer radius of corona and inner radius of blackbody emitting disk
rcor, i_rcor = uml.find_nearest(rad_edge,rcor)

print("Coronal radius reset to nearest radial bin edge: ",rcor)

cor_geometry = uml.an_sphere
geopar = [rcor]
omega_cor, disktocor_frac_sph, cortodisk_frac_sph = uml.calc_illumination_fracs(rad,rad_area,cor_geometry,geopar)

cor_geometry = uml.inv_cone

rcor = 10.0
hcorlist = [6.0,15.0,30.0] # Height of corona (for cylindrical or inverted cone coronal shapes)
angle_list = [30.,30.,30.]  # Cone opening angle in degrees
rtoplist = rcor + np.array(hcorlist)*np.tan(np.pi*(np.array(angle_list)/180))
label_list = []
lstylist = ['dashed','dashdot','dotted']
#figfile = 'figs/fdisk2cor_invcone_mono_hcorcompare.pdf'
figfile = None
leg_title = None
disktocor_frac_array = np.zeros((len(hcorlist),len(rad)))

for i, hcorval in enumerate(hcorlist):
    geopar = [rcor,hcorval,rtoplist[i],1000,1000]
    labeltxt = r"$h_{\rm cor}$="+str(round(hcorval))+r" $R_{g}$, $\theta_{\rm cor}=30^{\circ}$"
    label_list.append(labeltxt)
    omega_cor, disktocor_frac_array[i,:], cortodisk_frac = uml.calc_illumination_fracs(rad,rad_area,
                                                                                      cor_geometry,geopar)
    


plot_fdisk2cor(rad,disktocor_frac_sph,disktocor_frac_array,label_list,lstylist,leg_title,figfile)

# %%
rcor = 10.0
hcorlist = [10.0,10.0,10.0] # Height of corona (for cylindrical or inverted cone coronal shapes)
angle_list = [0.,20.,45.]  # Cone opening angle in degrees
rtoplist = rcor + np.array(hcorlist)*np.tan(np.pi*(np.array(angle_list)/180))
label_list = []
lstylist = ['dashed','dashdot','dotted']
#figfile = 'figs/fdisk2cor_invcone_mono_thetacorcompare.pdf'
figfile = None
leg_title = None
disktocor_frac_array = np.zeros((len(hcorlist),len(rad)))

for i, angleval in enumerate(angle_list):
    geopar = [rcor,hcorlist[i],rtoplist[i],1000,1000]
    labeltxt = r"$h_{\rm cor}=10$ $R_{g}$, $\theta_{\rm cor}$="+str(round(angle_list[i]))+r"$^{\circ}$" 
    label_list.append(labeltxt)
    omega_cor, disktocor_frac_array[i,:], cortodisk_frac = uml.calc_illumination_fracs(rad,rad_area,
                                                                                      cor_geometry,geopar)

plot_fdisk2cor(rad,disktocor_frac_sph,disktocor_frac_array,label_list,lstylist,leg_title,figfile)

# %%
# Set up starting parameters:
############################################
### Basic geometry and radial binning: #####
############################################
cor_geometry = uml.inv_cone
rin = 2.0  # Innermost radius for viscous dissipation (ISCO)
rout = 300.0 # Outermost radius for viscous dissipation - best to set large but with smaller rsigmax 
# to make linear rebinned IRFs manageable
nrad = 200 # Number of radial bins for viscous dissipation
rcor = 10.0 # Outer radius of corona and inner radius of blackbody emitting disk
hcor = 10.0 # Height of corona (for cylindrical or inverted cone coronal shapes)
cone_angle = 30.0  # Cone opening angle in degrees
rtop = rcor + hcor*np.tan(np.pi*(cone_angle/180))
print("Coronal top radius : ",rtop)
geopar = [rcor,hcor,rtop,1000,1000]
################################################################################
### 'Timing model' parameters for driving signal generation and propagation ####
################################################################################
rsigmax = 300.0 # Maximum radius for inward-propagating signals to start from
t_scale= 5e-5 # Scaling between Rg/c units and actual time units (e.g. for timing in seconds, this is Rg/c in seconds,
# e.g. 5e-5 for a 10 solar mass BH)
min_deltau_frac = 0.25 # Minimum bin size (fraction of minimum propagation delay across a bin)
disk_tau_par = [100.,0.] # Variability time-scale at radius r is disk_tau_par[0]*((r/rcor)^disk_tau_par[1])*r^1.5
cor_tau_par = [100., 0.] # As disk_tau_par but for signal time-scales generated in the corona
disk_prop_par = [100.,0.] # Radial propagation time delay across a radial bin of width dr at radius r
# is deltau = dr*(disk_prop_par[0]*(r/rcor)^disk_prop_par[1])*sqrt(r)
cor_prop_par = [0., 0.] # As disk_prop_par but for radial propagation delays generated in the corona

lor_model = 'continuous' # Driving signals are split across all radial bins to rsigmax (equivalent to basic Lyubarskii 
                         # model with mdot fluctuations at all radii)
lor_par = [1.0,0.4,0.0] # For continuous model: [q,total_rms_in_disk,total_rms_in_corona], if the last parameter is 
                        # < 0, the total_rms_in_disk is split evenly across corona and disk radii
nirf_mult = 8 # IRF is this (must be power of 2) times bigger than next highest power of 2 bins corresponding to 
#  propagation time from max. signal radius.  Set high enough to ensure entire useful frequency range can be covered.

###########################################################################################
### 'Spectral model' parameters for disk absorbed flux and seed and heating in corona, ####
### photon index dependence on L_s/L_h and choice of energies for power-law fluxes and ####
### observed disk band. ###################################################################
###########################################################################################

disk_abs_frac = 0.7 # Fraction of incident flux on disk which is reprocessed into blackbody emission (= 1-albedo)
heatff_norm = 1.0 # Normalisation parameter for power-law function describing radial dependence of fraction 
# of energy dissipated in coronal flow which goes into heating the corona (heat_frac_flow)
heatff_ind = 0.0 # Index for radial dependence of heat_frac_flow 
seedff_norm = 0.0 # Normalisation parameter for power-law function describing radial dependence of fraction 
# of energy dissipated in coronal flow which goes into internal seed photons (seed_frac_flow)
# should be set to zero if using full energy-dependent model, as assumed internal seed spectrum 
# not yet implemented. Set to < 0 if you require seed_frac_flow = 1.-heat_frac_flow
seedff_ind = 0.0 # Index for radial dependence of seed_frac_flow 
gamma_par = [2.33,0.167] # gamma = gamma_par[0]*(L_s/L_h)^(gamma_par[1])
e_seed = 1.0
# Choose power-law energies for analytical calculation using mono-energetic bands 
# (must be equal or greater than e_seed):
ens_mono = np.array([1.,3.,9.,27.])*e_seed
# Specify pairs of energy bands to use for spectral-timing measurements. Band 0 is the disk, larger indices
# i corresponds to index i-1 in the array of monoenergetic bands for power-law analysis.
encomb = np.array([[2,0],[3,2],[4,3]])
# Out:
# Coronal top radius :  15.773502691896256

# %%
#First set up radial grid
rad_edge = np.logspace(np.log10(rin), np.log10(rout), nrad+1)  # set up radial bin edges
rad = np.sqrt(rad_edge[1:]*rad_edge[:-1])  # Define radial bin centres as geometric mean of bin edges
rad_area = np.pi*(np.square(rad_edge[1:])-np.square(rad_edge[:-1]))

# Now reset coronal outer radius (i.e. disk inner radius) to be at the nearest radial bin edges
rcor, i_rcor = uml.find_nearest(rad_edge,rcor)

disp_frac, seed_frac_flow, heat_frac_flow = \
    uml.calc_dispfrac(rad,rad_area,rin,rcor,seedff_norm,seedff_ind,heatff_norm,heatff_ind) 
# Normalised viscous dissipation and parameters for seed and heating fractions within coronal flow.

# Reset maximum signal radius to nearest radial bin value
rsigmax, i_rsigmax = uml.find_nearest(rad,rsigmax)
print("Coronal radius reset to nearest radial bin edge: ",rcor)
print("Maximum signal radius reset to: ",rsigmax)

# Calculate illumination of corona by disk and vice-versa
omega_cor, disktocor_frac, cortodisk_frac = uml.calc_illumination_fracs(rad,rad_area,cor_geometry,geopar)

print(np.sum(disp_frac[rad>rcor]*disktocor_frac[rad>rcor])/np.sum(disp_frac[rad>rcor]),
      " of the disk flux is intercepted by the corona")
print(np.sum(cortodisk_frac)," of the coronal flux is intercepted by the disk")

# Now calculate radial dependence of timing parameters and calculate propagation delays
tau, lfreq, q, rms = uml.calc_timing_params(rad, i_rsigmax, rcor, i_rcor, t_scale, disk_tau_par, cor_tau_par,\
                                        lor_model, lor_par)

deltau = uml.calc_propagation_params(rad,rad_edge,rcor,disk_prop_par,cor_prop_par)

# Calculate the radially-dependent direct disk, seed photon and coronal heating luminosities
ldisk_disp, lseed_disp, lheat, ldisk_rev, lseed_rev =\
    uml.calc_radial_time_response(rad,rcor,disp_frac,disktocor_frac,cortodisk_frac,seed_frac_flow,heat_frac_flow)


print("Dissipation disk luminosity: ",np.sum(ldisk_disp))
print("Dissipation seed luminosity: ",np.sum(lseed_disp))
print("Coronal heating luminosity: ",np.sum(lheat))
print("Disk luminosity due to heating by corona: ",np.sum(ldisk_rev))
print("Seed luminosity due to heating by corona: ",np.sum(lseed_rev))
print("Total luminosity: ",np.sum(ldisk_disp+lseed_disp+lheat+ldisk_rev+lseed_rev))

# Now correct the reverberation components to correspond to only the thermal reverberation part
ldisk_rev = ldisk_rev*disk_abs_frac
lseed_rev = lseed_rev*disk_abs_frac
# Out:
# Coronal radius reset to nearest radial bin edge:  9.939835534143139
# Maximum signal radius reset to:  296.265462867623
# 0.24681402924048546  of the disk flux is intercepted by the corona
# 0.40436621249209237  of the coronal flux is intercepted by the disk
# Dissipation disk luminosity:  0.3102963057299046
# Dissipation seed luminosity:  0.06056525502386768
# Coronal heating luminosity:  0.35024556865242523
# Disk luminosity due to heating by corona:  0.22615350497881925
# Seed luminosity due to heating by corona:  0.0527393656149833
# Total luminosity:  1.0

# %%
# Calculate IRFs for the mono-energetic case
gamma_mean, gamma_irf, flux_irf_mono, disk_irf_mono, seed_irf_mono =\
                    uml.calc_irfs_mono(gamma_par,e_seed,ens_mono,\
                                ldisk_disp,lseed_disp,lheat,ldisk_rev,lseed_rev)
print("Mean gamma is:", gamma_mean)

# Calculate frequency-dependent spectral-timing products using the mono-energetic calculation
freq, phlag, tlag, psd_ci, psd_ref, mod_sig_psd, irf_nbins, irf_binedgefrac, deltau_scale, dt, nirf,\
        ci_irf, ci_mean, ci_outer =\
        uml.calculate_stprod_mono(nirf_mult,ens_mono,encomb,flux_irf_mono,disk_irf_mono,gamma_irf,
                                deltau,min_deltau_frac,i_rsigmax,lfreq,q,rms,t_scale)

# Carry out simulations of propagating fluctuations through the disk, to check the validity of the 
# model and the effects of increasing the total rms (i.e. checks validity of linear approximation for
# power-law variations)
iseed_start = 1 # Set starting seed for random number generation
nbins = np.amax([2*nirf,65536]) # Number of light curve bins
nsims = 10   # Number of simulations to run
segnbin = np.amax([nirf//4,16384])  # Segment size for timing analysis
print("IRF has ",nirf," bins.")
print("Light curve will be simulated with ",nbins," bins.")
print("Timing products will use a light curve segment size of ",segnbin," bins.")
bfac = 1.05  # Minimum requency binning factor for spectral-timing products
expquery = 'y'  # Should exponentiate the individual radial mdot light curves? (ensures non-negative mdots)
multquery = 'y' # Should multiply radial mdot variations together, rather than add (Lyubarskii model)


bin_freq, bin_psd_ref, bin_psd_referr, bin_psd_ciarr, bin_psd_cierrarr, bin_phlagarr, bin_tlagarr = \
uml.run_simulation(rad,iseed_start,nsims,nbins,expquery,multquery,dt,deltau_scale,nirf,segnbin,bfac,\
                   lfreq,q,rms,gamma_par,e_seed,\
                   ens_mono,encomb,i_rsigmax,irf_nbins,irf_binedgefrac,ldisk_disp,lseed_disp,lheat,\
                   rcor,disktocor_frac,cortodisk_frac,disk_abs_frac)
# Out:
# Mean gamma is: 1.8819005618014089
# #######################################
# Calculating mono-energetic spectral-timing products
# Time bin size dt is:  0.0010000306442932059
# The maximum propagation delay is:  17.215485885700527  and there are  262144  irf bins.
# CI mean, ref mean, CI outer, ref outer :  1.0 0.46860304712263123 0.0 0.0
# Calculated for energies  [2 0]
# CI mean, ref mean, CI outer, ref outer :  1.0 1.0 0.0 0.0
# Calculated for energies  [3 2]
# CI mean, ref mean, CI outer, ref outer :  1.0 1.0 0.0 0.0
# Calculated for energies  [4 3]
# #######################################
# IRF has  262144  bins.
# Light curve will be simulated with  524288  bins.
# Timing products will use a light curve segment size of  65536  bins.
# Minimum and maximum bins:  34428 489860
# Simulating radius  199 , r =  296.265462867623 , deltau =  0.6388011650925339
# Fractional rms of simulated light curve =  0.03020805371695928
# Mdot lengths 524288 524288
# Simulating radius  198 , r =  288.9352775596728 , deltau =  0.6152406398048204
# Fractional rms of simulated light curve =  0.031081139298063686
# Mdot lengths 524288 524288
# Simulating radius  197 , r =  281.7864553310663 , deltau =  0.59254908342668
# Fractional rms of simulated light curve =  0.034512691651694766
# Mdot lengths 524288 524288
# Simulating radius  196 , r =  274.8145089055388 , deltau =  0.5706944462920335
# Fractional rms of simulated light curve =  0.03379107382184336
# Mdot lengths 524288 524288
# Simulating radius  195 , r =  268.0150620307912 , deltau =  0.54964586080384
# Fractional rms of simulated light curve =  0.03597164669705831
# Mdot lengths 524288 524288
# Simulating radius  194 , r =  261.3838467315402 , deltau =  0.5293735978362983
# Fractional rms of simulated light curve =  0.036085972549106615
# Mdot lengths 524288 524288
# Simulating radius  193 , r =  254.91670063053425 , deltau =  0.5098490247452949
# Fractional rms of simulated light curve =  0.03185600763739692
# Mdot lengths 524288 524288
# Simulating radius  192 , r =  248.6095643358524 , deltau =  0.49104456492771725
# Fractional rms of simulated light curve =  0.03714783401896214
# Mdot lengths 524288 524288
# Simulating radius  191 , r =  242.45847889284602 , deltau =  0.47293365887184347
# Fractional rms of simulated light curve =  0.03185575043708078
# Mdot lengths 524288 524288
# Simulating radius  190 , r =  236.4595832991251 , deltau =  0.4554907266448252
# Fractional rms of simulated light curve =  0.034373847123483674
# Mdot lengths 524288 524288
# Simulating radius  189 , r =  230.60911208102783 , deltau =  0.4386911317632848
# Fractional rms of simulated light curve =  0.03464357064744971
# Mdot lengths 524288 524288
# Simulating radius  188 , r =  224.90339293005442 , deltau =  0.4225111463966203
# Fractional rms of simulated light curve =  0.03541317797771207
# Mdot lengths 524288 524288
# Simulating radius  187 , r =  219.3388443977787 , deltau =  0.4069279178538767
# Fractional rms of simulated light curve =  0.03245436612068698
# Mdot lengths 524288 524288
# Simulating radius  186 , r =  213.91197364779265 , deltau =  0.39191943630631476
# Fractional rms of simulated light curve =  0.03661095519494922
# Mdot lengths 524288 524288
# Simulating radius  185 , r =  208.6193742632727 , deltau =  0.3774645037006374
# Fractional rms of simulated light curve =  0.03497592689608631
# Mdot lengths 524288 524288
# Simulating radius  184 , r =  203.45772410879044 , deltau =  0.3635427038189067
# Fractional rms of simulated light curve =  0.03481735126509824
# Mdot lengths 524288 524288
# Simulating radius  183 , r =  198.42378324502656 , deltau =  0.3501343734423519
# Fractional rms of simulated light curve =  0.028050357528073232
# Mdot lengths 524288 524288
# Simulating radius  182 , r =  193.5143918950787 , deltau =  0.337220574579173
# Fractional rms of simulated light curve =  0.03277393240813718
# Mdot lengths 524288 524288
# Simulating radius  181 , r =  188.7264684610872 , deltau =  0.3247830677162055
# Fractional rms of simulated light curve =  0.0357410315134344
# Mdot lengths 524288 524288
# Simulating radius  180 , r =  184.05700758993285 , deltau =  0.31280428605755994
# Fractional rms of simulated light curve =  0.03554503416960677
# Mdot lengths 524288 524288
# Simulating radius  179 , r =  179.50307828679345 , deltau =  0.30126731071297513
# Fractional rms of simulated light curve =  0.03557448155205406
# Mdot lengths 524288 524288
# Simulating radius  178 , r =  175.06182207537475 , deltau =  0.29015584680169876
# Fractional rms of simulated light curve =  0.03288843277233333
# Mdot lengths 524288 524288
# Simulating radius  177 , r =  170.73045120365998 , deltau =  0.2794542004373809
# Fractional rms of simulated light curve =  0.03141192776415977
# Mdot lengths 524288 524288
# Simulating radius  176 , r =  166.5062468940541 , deltau =  0.26914725656195787
# Fractional rms of simulated light curve =  0.033610998916800035
# Mdot lengths 524288 524288
# Simulating radius  175 , r =  162.38655763682172 , deltau =  0.25922045759719065
# Fractional rms of simulated light curve =  0.03366613506681502
# Mdot lengths 524288 524288
# Simulating radius  174 , r =  158.36879752574893 , deltau =  0.24965978288328994
# Fractional rms of simulated light curve =  0.03265724173313109
# Mdot lengths 524288 524288
# Simulating radius  173 , r =  154.45044463498462 , deltau =  0.24045172887623445
# Fractional rms of simulated light curve =  0.03466772170560433
# Mdot lengths 524288 524288
# Simulating radius  172 , r =  150.6290394360411 , deltau =  0.23158329007520456
# Fractional rms of simulated light curve =  0.03310678837778753
# Mdot lengths 524288 524288
# Simulating radius  171 , r =  146.902183253962 , deltau =  0.22304194065352737
# Fractional rms of simulated light curve =  0.03344589675105791
# Mdot lengths 524288 524288
# Simulating radius  170 , r =  143.26753676168707 , deltau =  0.21481561676725933
# Fractional rms of simulated light curve =  0.03503173998129656
# Mdot lengths 524288 524288
# Simulating radius  169 , r =  139.7228185116696 , deltau =  0.20689269951599318
# Fractional rms of simulated light curve =  0.0353715005316929
# Mdot lengths 524288 524288
# Simulating radius  168 , r =  136.26580350382423 , deltau =  0.1992619985324127
# Fractional rms of simulated light curve =  0.034634481088579645
# Mdot lengths 524288 524288
# Simulating radius  167 , r =  132.8943217889067 , deltau =  0.1919127361768645
# Fractional rms of simulated light curve =  0.029993714994846436
# Mdot lengths 524288 524288
# Simulating radius  166 , r =  129.60625710644885 , deltau =  0.18483453231498978
# Fractional rms of simulated light curve =  0.03349118937445285
# Mdot lengths 524288 524288
# Simulating radius  165 , r =  126.39954555639345 , deltau =  0.1780173896568195
# Fractional rms of simulated light curve =  0.03363338513865318
# Mdot lengths 524288 524288
# Simulating radius  164 , r =  123.27217430359555 , deltau =  0.171451679636465
# Fractional rms of simulated light curve =  0.03544375165626765
# Mdot lengths 524288 524288
# Simulating radius  163 , r =  120.22218031437706 , deltau =  0.16512812881278052
# Fractional rms of simulated light curve =  0.03625997175023415
# Mdot lengths 524288 524288
# Simulating radius  162 , r =  117.24764912434108 , deltau =  0.15903780577143967
# Fractional rms of simulated light curve =  0.034115425701203676
# Mdot lengths 524288 524288
# Simulating radius  161 , r =  114.34671363667348 , deltau =  0.15317210851016821
# Fractional rms of simulated light curve =  0.03507921589858504
# Mdot lengths 524288 524288
# Simulating radius  160 , r =  111.51755295017645 , deltau =  0.1475227522892864
# Fractional rms of simulated light curve =  0.03577489845944475
# Mdot lengths 524288 524288
# Simulating radius  159 , r =  108.75839121629862 , deltau =  0.1420817579302446
# Fractional rms of simulated light curve =  0.03573385222388355
# Mdot lengths 524288 524288
# Simulating radius  158 , r =  106.06749652444509 , deltau =  0.13684144054579914
# Fractional rms of simulated light curve =  0.03368387511666242
# Mdot lengths 524288 524288
# Simulating radius  157 , r =  103.44317981486644 , deltau =  0.13179439868589204
# Fractional rms of simulated light curve =  0.03375013252057589
# Mdot lengths 524288 524288
# Simulating radius  156 , r =  100.88379381844541 , deltau =  0.12693350388372335
# Fractional rms of simulated light curve =  0.031894382572062986
# Mdot lengths 524288 524288
# Simulating radius  155 , r =  98.38773202271507 , deltau =  0.12225189058755077
# Fractional rms of simulated light curve =  0.03434999851867866
# Mdot lengths 524288 524288
# Simulating radius  154 , r =  95.95342766345976 , deltau =  0.11774294646369836
# Fractional rms of simulated light curve =  0.03342419367114409
# Mdot lengths 524288 524288
# Simulating radius  153 , r =  93.57935274126596 , deltau =  0.11340030305727426
# Fractional rms of simulated light curve =  0.03225510915565966
# Mdot lengths 524288 524288
# Simulating radius  152 , r =  91.26401706240549 , deltau =  0.10921782679734852
# Fractional rms of simulated light curve =  0.03506548661753298
# Mdot lengths 524288 524288
# Simulating radius  151 , r =  89.00596730344901 , deltau =  0.10518961033385404
# Fractional rms of simulated light curve =  0.03414621158628231
# Mdot lengths 524288 524288
# Simulating radius  150 , r =  86.80378609902304 , deltau =  0.10130996419401778
# Fractional rms of simulated light curve =  0.03399238071204599
# Mdot lengths 524288 524288
# Simulating radius  149 , r =  84.65609115213746 , deltau =  0.09757340874653274
# Fractional rms of simulated light curve =  0.032870576367935646
# Mdot lengths 524288 524288
# Simulating radius  148 , r =  82.56153436652534 , deltau =  0.09397466646207525
# Fractional rms of simulated light curve =  0.03430337975923496
# Mdot lengths 524288 524288
# Simulating radius  147 , r =  80.51880100045038 , deltau =  0.09050865445932489
# Fractional rms of simulated light curve =  0.03427168417677898
# Mdot lengths 524288 524288
# Simulating radius  146 , r =  78.52660884145075 , deltau =  0.08717047732585828
# Fractional rms of simulated light curve =  0.03302560678680144
# Mdot lengths 524288 524288
# Simulating radius  145 , r =  76.58370740150144 , deltau =  0.08395542020385188
# Fractional rms of simulated light curve =  0.03661712535417036
# Mdot lengths 524288 524288
# Simulating radius  144 , r =  74.68887713208973 , deltau =  0.08085894213079839
# Fractional rms of simulated light curve =  0.034337960831623986
# Mdot lengths 524288 524288
# Simulating radius  143 , r =  72.8409286587114 , deltau =  0.0778766696258118
# Fractional rms of simulated light curve =  0.03275310376073164
# Mdot lengths 524288 524288
# Simulating radius  142 , r =  71.03870203430697 , deltau =  0.07500439051252329
# Fractional rms of simulated light curve =  0.03411507381594031
# Mdot lengths 524288 524288
# Simulating radius  141 , r =  69.28106601116914 , deltau =  0.07223804796976682
# Fractional rms of simulated light curve =  0.03535947879310818
# Mdot lengths 524288 524288
# Simulating radius  140 , r =  67.5669173308651 , deltau =  0.06957373480171009
# Fractional rms of simulated light curve =  0.03471774424997879
# Mdot lengths 524288 524288
# Simulating radius  139 , r =  65.8951800317271 , deltau =  0.06700768791931852
# Fractional rms of simulated light curve =  0.032722364926864846
# Mdot lengths 524288 524288
# Simulating radius  138 , r =  64.26480477347728 , deltau =  0.06453628302533417
# Fractional rms of simulated light curve =  0.03414073265812196
# Mdot lengths 524288 524288
# Simulating radius  137 , r =  62.67476817856267 , deltau =  0.06215602949531512
# Fractional rms of simulated light curve =  0.032072769175798425
# Mdot lengths 524288 524288
# Simulating radius  136 , r =  61.124072189786666 , deltau =  0.05986356544745353
# Fractional rms of simulated light curve =  0.03385120324643724
# Mdot lengths 524288 524288
# Simulating radius  135 , r =  59.61174344383406 , deltau =  0.0576556529942376
# Fractional rms of simulated light curve =  0.03396476746611055
# Mdot lengths 524288 524288
# Simulating radius  134 , r =  58.136832660296214 , deltau =  0.055529173669248796
# Fractional rms of simulated light curve =  0.034430768295358266
# Mdot lengths 524288 524288
# Simulating radius  133 , r =  56.698414045813024 , deltau =  0.053481124022611834
# Fractional rms of simulated light curve =  0.034060682462811034
# Mdot lengths 524288 524288
# Simulating radius  132 , r =  55.29558471295757 , deltau =  0.05150861137892253
# Fractional rms of simulated light curve =  0.034554970491348945
# Mdot lengths 524288 524288
# Simulating radius  131 , r =  53.9274641134986 , deltau =  0.049608849751607266
# Fractional rms of simulated light curve =  0.03478501725588004
# Mdot lengths 524288 524288
# Simulating radius  130 , r =  52.59319348568531 , deltau =  0.0477791559079885
# Fractional rms of simulated light curve =  0.03565790252256931
# Mdot lengths 524288 524288
# Simulating radius  129 , r =  51.29193531520727 , deltau =  0.04601694557947252
# Fractional rms of simulated light curve =  0.03405115680585317
# Mdot lengths 524288 524288
# Simulating radius  128 , r =  50.022872809491375 , deltau =  0.04431972981151082
# Fractional rms of simulated light curve =  0.03648703796548284
# Mdot lengths 524288 524288
# Simulating radius  127 , r =  48.78520938500562 , deltau =  0.042685111448195416
# Fractional rms of simulated light curve =  0.033845084641275905
# Mdot lengths 524288 524288
# Simulating radius  126 , r =  47.57816816724805 , deltau =  0.041110781746499486
# Fractional rms of simulated light curve =  0.03430772361579812
# Mdot lengths 524288 524288
# Simulating radius  125 , r =  46.400991503106894 , deltau =  0.0395945171153992
# Fractional rms of simulated light curve =  0.033734368743664034
# Mdot lengths 524288 524288
# Simulating radius  124 , r =  45.252940485285855 , deltau =  0.03813417597526439
# Fractional rms of simulated light curve =  0.034372087855195375
# Mdot lengths 524288 524288
# Simulating radius  123 , r =  44.13329448849613 , deltau =  0.036727695733074744
# Fractional rms of simulated light curve =  0.034342876944058014
# Mdot lengths 524288 524288
# Simulating radius  122 , r =  43.041350717123876 , deltau =  0.03537308986921066
# Fractional rms of simulated light curve =  0.0343335293936813
# Mdot lengths 524288 524288
# Simulating radius  121 , r =  41.9764237640893 , deltau =  0.034068445131678476
# Fractional rms of simulated light curve =  0.03533744015077124
# Mdot lengths 524288 524288
# Simulating radius  120 , r =  40.937845180620386 , deltau =  0.03281191883382626
# Fractional rms of simulated light curve =  0.03460444278477552
# Mdot lengths 524288 524288
# Simulating radius  119 , r =  39.924963056671274 , deltau =  0.03160173625172404
# Fractional rms of simulated light curve =  0.03233736200305752
# Mdot lengths 524288 524288
# Simulating radius  118 , r =  38.93714161172198 , deltau =  0.030436188117531435
# Fractional rms of simulated light curve =  0.034386667292638944
# Mdot lengths 524288 524288
# Simulating radius  117 , r =  37.97376079570242 , deltau =  0.029313628205324495
# Fractional rms of simulated light curve =  0.03426878718743442
# Mdot lengths 524288 524288
# Simulating radius  116 , r =  37.03421589979044 , deltau =  0.028232471005955065
# Fractional rms of simulated light curve =  0.033232589409592804
# Mdot lengths 524288 524288
# Simulating radius  115 , r =  36.117917176839406 , deltau =  0.027191189487669524
# Fractional rms of simulated light curve =  0.03352770134409069
# Mdot lengths 524288 524288
# Simulating radius  114 , r =  35.22428947119717 , deltau =  0.02618831293932551
# Fractional rms of simulated light curve =  0.033438103826149264
# Mdot lengths 524288 524288
# Simulating radius  113 , r =  34.352771857684026 , deltau =  0.025222424893145117
# Fractional rms of simulated light curve =  0.035047439636289944
# Mdot lengths 524288 524288
# Simulating radius  112 , r =  33.502817289503135 , deltau =  0.024292161124096455
# Fractional rms of simulated light curve =  0.03373458454290155
# Mdot lengths 524288 524288
# Simulating radius  111 , r =  32.67389225486219 , deltau =  0.023396207723050243
# Fractional rms of simulated light curve =  0.034220490773667206
# Mdot lengths 524288 524288
# Simulating radius  110 , r =  31.865476442091083 , deltau =  0.02253329924101041
# Fractional rms of simulated light curve =  0.03417837593729923
# Mdot lengths 524288 524288
# Simulating radius  109 , r =  31.077062413045056 , deltau =  0.02170221690178883
# Fractional rms of simulated light curve =  0.03458284905504204
# Mdot lengths 524288 524288
# Simulating radius  108 , r =  30.308155284588636 , deltau =  0.02090178688059529
# Fractional rms of simulated light curve =  0.0351265798412256
# Mdot lengths 524288 524288
# Simulating radius  107 , r =  29.55827241796022 , deltau =  0.02013087864612648
# Fractional rms of simulated light curve =  0.03363831714766907
# Mdot lengths 524288 524288
# Simulating radius  106 , r =  28.826943115822377 , deltau =  0.01938840336379537
# Fractional rms of simulated light curve =  0.03472851892775535
# Mdot lengths 524288 524288
# Simulating radius  105 , r =  28.11370832680773 , deltau =  0.018673312357856697
# Fractional rms of simulated light curve =  0.03401235975583007
# Mdot lengths 524288 524288
# Simulating radius  104 , r =  27.41812035737491 , deltau =  0.017984595630253005
# Fractional rms of simulated light curve =  0.03452206526210403
# Mdot lengths 524288 524288
# Simulating radius  103 , r =  26.739742590793853 , deltau =  0.017321280434085415
# Fractional rms of simulated light curve =  0.0357258365810243
# Mdot lengths 524288 524288
# Simulating radius  102 , r =  26.078149213083847 , deltau =  0.01668242989970467
# Fractional rms of simulated light curve =  0.03429742103497565
# Mdot lengths 524288 524288
# Simulating radius  101 , r =  25.43292494573246 , deltau =  0.01606714171146987
# Fractional rms of simulated light curve =  0.03419112908901359
# Mdot lengths 524288 524288
# Simulating radius  100 , r =  24.803664785027504 , deltau =  0.015474546833313447
# Fractional rms of simulated light curve =  0.03428374792988291
# Mdot lengths 524288 524288
# Simulating radius  99 , r =  24.18997374783844 , deltau =  0.01490380828131224
# Fractional rms of simulated light curve =  0.034872281928047075
# Mdot lengths 524288 524288
# Simulating radius  98 , r =  23.591466623687634 , deltau =  0.01435411994152372
# Fractional rms of simulated light curve =  0.03439394140540297
# Mdot lengths 524288 524288
# Simulating radius  97 , r =  23.007767732955905 , deltau =  0.013824705431429917
# Fractional rms of simulated light curve =  0.03462136310607062
# Mdot lengths 524288 524288
# Simulating radius  96 , r =  22.43851069107046 , deltau =  0.013314817003369716
# Fractional rms of simulated light curve =  0.0349856091819062
# Mdot lengths 524288 524288
# Simulating radius  95 , r =  21.883338178527342 , deltau =  0.012823734488415992
# Fractional rms of simulated light curve =  0.03404570962211613
# Mdot lengths 524288 524288
# Simulating radius  94 , r =  21.341901716603935 , deltau =  0.012350764279207057
# Fractional rms of simulated light curve =  0.03437808733771101
# Mdot lengths 524288 524288
# Simulating radius  93 , r =  20.813861448620795 , deltau =  0.01189523835028926
# Fractional rms of simulated light curve =  0.03497254710327047
# Mdot lengths 524288 524288
# Simulating radius  92 , r =  20.298885926615505 , deltau =  0.011456513314597615
# Fractional rms of simulated light curve =  0.03425595767526242
# Mdot lengths 524288 524288
# Simulating radius  91 , r =  19.796651903294602 , deltau =  0.011033969514731177
# Fractional rms of simulated light curve =  0.03446049530852465
# Mdot lengths 524288 524288
# Simulating radius  90 , r =  19.30684412913304 , deltau =  0.010627010147746061
# Fractional rms of simulated light curve =  0.03433241070467254
# Mdot lengths 524288 524288
# Simulating radius  89 , r =  18.829155154493797 , deltau =  0.010235060422228028
# Fractional rms of simulated light curve =  0.03405778639350322
# Mdot lengths 524288 524288
# Simulating radius  88 , r =  18.363285136643434 , deltau =  0.00985756674645511
# Fractional rms of simulated light curve =  0.03458298487797085
# Mdot lengths 524288 524288
# Simulating radius  87 , r =  17.908941651542474 , deltau =  0.009493995946499984
# Fractional rms of simulated light curve =  0.03432263714252823
# Mdot lengths 524288 524288
# Simulating radius  86 , r =  17.465839510292444 , deltau =  0.009143834513174664
# Fractional rms of simulated light curve =  0.03401853261284179
# Mdot lengths 524288 524288
# Simulating radius  85 , r =  17.03370058012437 , deltau =  0.00880658787674612
# Fractional rms of simulated light curve =  0.033702042249821755
# Mdot lengths 524288 524288
# Simulating radius  84 , r =  16.612253609816396 , deltau =  0.008481779708404089
# Fractional rms of simulated light curve =  0.034031264652328024
# Mdot lengths 524288 524288
# Simulating radius  83 , r =  16.201234059430842 , deltau =  0.00816895124749262
# Fractional rms of simulated light curve =  0.03405220496887295
# Mdot lengths 524288 524288
# Simulating radius  82 , r =  15.800383934263985 , deltau =  0.007867660653552414
# Fractional rms of simulated light curve =  0.034520597821521594
# Mdot lengths 524288 524288
# Simulating radius  81 , r =  15.409451622904204 , deltau =  0.00757748238226494
# Fractional rms of simulated light curve =  0.03417819862243893
# Mdot lengths 524288 524288
# Simulating radius  80 , r =  15.028191739296872 , deltau =  0.007298006584410682
# Fractional rms of simulated light curve =  0.03430729530164599
# Mdot lengths 524288 524288
# Simulating radius  79 , r =  14.65636496871689 , deltau =  0.007028838526996867
# Fractional rms of simulated light curve =  0.034140315859151914
# Mdot lengths 524288 524288
# Simulating radius  78 , r =  14.293737917552141 , deltau =  0.006769598035733192
# Fractional rms of simulated light curve =  0.034548950276220666
# Mdot lengths 524288 524288
# Simulating radius  77 , r =  13.940082966803637 , deltau =  0.006519918958073314
# Fractional rms of simulated light curve =  0.03447660574221267
# Mdot lengths 524288 524288
# Simulating radius  76 , r =  13.595178129210302 , deltau =  0.006279448646058267
# Fractional rms of simulated light curve =  0.03426023400685432
# Mdot lengths 524288 524288
# Simulating radius  75 , r =  13.25880690990881 , deltau =  0.006047847458235072
# Fractional rms of simulated light curve =  0.03430839569905597
# Mdot lengths 524288 524288
# Simulating radius  74 , r =  12.93075817054094 , deltau =  0.005824788279945822
# Fractional rms of simulated light curve =  0.0346055296593113
# Mdot lengths 524288 524288
# Simulating radius  73 , r =  12.610825996723202 , deltau =  0.005609956061308276
# Fractional rms of simulated light curve =  0.034129337235124554
# Mdot lengths 524288 524288
# Simulating radius  72 , r =  12.298809568795516 , deltau =  0.005403047372238892
# Fractional rms of simulated light curve =  0.034320881692362144
# Mdot lengths 524288 524288
# Simulating radius  71 , r =  11.994513035767822 , deltau =  0.005203769973886329
# Fractional rms of simulated light curve =  0.03406779831355
# Mdot lengths 524288 524288
# Simulating radius  70 , r =  11.697745392385485 , deltau =  0.00501184240587171
# Fractional rms of simulated light curve =  0.034166428383175594
# Mdot lengths 524288 524288
# Simulating radius  69 , r =  11.408320359236347 , deltau =  0.004826993588753066
# Fractional rms of simulated light curve =  0.03425316482181188
# Mdot lengths 524288 524288
# Simulating radius  68 , r =  11.126056265824184 , deltau =  0.00464896244115038
# Fractional rms of simulated light curve =  0.03451920781500443
# Mdot lengths 524288 524288
# Simulating radius  67 , r =  10.850775936535134 , deltau =  0.0044774975109942786
# Fractional rms of simulated light curve =  0.034121900958235286
# Mdot lengths 524288 524288
# Simulating radius  66 , r =  10.582306579425529 , deltau =  0.00431235662037293
# Fractional rms of simulated light curve =  0.03372979883844295
# Mdot lengths 524288 524288
# Simulating radius  65 , r =  10.320479677761364 , deltau =  0.004153306523479057
# Fractional rms of simulated light curve =  0.03427353611321787
# Mdot lengths 524288 524288
# Simulating radius  64 , r =  10.065130884241253 , deltau =  0.0040001225771728235
# Fractional rms of simulated light curve =  0.03438236607059892
# Mdot lengths 524288 524288
# Simulating radius  63 , r =  9.816099917836546 , deltau =  0.0
# Mdot lengths 524288 524288
# Simulated  1  light curves
# rms values, disk disp:  0.07268163622692532  seed disp:  0.022070753732805405  heat:  0.14864664919002113
# disk due to heating:  0.06495147629581892  seed due to heating:  0.015146790035020393
# Total mean luminosity (absorption corrected):  1.0030323387917948
# Simulating radius  199 , r =  296.265462867623 , deltau =  0.6388011650925339
# Fractional rms of simulated light curve =  0.034501640766800006
# Mdot lengths 524288 524288
# Simulating radius  198 , r =  288.9352775596728 , deltau =  0.6152406398048204
# Fractional rms of simulated light curve =  0.030679304440690728
# Mdot lengths 524288 524288
# Simulating radius  197 , r =  281.7864553310663 , deltau =  0.59254908342668
# Fractional rms of simulated light curve =  0.033629452111167454
# Mdot lengths 524288 524288
# Simulating radius  196 , r =  274.8145089055388 , deltau =  0.5706944462920335
# Fractional rms of simulated light curve =  0.03616852983241564
# Mdot lengths 524288 524288
# Simulating radius  195 , r =  268.0150620307912 , deltau =  0.54964586080384
# Fractional rms of simulated light curve =  0.03292277882103465
# Mdot lengths 524288 524288
# Simulating radius  194 , r =  261.3838467315402 , deltau =  0.5293735978362983
# Fractional rms of simulated light curve =  0.03710714018119706
# Mdot lengths 524288 524288
# Simulating radius  193 , r =  254.91670063053425 , deltau =  0.5098490247452949
# Fractional rms of simulated light curve =  0.037883412946029024
# Mdot lengths 524288 524288
# Simulating radius  192 , r =  248.6095643358524 , deltau =  0.49104456492771725
# Fractional rms of simulated light curve =  0.036166223842434085
# Mdot lengths 524288 524288
# Simulating radius  191 , r =  242.45847889284602 , deltau =  0.47293365887184347
# Fractional rms of simulated light curve =  0.0335873046077137
# Mdot lengths 524288 524288
# Simulating radius  190 , r =  236.4595832991251 , deltau =  0.4554907266448252
# Fractional rms of simulated light curve =  0.03337096473577993
# Mdot lengths 524288 524288
# Simulating radius  189 , r =  230.60911208102783 , deltau =  0.4386911317632848
# Fractional rms of simulated light curve =  0.03829430200277457
# Mdot lengths 524288 524288
# Simulating radius  188 , r =  224.90339293005442 , deltau =  0.4225111463966203
# Fractional rms of simulated light curve =  0.034970817001677805
# Mdot lengths 524288 524288
# Simulating radius  187 , r =  219.3388443977787 , deltau =  0.4069279178538767
# Fractional rms of simulated light curve =  0.03440745903725474
# Mdot lengths 524288 524288
# Simulating radius  186 , r =  213.91197364779265 , deltau =  0.39191943630631476
# Fractional rms of simulated light curve =  0.0333327643623224
# Mdot lengths 524288 524288
# Simulating radius  185 , r =  208.6193742632727 , deltau =  0.3774645037006374
# Fractional rms of simulated light curve =  0.03389032586899067
# Mdot lengths 524288 524288
# Simulating radius  184 , r =  203.45772410879044 , deltau =  0.3635427038189067
# Fractional rms of simulated light curve =  0.03254188695892787
# Mdot lengths 524288 524288
# Simulating radius  183 , r =  198.42378324502656 , deltau =  0.3501343734423519
# Fractional rms of simulated light curve =  0.03512834750238517
# Mdot lengths 524288 524288
# Simulating radius  182 , r =  193.5143918950787 , deltau =  0.337220574579173
# Fractional rms of simulated light curve =  0.03306946245668531
# Mdot lengths 524288 524288
# Simulating radius  181 , r =  188.7264684610872 , deltau =  0.3247830677162055
# Fractional rms of simulated light curve =  0.03685861029949012
# Mdot lengths 524288 524288
# Simulating radius  180 , r =  184.05700758993285 , deltau =  0.31280428605755994
# Fractional rms of simulated light curve =  0.034475396025133866
# Mdot lengths 524288 524288
# Simulating radius  179 , r =  179.50307828679345 , deltau =  0.30126731071297513
# Fractional rms of simulated light curve =  0.03868019967582125
# Mdot lengths 524288 524288
# Simulating radius  178 , r =  175.06182207537475 , deltau =  0.29015584680169876
# Fractional rms of simulated light curve =  0.03145501694791953
# Mdot lengths 524288 524288
# Simulating radius  177 , r =  170.73045120365998 , deltau =  0.2794542004373809
# Fractional rms of simulated light curve =  0.03354825507607657
# Mdot lengths 524288 524288
# Simulating radius  176 , r =  166.5062468940541 , deltau =  0.26914725656195787
# Fractional rms of simulated light curve =  0.03469064081702987
# Mdot lengths 524288 524288
# Simulating radius  175 , r =  162.38655763682172 , deltau =  0.25922045759719065
# Fractional rms of simulated light curve =  0.037441221361923786
# Mdot lengths 524288 524288
# Simulating radius  174 , r =  158.36879752574893 , deltau =  0.24965978288328994
# Fractional rms of simulated light curve =  0.03249096162499
# Mdot lengths 524288 524288
# Simulating radius  173 , r =  154.45044463498462 , deltau =  0.24045172887623445
# Fractional rms of simulated light curve =  0.03456079803945398
# Mdot lengths 524288 524288
# Simulating radius  172 , r =  150.6290394360411 , deltau =  0.23158329007520456
# Fractional rms of simulated light curve =  0.03610158069255537
# Mdot lengths 524288 524288
# Simulating radius  171 , r =  146.902183253962 , deltau =  0.22304194065352737
# Fractional rms of simulated light curve =  0.03518692000335418
# Mdot lengths 524288 524288
# Simulating radius  170 , r =  143.26753676168707 , deltau =  0.21481561676725933
# Fractional rms of simulated light curve =  0.034992522346902574
# Mdot lengths 524288 524288
# Simulating radius  169 , r =  139.7228185116696 , deltau =  0.20689269951599318
# Fractional rms of simulated light curve =  0.035715709655928095
# Mdot lengths 524288 524288
# Simulating radius  168 , r =  136.26580350382423 , deltau =  0.1992619985324127
# Fractional rms of simulated light curve =  0.03239840086524737
# Mdot lengths 524288 524288
# Simulating radius  167 , r =  132.8943217889067 , deltau =  0.1919127361768645
# Fractional rms of simulated light curve =  0.035141686349775186
# Mdot lengths 524288 524288
# Simulating radius  166 , r =  129.60625710644885 , deltau =  0.18483453231498978
# Fractional rms of simulated light curve =  0.03745790477547351
# Mdot lengths 524288 524288
# Simulating radius  165 , r =  126.39954555639345 , deltau =  0.1780173896568195
# Fractional rms of simulated light curve =  0.0320551268769289
# Mdot lengths 524288 524288
# Simulating radius  164 , r =  123.27217430359555 , deltau =  0.171451679636465
# Fractional rms of simulated light curve =  0.033662076754718544
# Mdot lengths 524288 524288
# Simulating radius  163 , r =  120.22218031437706 , deltau =  0.16512812881278052
# Fractional rms of simulated light curve =  0.03472667659424151
# Mdot lengths 524288 524288
# Simulating radius  162 , r =  117.24764912434108 , deltau =  0.15903780577143967
# Fractional rms of simulated light curve =  0.03548165818173044
# Mdot lengths 524288 524288
# Simulating radius  161 , r =  114.34671363667348 , deltau =  0.15317210851016821
# Fractional rms of simulated light curve =  0.03274582147860032
# Mdot lengths 524288 524288
# Simulating radius  160 , r =  111.51755295017645 , deltau =  0.1475227522892864
# Fractional rms of simulated light curve =  0.03384368403894613
# Mdot lengths 524288 524288
# Simulating radius  159 , r =  108.75839121629862 , deltau =  0.1420817579302446
# Fractional rms of simulated light curve =  0.033666828881994536
# Mdot lengths 524288 524288
# Simulating radius  158 , r =  106.06749652444509 , deltau =  0.13684144054579914
# Fractional rms of simulated light curve =  0.03395691813522279
# Mdot lengths 524288 524288
# Simulating radius  157 , r =  103.44317981486644 , deltau =  0.13179439868589204
# Fractional rms of simulated light curve =  0.033949550047765044
# Mdot lengths 524288 524288
# Simulating radius  156 , r =  100.88379381844541 , deltau =  0.12693350388372335
# Fractional rms of simulated light curve =  0.035758561013698856
# Mdot lengths 524288 524288
# Simulating radius  155 , r =  98.38773202271507 , deltau =  0.12225189058755077
# Fractional rms of simulated light curve =  0.03505726548723283
# Mdot lengths 524288 524288
# Simulating radius  154 , r =  95.95342766345976 , deltau =  0.11774294646369836
# Fractional rms of simulated light curve =  0.03483358838641276
# Mdot lengths 524288 524288
# Simulating radius  153 , r =  93.57935274126596 , deltau =  0.11340030305727426
# Fractional rms of simulated light curve =  0.03490495413263832
# Mdot lengths 524288 524288
# Simulating radius  152 , r =  91.26401706240549 , deltau =  0.10921782679734852
# Fractional rms of simulated light curve =  0.03172118984744243
# Mdot lengths 524288 524288
# Simulating radius  151 , r =  89.00596730344901 , deltau =  0.10518961033385404
# Fractional rms of simulated light curve =  0.03275741912646652
# Mdot lengths 524288 524288
# Simulating radius  150 , r =  86.80378609902304 , deltau =  0.10130996419401778
# Fractional rms of simulated light curve =  0.03405896284120927
# Mdot lengths 524288 524288
# Simulating radius  149 , r =  84.65609115213746 , deltau =  0.09757340874653274
# Fractional rms of simulated light curve =  0.03383967230902298
# Mdot lengths 524288 524288
# Simulating radius  148 , r =  82.56153436652534 , deltau =  0.09397466646207525
# Fractional rms of simulated light curve =  0.03649266067414266
# Mdot lengths 524288 524288
# Simulating radius  147 , r =  80.51880100045038 , deltau =  0.09050865445932489
# Fractional rms of simulated light curve =  0.03287615002774733
# Mdot lengths 524288 524288
# Simulating radius  146 , r =  78.52660884145075 , deltau =  0.08717047732585828
# Fractional rms of simulated light curve =  0.034609640724912245
# Mdot lengths 524288 524288
# Simulating radius  145 , r =  76.58370740150144 , deltau =  0.08395542020385188
# Fractional rms of simulated light curve =  0.0340351014031752
# Mdot lengths 524288 524288
# Simulating radius  144 , r =  74.68887713208973 , deltau =  0.08085894213079839
# Fractional rms of simulated light curve =  0.035940834544384556
# Mdot lengths 524288 524288
# Simulating radius  143 , r =  72.8409286587114 , deltau =  0.0778766696258118
# Fractional rms of simulated light curve =  0.034921829514201516
# Mdot lengths 524288 524288
# Simulating radius  142 , r =  71.03870203430697 , deltau =  0.07500439051252329
# Fractional rms of simulated light curve =  0.03442979581112202
# Mdot lengths 524288 524288
# Simulating radius  141 , r =  69.28106601116914 , deltau =  0.07223804796976682
# Fractional rms of simulated light curve =  0.03335466644809268
# Mdot lengths 524288 524288
# Simulating radius  140 , r =  67.5669173308651 , deltau =  0.06957373480171009
# Fractional rms of simulated light curve =  0.03473224184136781
# Mdot lengths 524288 524288
# Simulating radius  139 , r =  65.8951800317271 , deltau =  0.06700768791931852
# Fractional rms of simulated light curve =  0.03434718693643621
# Mdot lengths 524288 524288
# Simulating radius  138 , r =  64.26480477347728 , deltau =  0.06453628302533417
# Fractional rms of simulated light curve =  0.03457849242021805
# Mdot lengths 524288 524288
# Simulating radius  137 , r =  62.67476817856267 , deltau =  0.06215602949531512
# Fractional rms of simulated light curve =  0.034399452500371054
# Mdot lengths 524288 524288
# Simulating radius  136 , r =  61.124072189786666 , deltau =  0.05986356544745353
# Fractional rms of simulated light curve =  0.03520653632182518
# Mdot lengths 524288 524288
# Simulating radius  135 , r =  59.61174344383406 , deltau =  0.0576556529942376
# Fractional rms of simulated light curve =  0.0341411372038435
# Mdot lengths 524288 524288
# Simulating radius  134 , r =  58.136832660296214 , deltau =  0.055529173669248796
# Fractional rms of simulated light curve =  0.0350411947362753
# Mdot lengths 524288 524288
# Simulating radius  133 , r =  56.698414045813024 , deltau =  0.053481124022611834
# Fractional rms of simulated light curve =  0.032960741762075606
# Mdot lengths 524288 524288
# Simulating radius  132 , r =  55.29558471295757 , deltau =  0.05150861137892253
# Fractional rms of simulated light curve =  0.03366176406399209
# Mdot lengths 524288 524288
# Simulating radius  131 , r =  53.9274641134986 , deltau =  0.049608849751607266
# Fractional rms of simulated light curve =  0.03394941424603102
# Mdot lengths 524288 524288
# Simulating radius  130 , r =  52.59319348568531 , deltau =  0.0477791559079885
# Fractional rms of simulated light curve =  0.035183693529373124
# Mdot lengths 524288 524288
# Simulating radius  129 , r =  51.29193531520727 , deltau =  0.04601694557947252
# Fractional rms of simulated light curve =  0.03343715454570902
# Mdot lengths 524288 524288
# Simulating radius  128 , r =  50.022872809491375 , deltau =  0.04431972981151082
# Fractional rms of simulated light curve =  0.03389972156428548
# Mdot lengths 524288 524288
# Simulating radius  127 , r =  48.78520938500562 , deltau =  0.042685111448195416
# Fractional rms of simulated light curve =  0.03458097190088004
# Mdot lengths 524288 524288
# Simulating radius  126 , r =  47.57816816724805 , deltau =  0.041110781746499486
# Fractional rms of simulated light curve =  0.03445216892738211
# Mdot lengths 524288 524288
# Simulating radius  125 , r =  46.400991503106894 , deltau =  0.0395945171153992
# Fractional rms of simulated light curve =  0.03405654581647913
# Mdot lengths 524288 524288
# Simulating radius  124 , r =  45.252940485285855 , deltau =  0.03813417597526439
# Fractional rms of simulated light curve =  0.03438013240856813
# Mdot lengths 524288 524288
# Simulating radius  123 , r =  44.13329448849613 , deltau =  0.036727695733074744
# Fractional rms of simulated light curve =  0.03416594272264032
# Mdot lengths 524288 524288
# Simulating radius  122 , r =  43.041350717123876 , deltau =  0.03537308986921066
# Fractional rms of simulated light curve =  0.03488842244923125
# Mdot lengths 524288 524288
# Simulating radius  121 , r =  41.9764237640893 , deltau =  0.034068445131678476
# Fractional rms of simulated light curve =  0.03334883842781508
# Mdot lengths 524288 524288
# Simulating radius  120 , r =  40.937845180620386 , deltau =  0.03281191883382626
# Fractional rms of simulated light curve =  0.034828691794190195
# Mdot lengths 524288 524288
# Simulating radius  119 , r =  39.924963056671274 , deltau =  0.03160173625172404
# Fractional rms of simulated light curve =  0.034554628998864724
# Mdot lengths 524288 524288
# Simulating radius  118 , r =  38.93714161172198 , deltau =  0.030436188117531435
# Fractional rms of simulated light curve =  0.03438156466873679
# Mdot lengths 524288 524288
# Simulating radius  117 , r =  37.97376079570242 , deltau =  0.029313628205324495
# Fractional rms of simulated light curve =  0.03437727381692696
# Mdot lengths 524288 524288
# Simulating radius  116 , r =  37.03421589979044 , deltau =  0.028232471005955065
# Fractional rms of simulated light curve =  0.034121608949126074
# Mdot lengths 524288 524288
# Simulating radius  115 , r =  36.117917176839406 , deltau =  0.027191189487669524
# Fractional rms of simulated light curve =  0.03390077394524686
# Mdot lengths 524288 524288
# Simulating radius  114 , r =  35.22428947119717 , deltau =  0.02618831293932551
# Fractional rms of simulated light curve =  0.03416715805487303
# Mdot lengths 524288 524288
# Simulating radius  113 , r =  34.352771857684026 , deltau =  0.025222424893145117
# Fractional rms of simulated light curve =  0.033561866253809476
# Mdot lengths 524288 524288
# Simulating radius  112 , r =  33.502817289503135 , deltau =  0.024292161124096455
# Fractional rms of simulated light curve =  0.03393736839113893
# Mdot lengths 524288 524288
# Simulating radius  111 , r =  32.67389225486219 , deltau =  0.023396207723050243
# Fractional rms of simulated light curve =  0.03374736130644308
# Mdot lengths 524288 524288
# Simulating radius  110 , r =  31.865476442091083 , deltau =  0.02253329924101041
# Fractional rms of simulated light curve =  0.03381432353590623
# Mdot lengths 524288 524288
# Simulating radius  109 , r =  31.077062413045056 , deltau =  0.02170221690178883
# Fractional rms of simulated light curve =  0.034820239213042226
# Mdot lengths 524288 524288
# Simulating radius  108 , r =  30.308155284588636 , deltau =  0.02090178688059529
# Fractional rms of simulated light curve =  0.0347161888932977
# Mdot lengths 524288 524288
# Simulating radius  107 , r =  29.55827241796022 , deltau =  0.02013087864612648
# Fractional rms of simulated light curve =  0.03412325279167787
# Mdot lengths 524288 524288
# Simulating radius  106 , r =  28.826943115822377 , deltau =  0.01938840336379537
# Fractional rms of simulated light curve =  0.03427194315765982
# Mdot lengths 524288 524288
# Simulating radius  105 , r =  28.11370832680773 , deltau =  0.018673312357856697
# Fractional rms of simulated light curve =  0.03416353991296279
# Mdot lengths 524288 524288
# Simulating radius  104 , r =  27.41812035737491 , deltau =  0.017984595630253005
# Fractional rms of simulated light curve =  0.034269389374795775
# Mdot lengths 524288 524288
# Simulating radius  103 , r =  26.739742590793853 , deltau =  0.017321280434085415
# Fractional rms of simulated light curve =  0.03441370637843181
# Mdot lengths 524288 524288
# Simulating radius  102 , r =  26.078149213083847 , deltau =  0.01668242989970467
# Fractional rms of simulated light curve =  0.034422010783981556
# Mdot lengths 524288 524288
# Simulating radius  101 , r =  25.43292494573246 , deltau =  0.01606714171146987
# Fractional rms of simulated light curve =  0.03434741297228227
# Mdot lengths 524288 524288
# Simulating radius  100 , r =  24.803664785027504 , deltau =  0.015474546833313447
# Fractional rms of simulated light curve =  0.03423152117427328
# Mdot lengths 524288 524288
# Simulating radius  99 , r =  24.18997374783844 , deltau =  0.01490380828131224
# Fractional rms of simulated light curve =  0.033771683165770665
# Mdot lengths 524288 524288
# Simulating radius  98 , r =  23.591466623687634 , deltau =  0.01435411994152372
# Fractional rms of simulated light curve =  0.033874375265350046
# Mdot lengths 524288 524288
# Simulating radius  97 , r =  23.007767732955905 , deltau =  0.013824705431429917
# Fractional rms of simulated light curve =  0.03416914719688871
# Mdot lengths 524288 524288
# Simulating radius  96 , r =  22.43851069107046 , deltau =  0.013314817003369716
# Fractional rms of simulated light curve =  0.035071060234362995
# Mdot lengths 524288 524288
# Simulating radius  95 , r =  21.883338178527342 , deltau =  0.012823734488415992
# Fractional rms of simulated light curve =  0.033573861969669244
# Mdot lengths 524288 524288
# Simulating radius  94 , r =  21.341901716603935 , deltau =  0.012350764279207057
# Fractional rms of simulated light curve =  0.034292465477954746
# Mdot lengths 524288 524288
# Simulating radius  93 , r =  20.813861448620795 , deltau =  0.01189523835028926
# Fractional rms of simulated light curve =  0.03466520024068426
# Mdot lengths 524288 524288
# Simulating radius  92 , r =  20.298885926615505 , deltau =  0.011456513314597615
# Fractional rms of simulated light curve =  0.03453226283985774
# Mdot lengths 524288 524288
# Simulating radius  91 , r =  19.796651903294602 , deltau =  0.011033969514731177
# Fractional rms of simulated light curve =  0.03451957248945871
# Mdot lengths 524288 524288
# Simulating radius  90 , r =  19.30684412913304 , deltau =  0.010627010147746061
# Fractional rms of simulated light curve =  0.03434541292602386
# Mdot lengths 524288 524288
# Simulating radius  89 , r =  18.829155154493797 , deltau =  0.010235060422228028
# Fractional rms of simulated light curve =  0.03480070468901869
# Mdot lengths 524288 524288
# Simulating radius  88 , r =  18.363285136643434 , deltau =  0.00985756674645511
# Fractional rms of simulated light curve =  0.03441318044787513
# Mdot lengths 524288 524288
# Simulating radius  87 , r =  17.908941651542474 , deltau =  0.009493995946499984
# Fractional rms of simulated light curve =  0.03477556547421397
# Mdot lengths 524288 524288
# Simulating radius  86 , r =  17.465839510292444 , deltau =  0.009143834513174664
# Fractional rms of simulated light curve =  0.03378038555174509
# Mdot lengths 524288 524288
# Simulating radius  85 , r =  17.03370058012437 , deltau =  0.00880658787674612
# Fractional rms of simulated light curve =  0.03378549161588512
# Mdot lengths 524288 524288
# Simulating radius  84 , r =  16.612253609816396 , deltau =  0.008481779708404089
# Fractional rms of simulated light curve =  0.034218019496277306
# Mdot lengths 524288 524288
# Simulating radius  83 , r =  16.201234059430842 , deltau =  0.00816895124749262
# Fractional rms of simulated light curve =  0.034964424776171156
# Mdot lengths 524288 524288
# Simulating radius  82 , r =  15.800383934263985 , deltau =  0.007867660653552414
# Fractional rms of simulated light curve =  0.03419365818076501
# Mdot lengths 524288 524288
# Simulating radius  81 , r =  15.409451622904204 , deltau =  0.00757748238226494
# Fractional rms of simulated light curve =  0.03379414259077332
# Mdot lengths 524288 524288
# Simulating radius  80 , r =  15.028191739296872 , deltau =  0.007298006584410682
# Fractional rms of simulated light curve =  0.03481127431931229
# Mdot lengths 524288 524288
# Simulating radius  79 , r =  14.65636496871689 , deltau =  0.007028838526996867
# Fractional rms of simulated light curve =  0.03485110507722538
# Mdot lengths 524288 524288
# Simulating radius  78 , r =  14.293737917552141 , deltau =  0.006769598035733192
# Fractional rms of simulated light curve =  0.034217633208167106
# Mdot lengths 524288 524288
# Simulating radius  77 , r =  13.940082966803637 , deltau =  0.006519918958073314
# Fractional rms of simulated light curve =  0.0342857620326469
# Mdot lengths 524288 524288
# Simulating radius  76 , r =  13.595178129210302 , deltau =  0.006279448646058267
# Fractional rms of simulated light curve =  0.03439908722887064
# Mdot lengths 524288 524288
# Simulating radius  75 , r =  13.25880690990881 , deltau =  0.006047847458235072
# Fractional rms of simulated light curve =  0.03412089322325732
# Mdot lengths 524288 524288
# Simulating radius  74 , r =  12.93075817054094 , deltau =  0.005824788279945822
# Fractional rms of simulated light curve =  0.03399649824323391
# Mdot lengths 524288 524288
# Simulating radius  73 , r =  12.610825996723202 , deltau =  0.005609956061308276
# Fractional rms of simulated light curve =  0.03404063843977412
# Mdot lengths 524288 524288
# Simulating radius  72 , r =  12.298809568795516 , deltau =  0.005403047372238892
# Fractional rms of simulated light curve =  0.03433114648811042
# Mdot lengths 524288 524288
# Simulating radius  71 , r =  11.994513035767822 , deltau =  0.005203769973886329
# Fractional rms of simulated light curve =  0.03464195037702762
# Mdot lengths 524288 524288
# Simulating radius  70 , r =  11.697745392385485 , deltau =  0.00501184240587171
# Fractional rms of simulated light curve =  0.03422668212838942
# Mdot lengths 524288 524288
# Simulating radius  69 , r =  11.408320359236347 , deltau =  0.004826993588753066
# Fractional rms of simulated light curve =  0.034208666124150085
# Mdot lengths 524288 524288
# Simulating radius  68 , r =  11.126056265824184 , deltau =  0.00464896244115038
# Fractional rms of simulated light curve =  0.03408829182152095
# Mdot lengths 524288 524288
# Simulating radius  67 , r =  10.850775936535134 , deltau =  0.0044774975109942786
# Fractional rms of simulated light curve =  0.034282887404520505
# Mdot lengths 524288 524288
# Simulating radius  66 , r =  10.582306579425529 , deltau =  0.00431235662037293
# Fractional rms of simulated light curve =  0.034160824868426906
# Mdot lengths 524288 524288
# Simulating radius  65 , r =  10.320479677761364 , deltau =  0.004153306523479057
# Fractional rms of simulated light curve =  0.034228939994607153
# Mdot lengths 524288 524288
# Simulating radius  64 , r =  10.065130884241253 , deltau =  0.0040001225771728235
# Fractional rms of simulated light curve =  0.034530012822923874
# Mdot lengths 524288 524288
# Simulating radius  63 , r =  9.816099917836546 , deltau =  0.0
# Mdot lengths 524288 524288
# Simulated  2  light curves
# rms values, disk disp:  0.0722046515782898  seed disp:  0.021699710591712867  heat:  0.14702235563634394
# disk due to heating:  0.06416815814136675  seed due to heating:  0.014964118965896901
# Total mean luminosity (absorption corrected):  1.0005178690658458
# Simulating radius  199 , r =  296.265462867623 , deltau =  0.6388011650925339
# ...
# Fractional rms of simulated light curve =  0.034613697571409835
# Mdot lengths 524288 524288
# Simulating radius  154 , r =  95.95342766345976 , deltau =  0.11774294646369836
# Fractional rms of simulated light curve =  0.03309611646352404
# Mdot lengths 524288 524288
# Simulating radius  153 , r =  93.57935274126596 , deltau =  0.11340030305727426
# Fractional rms of simulated light curve =  0.035494367230281036
# Mdot lengths 524288 524288
# Simulating radius  152 , r =  91.26401706240549 , deltau =  0.10921782679734852
# Fractional rms of simulated light curve =  0.031451891185456
# Mdot lengths 524288 524288
# Simulating radius  151 , r =  89.00596730344901 , deltau =  0.10518961033385404
# Fractional rms of simulated light curve =  0.033416023162760974
# Mdot lengths 524288 524288
# Simulating radius  150 , r =  86.80378609902304 , deltau =  0.10130996419401778
# Fractional rms of simulated light curve =  0.03227612958590708
# Mdot lengths 524288 524288
# Simulating radius  149 , r =  84.65609115213746 , deltau =  0.09757340874653274
# Fractional rms of simulated light curve =  0.03372223790940378
# Mdot lengths 524288 524288
# Simulating radius  148 , r =  82.56153436652534 , deltau =  0.09397466646207525
# Fractional rms of simulated light curve =  0.03332501576429088
# Mdot lengths 524288 524288
# Simulating radius  147 , r =  80.51880100045038 , deltau =  0.09050865445932489
# Fractional rms of simulated light curve =  0.03335429553371541
# Mdot lengths 524288 524288
# Simulating radius  146 , r =  78.52660884145075 , deltau =  0.08717047732585828
# Fractional rms of simulated light curve =  0.03423492809766319
# Mdot lengths 524288 524288
# Simulating radius  145 , r =  76.58370740150144 , deltau =  0.08395542020385188
# Fractional rms of simulated light curve =  0.03356868506525977
# Mdot lengths 524288 524288
# Simulating radius  144 , r =  74.68887713208973 , deltau =  0.08085894213079839
# Fractional rms of simulated light curve =  0.03641150455233328
# Mdot lengths 524288 524288
# Simulating radius  143 , r =  72.8409286587114 , deltau =  0.0778766696258118
# Fractional rms of simulated light curve =  0.03525380945237724
# Mdot lengths 524288 524288
# Simulating radius  142 , r =  71.03870203430697 , deltau =  0.07500439051252329
# Fractional rms of simulated light curve =  0.03342465567485805
# Mdot lengths 524288 524288
# Simulating radius  141 , r =  69.28106601116914 , deltau =  0.07223804796976682
# Fractional rms of simulated light curve =  0.03281838885935717
# Mdot lengths 524288 524288
# Simulating radius  140 , r =  67.5669173308651 , deltau =  0.06957373480171009
# Fractional rms of simulated light curve =  0.033843210252926643
# Mdot lengths 524288 524288
# Simulating radius  139 , r =  65.8951800317271 , deltau =  0.06700768791931852
# Fractional rms of simulated light curve =  0.033243387401080876
# Mdot lengths 524288 524288
# Simulating radius  138 , r =  64.26480477347728 , deltau =  0.06453628302533417
# Fractional rms of simulated light curve =  0.033345685511589354
# Mdot lengths 524288 524288
# Simulating radius  137 , r =  62.67476817856267 , deltau =  0.06215602949531512
# Fractional rms of simulated light curve =  0.03333628379752576
# Mdot lengths 524288 524288
# Simulating radius  136 , r =  61.124072189786666 , deltau =  0.05986356544745353
# Fractional rms of simulated light curve =  0.03536840230630707
# Mdot lengths 524288 524288
# Simulating radius  135 , r =  59.61174344383406 , deltau =  0.0576556529942376
# Fractional rms of simulated light curve =  0.034880343726975696
# Mdot lengths 524288 524288
# Simulating radius  134 , r =  58.136832660296214 , deltau =  0.055529173669248796
# Fractional rms of simulated light curve =  0.03539934722881917
# Mdot lengths 524288 524288
# Simulating radius  133 , r =  56.698414045813024 , deltau =  0.053481124022611834
# Fractional rms of simulated light curve =  0.033641196224548
# Mdot lengths 524288 524288
# Simulating radius  132 , r =  55.29558471295757 , deltau =  0.05150861137892253
# Fractional rms of simulated light curve =  0.03495714705019323
# Mdot lengths 524288 524288
# Simulating radius  131 , r =  53.9274641134986 , deltau =  0.049608849751607266
# Fractional rms of simulated light curve =  0.0338638841461479
# Mdot lengths 524288 524288
# Simulating radius  130 , r =  52.59319348568531 , deltau =  0.0477791559079885
# Fractional rms of simulated light curve =  0.033451121687814424
# Mdot lengths 524288 524288
# Simulating radius  129 , r =  51.29193531520727 , deltau =  0.04601694557947252
# Fractional rms of simulated light curve =  0.03485458653784977
# Mdot lengths 524288 524288
# Simulating radius  128 , r =  50.022872809491375 , deltau =  0.04431972981151082
# Fractional rms of simulated light curve =  0.03479659518849566
# Mdot lengths 524288 524288
# Simulating radius  127 , r =  48.78520938500562 , deltau =  0.042685111448195416
# Fractional rms of simulated light curve =  0.03505358950271387
# Mdot lengths 524288 524288
# Simulating radius  126 , r =  47.57816816724805 , deltau =  0.041110781746499486
# Fractional rms of simulated light curve =  0.03374708408679408
# Mdot lengths 524288 524288
# Simulating radius  125 , r =  46.400991503106894 , deltau =  0.0395945171153992
# Fractional rms of simulated light curve =  0.0352875087546211
# Mdot lengths 524288 524288
# Simulating radius  124 , r =  45.252940485285855 , deltau =  0.03813417597526439
# Fractional rms of simulated light curve =  0.03431940213578848
# Mdot lengths 524288 524288
# Simulating radius  123 , r =  44.13329448849613 , deltau =  0.036727695733074744
# Fractional rms of simulated light curve =  0.03453597855369505
# Mdot lengths 524288 524288
# Simulating radius  122 , r =  43.041350717123876 , deltau =  0.03537308986921066
# Fractional rms of simulated light curve =  0.03423017964032671
# Mdot lengths 524288 524288
# Simulating radius  121 , r =  41.9764237640893 , deltau =  0.034068445131678476
# Fractional rms of simulated light curve =  0.03436971485493315
# Mdot lengths 524288 524288
# Simulating radius  120 , r =  40.937845180620386 , deltau =  0.03281191883382626
# Fractional rms of simulated light curve =  0.03394015718023482
# Mdot lengths 524288 524288
# Simulating radius  119 , r =  39.924963056671274 , deltau =  0.03160173625172404
# Fractional rms of simulated light curve =  0.034314602124714724
# Mdot lengths 524288 524288
# Simulating radius  118 , r =  38.93714161172198 , deltau =  0.030436188117531435
# Fractional rms of simulated light curve =  0.034182080976652866
# Mdot lengths 524288 524288
# Simulating radius  117 , r =  37.97376079570242 , deltau =  0.029313628205324495
# Fractional rms of simulated light curve =  0.03364000759005007
# Mdot lengths 524288 524288
# Simulating radius  116 , r =  37.03421589979044 , deltau =  0.028232471005955065
# Fractional rms of simulated light curve =  0.03373154926368686
# Mdot lengths 524288 524288
# Simulating radius  115 , r =  36.117917176839406 , deltau =  0.027191189487669524
# Fractional rms of simulated light curve =  0.034108009719294494
# Mdot lengths 524288 524288
# Simulating radius  114 , r =  35.22428947119717 , deltau =  0.02618831293932551
# Fractional rms of simulated light curve =  0.034744138912621174
# Mdot lengths 524288 524288
# Simulating radius  113 , r =  34.352771857684026 , deltau =  0.025222424893145117
# Fractional rms of simulated light curve =  0.034639330997629655
# Mdot lengths 524288 524288
# Simulating radius  112 , r =  33.502817289503135 , deltau =  0.024292161124096455
# Fractional rms of simulated light curve =  0.03448323990704502
# Mdot lengths 524288 524288
# Simulating radius  111 , r =  32.67389225486219 , deltau =  0.023396207723050243
# Fractional rms of simulated light curve =  0.03417827162879908
# Mdot lengths 524288 524288
# Simulating radius  110 , r =  31.865476442091083 , deltau =  0.02253329924101041
# Fractional rms of simulated light curve =  0.03477206989962554
# Mdot lengths 524288 524288
# Simulating radius  109 , r =  31.077062413045056 , deltau =  0.02170221690178883
# Fractional rms of simulated light curve =  0.03416512756277892
# Mdot lengths 524288 524288
# Simulating radius  108 , r =  30.308155284588636 , deltau =  0.02090178688059529
# Fractional rms of simulated light curve =  0.03336502737911965
# Mdot lengths 524288 524288
# Simulating radius  107 , r =  29.55827241796022 , deltau =  0.02013087864612648
# Fractional rms of simulated light curve =  0.03467474461054538
# Mdot lengths 524288 524288
# Simulating radius  106 , r =  28.826943115822377 , deltau =  0.01938840336379537
# Fractional rms of simulated light curve =  0.03408511177760218
# Mdot lengths 524288 524288
# Simulating radius  105 , r =  28.11370832680773 , deltau =  0.018673312357856697
# Fractional rms of simulated light curve =  0.0347453421781777
# Mdot lengths 524288 524288
# Simulating radius  104 , r =  27.41812035737491 , deltau =  0.017984595630253005
# Fractional rms of simulated light curve =  0.033943295560102615
# Mdot lengths 524288 524288
# Simulating radius  103 , r =  26.739742590793853 , deltau =  0.017321280434085415
# Fractional rms of simulated light curve =  0.034851332727016106
# Mdot lengths 524288 524288
# Simulating radius  102 , r =  26.078149213083847 , deltau =  0.01668242989970467
# Fractional rms of simulated light curve =  0.03395890169017606
# Mdot lengths 524288 524288
# Simulating radius  101 , r =  25.43292494573246 , deltau =  0.01606714171146987
# Fractional rms of simulated light curve =  0.03393856669846558
# Mdot lengths 524288 524288
# Simulating radius  100 , r =  24.803664785027504 , deltau =  0.015474546833313447
# Fractional rms of simulated light curve =  0.03432036260333486
# Mdot lengths 524288 524288
# Simulating radius  99 , r =  24.18997374783844 , deltau =  0.01490380828131224
# Fractional rms of simulated light curve =  0.03387598524638036
# Mdot lengths 524288 524288
# Simulating radius  98 , r =  23.591466623687634 , deltau =  0.01435411994152372
# Fractional rms of simulated light curve =  0.033904284706178796
# Mdot lengths 524288 524288
# Simulating radius  97 , r =  23.007767732955905 , deltau =  0.013824705431429917
# Fractional rms of simulated light curve =  0.03435561151873225
# Mdot lengths 524288 524288
# Simulating radius  96 , r =  22.43851069107046 , deltau =  0.013314817003369716
# Fractional rms of simulated light curve =  0.03469742933257486
# Mdot lengths 524288 524288
# Simulating radius  95 , r =  21.883338178527342 , deltau =  0.012823734488415992
# Fractional rms of simulated light curve =  0.034242084705787997
# Mdot lengths 524288 524288
# Simulating radius  94 , r =  21.341901716603935 , deltau =  0.012350764279207057
# Fractional rms of simulated light curve =  0.033667377118950945
# Mdot lengths 524288 524288
# Simulating radius  93 , r =  20.813861448620795 , deltau =  0.01189523835028926
# Fractional rms of simulated light curve =  0.03417548432026213
# Mdot lengths 524288 524288
# Simulating radius  92 , r =  20.298885926615505 , deltau =  0.011456513314597615
# Fractional rms of simulated light curve =  0.03407843893424761
# Mdot lengths 524288 524288
# Simulating radius  91 , r =  19.796651903294602 , deltau =  0.011033969514731177
# Fractional rms of simulated light curve =  0.03482638113954148
# Mdot lengths 524288 524288
# Simulating radius  90 , r =  19.30684412913304 , deltau =  0.010627010147746061
# Fractional rms of simulated light curve =  0.03485602607862951
# Mdot lengths 524288 524288
# Simulating radius  89 , r =  18.829155154493797 , deltau =  0.010235060422228028
# Fractional rms of simulated light curve =  0.034657415157164
# Mdot lengths 524288 524288
# Simulating radius  88 , r =  18.363285136643434 , deltau =  0.00985756674645511
# Fractional rms of simulated light curve =  0.034454976161875546
# Mdot lengths 524288 524288
# Simulating radius  87 , r =  17.908941651542474 , deltau =  0.009493995946499984
# Fractional rms of simulated light curve =  0.034760902878959346
# Mdot lengths 524288 524288
# Simulating radius  86 , r =  17.465839510292444 , deltau =  0.009143834513174664
# Fractional rms of simulated light curve =  0.03410184234169009
# Mdot lengths 524288 524288
# Simulating radius  85 , r =  17.03370058012437 , deltau =  0.00880658787674612
# Fractional rms of simulated light curve =  0.034177018986748436
# Mdot lengths 524288 524288
# Simulating radius  84 , r =  16.612253609816396 , deltau =  0.008481779708404089
# Fractional rms of simulated light curve =  0.03422017945843609
# Mdot lengths 524288 524288
# Simulating radius  83 , r =  16.201234059430842 , deltau =  0.00816895124749262
# Fractional rms of simulated light curve =  0.03476493025505972
# Mdot lengths 524288 524288
# Simulating radius  82 , r =  15.800383934263985 , deltau =  0.007867660653552414
# Fractional rms of simulated light curve =  0.03397467401053271
# Mdot lengths 524288 524288
# Simulating radius  81 , r =  15.409451622904204 , deltau =  0.00757748238226494
# Fractional rms of simulated light curve =  0.034205062490133845
# Mdot lengths 524288 524288
# Simulating radius  80 , r =  15.028191739296872 , deltau =  0.007298006584410682
# Fractional rms of simulated light curve =  0.03469860531510605
# Mdot lengths 524288 524288
# Simulating radius  79 , r =  14.65636496871689 , deltau =  0.007028838526996867
# Fractional rms of simulated light curve =  0.03475640418814133
# Mdot lengths 524288 524288
# Simulating radius  78 , r =  14.293737917552141 , deltau =  0.006769598035733192
# Fractional rms of simulated light curve =  0.0339938025931316
# Mdot lengths 524288 524288
# Simulating radius  77 , r =  13.940082966803637 , deltau =  0.006519918958073314
# Fractional rms of simulated light curve =  0.034270813489536214
# Mdot lengths 524288 524288
# Simulating radius  76 , r =  13.595178129210302 , deltau =  0.006279448646058267
# Fractional rms of simulated light curve =  0.03477827435914159
# Mdot lengths 524288 524288
# Simulating radius  75 , r =  13.25880690990881 , deltau =  0.006047847458235072
# Fractional rms of simulated light curve =  0.034763939114344285
# Mdot lengths 524288 524288
# Simulating radius  74 , r =  12.93075817054094 , deltau =  0.005824788279945822
# Fractional rms of simulated light curve =  0.033804817823598725
# Mdot lengths 524288 524288
# Simulating radius  73 , r =  12.610825996723202 , deltau =  0.005609956061308276
# Fractional rms of simulated light curve =  0.0345424260329462
# Mdot lengths 524288 524288
# Simulating radius  72 , r =  12.298809568795516 , deltau =  0.005403047372238892
# Fractional rms of simulated light curve =  0.033768997892635044
# Mdot lengths 524288 524288
# Simulating radius  71 , r =  11.994513035767822 , deltau =  0.005203769973886329
# Fractional rms of simulated light curve =  0.03444391564060383
# Mdot lengths 524288 524288
# Simulating radius  70 , r =  11.697745392385485 , deltau =  0.00501184240587171
# Fractional rms of simulated light curve =  0.03439212729445252
# Mdot lengths 524288 524288
# Simulating radius  69 , r =  11.408320359236347 , deltau =  0.004826993588753066
# Fractional rms of simulated light curve =  0.034305231674576435
# Mdot lengths 524288 524288
# Simulating radius  68 , r =  11.126056265824184 , deltau =  0.00464896244115038
# Fractional rms of simulated light curve =  0.034442178248427956
# Mdot lengths 524288 524288
# Simulating radius  67 , r =  10.850775936535134 , deltau =  0.0044774975109942786
# Fractional rms of simulated light curve =  0.03438386390525252
# Mdot lengths 524288 524288
# Simulating radius  66 , r =  10.582306579425529 , deltau =  0.00431235662037293
# Fractional rms of simulated light curve =  0.03404673330877222
# Mdot lengths 524288 524288
# Simulating radius  65 , r =  10.320479677761364 , deltau =  0.004153306523479057
# Fractional rms of simulated light curve =  0.03431113318105836
# Mdot lengths 524288 524288
# Simulating radius  64 , r =  10.065130884241253 , deltau =  0.0040001225771728235
# Fractional rms of simulated light curve =  0.034213546587851695
# Mdot lengths 524288 524288
# Simulating radius  63 , r =  9.816099917836546 , deltau =  0.0
# Mdot lengths 524288 524288
# Simulated  10  light curves
# rms values, disk disp:  0.06987025870934303  seed disp:  0.02139766813766607  heat:  0.1456368179538858
# disk due to heating:  0.06351405431372527  seed due to heating:  0.014811580888190014
# Total mean luminosity (absorption corrected):  1.001333837031195

# %%
ls_list = ['solid','dashed','dotted']
vlines_list = []
laglist = []
psdlist = []

for j in range(3):
    if j == 0:
        labtxt = 'Linear impulse response model'
    else:
        labtxt = None
    laglist.append([freq,tlag[j,:],CBcol[0],ls_list[j],labtxt])
    if j == 0:
        psdlist.append([freq,freq*psd_ref[j,:],CBcol[0],ls_list[j],labtxt])
    else:
        psdlist.append([freq,freq*psd_ci[j,:],CBcol[0],ls_list[j],labtxt])
for j in range(3):
    if j == 0:
        labtxt = r'40% rms simulation'
    else:
        labtxt = None
    laglist.append([bin_freq,bin_tlagarr[j,:],CBcol[1],ls_list[j],labtxt])
    if j == 0:
        psdlist.append([bin_freq,bin_freq*bin_psd_ref[0,:],CBcol[1],ls_list[j],labtxt])
    else:
        psdlist.append([bin_freq,bin_freq*bin_psd_ciarr[j,:],CBcol[1],ls_list[j],labtxt])

vlines_list.append([1./(tau[i_rcor]*t_scale),'gray','dashdot'])

freqlim = [0.007,100.0]
tlaglim = [0.001,1]
tlaglim_in = [-0.01,0.005]
psdlim = [0.0001,0.07]
inset_yticks = [-0.005,0,0.005]
axis_names = ['Frequency (Hz)','Time lag (s)',r'$\nu P(\nu)$ (frac. rms$^{2}$)']
leg_title=None
figfile = 'figs/lagspsd_modelsim40pcrms_compare.pdf'
#figfile = None
uml.plot_lags_psds(laglist, psdlist, vlines_list, axis_names, freqlim, tlaglim, tlaglim_in, psdlim, 
               inset_yticks, leg_title, figfile)
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
cor_prop_par = [10., 0.] # As disk_prop_par but for radial propagation delays generated in the corona
lor_par = [1.0,0.4,0.0] # For continuous model: [q,total_rms_in_disk,total_rms_in_corona], if the last parameter is 
                        # < 0, the total_rms_in_disk is split evenly across corona and disk radii
# Now calculate radial dependence of timing parameters and calculate propagation delays
tau_cp, lfreq_cp, q_cp, rms_cp = uml.calc_timing_params(rad, i_rsigmax, rcor, i_rcor, t_scale, disk_tau_par, cor_tau_par,\
                                        lor_model, lor_par)

deltau_cp = uml.calc_propagation_params(rad,rad_edge,rcor,disk_prop_par,cor_prop_par)    
# Calculate frequency-dependent spectral-timing products using the mono-energetic calculation
freq_cp, phlag_cp, tlag_cp, psd_ci_cp, psd_ref_cp, mod_sig_psd_cp, irf_nbins_cp, irf_binedgefrac_cp,\
        deltau_scale_cp, dt_cp, nirf_cp,\
        ci_irf_cp, ci_mean_cp, ci_outer_cp =\
        uml.calculate_stprod_mono(nirf_mult,ens_mono,encomb,flux_irf_mono,disk_irf_mono,gamma_irf,
                                deltau_cp,min_deltau_frac,i_rsigmax,lfreq_cp,q_cp,rms_cp,t_scale)
# Out:
# #######################################
# Calculating mono-energetic spectral-timing products
# Time bin size dt is:  9.025878937246894e-06
# The maximum propagation delay is:  17.224988706393415  and there are  16777216  irf bins.
# CI mean, ref mean, CI outer, ref outer :  1.0 0.4686037582175344 0.0 0.0
# Calculated for energies  [2 0]
# CI mean, ref mean, CI outer, ref outer :  1.0 1.0 0.0 0.0
# Calculated for energies  [3 2]
# CI mean, ref mean, CI outer, ref outer :  1.0 1.0 0.0 0.0
# Calculated for energies  [4 3]
# #######################################

# %%
cor_prop_par = [10., 0.] # As disk_prop_par but for radial propagation delays generated in the corona
lor_par = [1.0,0.4,-0.1] # For continuous model: [q,total_rms_in_disk,total_rms_in_corona], if the last parameter is 
                        # < 0, the total_rms_in_disk is split evenly across corona and disk radii
# Now calculate radial dependence of timing parameters and calculate propagation delays
tau_cpcr, lfreq_cpcr, q_cpcr, rms_cpcr = uml.calc_timing_params(rad, i_rsigmax, rcor, i_rcor, t_scale, disk_tau_par, cor_tau_par,\
                                        lor_model, lor_par)

deltau_cpcr = uml.calc_propagation_params(rad,rad_edge,rcor,disk_prop_par,cor_prop_par)    
# Calculate frequency-dependent spectral-timing products using the mono-energetic calculation
freq_cpcr, phlag_cpcr, tlag_cpcr, psd_ci_cpcr, psd_ref_cpcr, mod_sig_psd_cpcr, irf_nbins_cpcr, irf_binedgefrac_cpcr,\
        deltau_scale_cpcr, dt_cpcr, nirf_cpcr,\
        ci_irf_cpcr, ci_mean_cpcr, ci_outer_cpcr =\
        uml.calculate_stprod_mono(nirf_mult,ens_mono,encomb,flux_irf_mono,disk_irf_mono,gamma_irf,
                                deltau_cpcr,min_deltau_frac,i_rsigmax,lfreq_cpcr,q_cpcr,rms_cpcr,t_scale)
# Out:
# #######################################
# Calculating mono-energetic spectral-timing products
# Time bin size dt is:  9.025878937246894e-06
# The maximum propagation delay is:  17.224988706393415  and there are  16777216  irf bins.
# CI mean, ref mean, CI outer, ref outer :  1.0 0.4686037582175344 0.0 0.0
# Calculated for energies  [2 0]
# CI mean, ref mean, CI outer, ref outer :  1.0 1.0 0.0 0.0
# Calculated for energies  [3 2]
# CI mean, ref mean, CI outer, ref outer :  1.0 1.0 0.0 0.0
# Calculated for energies  [4 3]
# #######################################

# %%
# Due to the small dt, the coronal propagation products are enormous arrays so to speed up plotting we use a 
# geometrically spaced array (with linear spacing for the first values)
nvals = len(psd_ref_cp[0,:])
vals = np.rint(np.geomspace(1,nvals,10000)-1)
ivals = np.unique(vals.astype(int))


ls_list = ['solid','dashed','dotted']
vlines_list = []
laglist = []
psdlist = []

for j in range(3):
    if j == 0:
        labtxt = r'$v_{r,cor} = \infty$, $rms_{i, cor} = 0$'
    else:
        labtxt = None
    laglist.append([freq,tlag[j,:],CBcol[0],ls_list[j],labtxt])
    if j == 0:
        psdlist.append([freq,psd_ref[j,:]/mod_sig_psd[0,:],CBcol[0],ls_list[j],labtxt])
    else:
        psdlist.append([freq,psd_ci[j,:]/mod_sig_psd[0,:],CBcol[0],ls_list[j],labtxt])
for j in range(3):
    if j == 0:
        labtxt = r'$v_{r,cor}=0.1 r^{-1/2}$, $rms_{i, cor} = 0$'
    else:
        labtxt = None
    laglist.append([freq_cp[ivals],tlag_cp[j,ivals],CBcol[1],ls_list[j],labtxt])
    if j == 0:
        psdlist.append([freq_cp[ivals],psd_ref_cp[j,ivals]/mod_sig_psd_cp[0,ivals],CBcol[1],ls_list[j],labtxt])
    else:
        psdlist.append([freq_cp[ivals],psd_ci_cp[j,ivals]/mod_sig_psd_cp[0,ivals],CBcol[1],ls_list[j],labtxt])
for j in range(3):
    if j == 0:
        labtxt = r'$v_{r,cor}=0.1 r^{-1/2}$, $rms_{i, cor} = rms_{i, disk}$'
    else:
        labtxt = None
    laglist.append([freq_cpcr[ivals],tlag_cpcr[j,ivals],CBcol[2],ls_list[j],labtxt])
    if j == 0:
        psdlist.append([freq_cpcr[ivals],psd_ref_cpcr[j,ivals]/mod_sig_psd_cpcr[0,ivals],CBcol[2],ls_list[j],labtxt])
    else:
        psdlist.append([freq_cpcr[ivals],psd_ci_cpcr[j,ivals]/mod_sig_psd_cpcr[0,ivals],CBcol[2],ls_list[j],labtxt])


vlines_list.append([1./(tau[i_rcor]*t_scale),'gray','dashdot'])
vlines_list.append([1./(tau[0]*t_scale),'gray','solid'])

freqlim = [0.007,100.0]
tlaglim = [0.001,1]
tlaglim_in = [-0.01,0.005]
psdlim = [0.01,1.5]
inset_yticks = [-0.005,0,0.005]
axis_names = ['Frequency (Hz)','Time lag (s)',r'$P/P_{\Sigma \; \dot{m}(r)}$']
leg_title=None
figfile = 'figs/lagspsd_coronalprop_compare.pdf'
#figfile = None
uml.plot_lags_psds(laglist, psdlist, vlines_list, axis_names, freqlim, tlaglim, tlaglim_in, psdlim, 
               inset_yticks, leg_title, figfile)
# Out:
# <img src="data:image/png;base64,..." width="800">
